# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mygene
import h5py
import networkx as nx
import seaborn as sns
# %matplotlib inline

# %%
rede = 'unity'


hist_complete = pd.read_csv(f'C:/Users/renan/Desktop/predict/concat/{rede}_complete.tsv', sep='\t')
hist_complete

#ultima_epoca = hist_complete.loc[hist_complete['epochs'] == 499]
#ultima_epoca
# Out:
#       epochs        loss       acc   auc_roc    auc_pr    val_loss   val_acc  \
# 0          0  481.962036  0.933215  0.255894  0.035965  104.653801  0.940922
# 1          1  421.336700  0.941095  0.204140  0.033904  102.469109  0.940922
# 2          2  412.464966  0.941095  0.205653  0.033961   98.190247  0.940922
# 3          3  394.532562  0.941095  0.208459  0.034058   95.076187  0.940922
# 4          4  381.333466  0.941095  0.213283  0.034226   91.965157  0.940922
# ...      ...         ...       ...       ...       ...         ...       ...
# 2495     495  228.606384  0.948390  0.901087  0.478826   56.964344  0.916864
# 2496     496  211.474823  0.922092  0.891687  0.492267   61.018482  0.884949
# 2497     497  230.150299  0.892150  0.887288  0.485296   55.993572  0.946414
# 2498     498  202.704391  0.949473  0.895101  0.500335   63.850712  0.947203
# 2499     499  228.343918  0.948882  0.899432  0.504304   56.740307  0.948779
#
#       val_auc_roc  val_auc_pr  fold
# ...

# %%
SMALL_SIZE = 10 #10 para individual 
MEDIUM_SIZE = 18 #18 para figura individual #26 para pagina completa
BIGGER_SIZE = 20 #20 para figura individual #26 para pagina completa

plt.rc('font', size=BIGGER_SIZE)          
plt.rc('axes', titlesize=MEDIUM_SIZE)     
plt.rc('axes', labelsize=MEDIUM_SIZE)    
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # MEDIUM_SIZE para individual
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # MEDIUM_SIZE para individual
plt.rc('legend', fontsize=MEDIUM_SIZE)    
plt.rc('figure', titlesize=BIGGER_SIZE)

# %%
plt.figure(figsize=(12.80,7.20))
plt.title(label="UNITY", fontsize=20)

plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.ylim(0, 1700) # 0 à 1700 loss

sns.lineplot(data=hist_complete, x='epochs', y="loss", label='Train')
sns.lineplot(data=hist_complete, x='epochs', y="val_loss", label='Validation')
plt.legend(loc='upper right')


file_name = f"C:/Users/renan/Desktop/predict/concat/loss_padrao/{rede}_loss_title.pdf"
plt.savefig(file_name, format="pdf", bbox_inches="tight")

# %% [markdown]
# ------
