# %% [markdown]
# # Node classification with Graph Convolutional Network (GCN)

# %%
import numpy as np

import mygene
import h5py
import pickle
import argparse
import networkx as nx
import seaborn as sns

import pandas as pd
import os

import stellargraph as sg
from stellargraph.layer import GCN
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import sys

from stellargraph import StellarGraph
from stellargraph import datasets
from stellargraph.mapper import (
    CorruptedGenerator,
    FullBatchNodeGenerator,
    GraphSAGENodeGenerator,
    HinSAGENodeGenerator,
    ClusterNodeGenerator,
)

from stellargraph.layer import GCN, DeepGraphInfomax, GraphSAGE, GAT, APPNP, HinSAGE
from stellargraph.utils import plot_history

from tensorflow.keras import layers, optimizers, losses, metrics, Model
from sklearn import preprocessing, feature_extraction, model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold, ParameterGrid
from sklearn.manifold import TSNE
from sklearn.metrics import average_precision_score
from IPython.display import display, HTML

import tensorflow as tf
from scipy.sparse import csr_matrix, lil_matrix
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras import Model
from keras.models import Sequential
from keras.layers import Dense

from imblearn.over_sampling import SMOTE

# %%
network = pd.read_csv('C:/Users/renan/Desktop/UFRGS/GNN/data/data_final_v2/HPRD_network.tsv', sep='\t')

features = pd.read_csv('C:/Users/renan/Desktop/UFRGS/GNN/data/data_final_v2/HPRD_features_complete.tsv', sep='\t', index_col='gene')

labels = pd.read_csv('C:/Users/renan/Desktop/UFRGS/GNN/data/data_final_v2/HPRD_labels_semisupervised.tsv', sep='\t', index_col='gene')

# %%
# Mutations 0:48
# CNA 16:64
# DNA Methylation 0:32 e 16:48
# Gene Expression 0:16 e 16:48


#features.drop(features.iloc[:, 0:16], inplace = True, axis = 1)
#features.drop(features.iloc[:, 16:48], inplace = True, axis = 1)
#features

# %%
# Transformar as labels boleanas em 0/1
labels["label"].replace({False: 0, True: 1}, inplace=True)

# Transformar as labels vazias em -1
labels["label"] = labels.label.fillna(-1)

# %%
G = StellarGraph(edges=network, nodes=features)

print(G.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 9438, Edges: 36844
#
#  Node types:
#   default: [9438]
#     Features: float32 vector, length 68
#     Edge types: default-default->default
#
#  Edge types:
#     default-default->default: [36844]
#         Weights: all 1 (default)
#         Features: none

# %%
series_classes = labels['label']

series_classes.value_counts(dropna = False).to_frame()
# Out:
#       label
#  0.0   4873
# -1.0   3772
#  1.0    793

# %%
# Dividindo dados em treino/validação/teste

train_ratio = 0.80
test_ratio = 0.20

labeled_data = labels[labels['label'] != -1]
labeled_data = labeled_data.sample(frac=1)

# Aqui aplica-se então 20% do tamanho total da rede e o restante para treino
labeled_train, labeled_test = model_selection.train_test_split(
    labeled_data, test_size=test_ratio, stratify=labeled_data)


print("Train: ", len(labeled_train))
print("Test: ", len(labeled_test))
print("\nTotal: ", len(labeled_train)+len(labeled_test))
# Out:
# Train:  4532
# Test:  1134
#
# Total:  5666

# %%
# Difinição da função de custo Focal Loss

import dill

from keras import backend as K

def binary_focal_loss(gamma=2., alpha=.25):

    def binary_focal_loss_fixed(y_true, y_pred):
     
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)
        # Define epsilon so that the back-propagation will not result in NaN for 0 divisor case
        epsilon = K.epsilon()
        # Add the epsilon to prediction value
        # y_pred = y_pred + epsilon
        # Clip the prediciton value
        y_pred = K.clip(y_pred, epsilon, 1.0 - epsilon)
        # Calculate p_t
        p_t = tf.where(K.equal(y_true, 1), y_pred, 1 - y_pred)
        # Calculate alpha_t
        alpha_factor = K.ones_like(y_true) * alpha
        alpha_t = tf.where(K.equal(y_true, 1), alpha_factor, 1 - alpha_factor)
        # Calculate cross entropy
        cross_entropy = -K.log(p_t)
        weight = alpha_t * K.pow((1 - p_t), gamma)
        # Calculate focal loss
        loss = weight * cross_entropy
        # Sum the losses in mini_batch
        loss = K.mean(K.sum(loss, axis=1))
        return loss

    return binary_focal_loss_fixed

# %%
target_encoding = preprocessing.LabelBinarizer()

train_targets = target_encoding.fit_transform(labeled_train)
test_targets = target_encoding.transform(labeled_test)



generator = FullBatchNodeGenerator(G, method="gcn")
# Out:
# Using GCN (local pooling) filters...

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import ParameterGrid


params = {'layer_sizes':[[64, 64], [128, 128], [256, 256]],
        'activations': [["ReLU", "ReLU"], ["PReLU", "PReLU"]],
        'dropout':[0.01, 0.001, 0.1],
        'learning_rate':[0.001, 0.0001, 0.00001],
        'epochs':[300, 700],
        'gamma':[0, 0.1, 0.2, 0.5, 1, 2, 5],
        'alpha':[0.95, 0.90, 0.85, 0.80, 0.75, 0.50, 0.25]
        }


num_of_settings = len(list(ParameterGrid(params)))
print ("Grid Search: Trying {} different parameter settings...".format(num_of_settings))
param_num = 0

for param_set in list(ParameterGrid(params)):

  num_folds = 5

  auc_pr_per_fold = []
  loss_per_fold = []

  kfold = StratifiedKFold(n_splits=num_folds, shuffle=True)

  fold_no = 1
  for train, test in kfold.split(labeled_train.index, train_targets):

    train_gen = generator.flow(labeled_train.index[train], train_targets[train])

    gcn = GCN(
      layer_sizes=param_set['layer_sizes'], activations=param_set['activations'], generator=generator, dropout=param_set['dropout']
    )

    x_inp, x_out = gcn.in_out_tensors()

    predictions = layers.Dense(units=train_targets.shape[1], activation="sigmoid")(x_out)

    model = Model(inputs=x_inp, outputs=predictions)
    model.compile(
      optimizer=optimizers.Adam(learning_rate=param_set['learning_rate']),
      #loss=losses.binary_crossentropy,
      loss=[binary_focal_loss(gamma=param_set['gamma'], alpha=param_set['alpha'])],
      metrics=["acc", metrics.AUC(curve="ROC", name="auc_roc"), metrics.AUC(curve="PR", name="auc_pr")],
    )

    val_gen = generator.flow(labeled_train.index[test], train_targets[test])


    # Generate a print
    print('------------------------------------------------------------------------')
    print(f'Training for fold {fold_no} ...')

    history = model.fit(
      train_gen,
      epochs=param_set['epochs'],
      validation_data=val_gen,
      verbose=2,
      shuffle=False,
    )

    # Generate generalization metrics
    #val_gen = generator.flow(labeled_train.index[test], train_targets[test])
    scores = model.evaluate(val_gen, verbose=0)
    print('\n')
    print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[3]} of {scores[3]*100}%')
    auc_pr_per_fold.append(scores[3] * 100)
    loss_per_fold.append(scores[0])

    # Save history to csv
    hist_df = pd.DataFrame(history.history)

    hist_csv_file = f'fold{fold_no}_hprd_param{param_num}.csv'
    with open(hist_csv_file, mode='w') as f:
      hist_df.to_csv(f)
    f.close()

    # Increase fold number
    fold_no = fold_no + 1

  # Provide average scores
  print('------------------------------------------------------------------------')
  print('Score per fold')
  for i in range(0, len(auc_pr_per_fold)):
    print('------------------------------------------------------------------------')
    print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - AUC PR: {auc_pr_per_fold[i]}%')
  print('------------------------------------------------------------------------')
  print('Average scores for all folds:')
  print(f'> AUC PR: {np.mean(auc_pr_per_fold)} (+- {np.std(auc_pr_per_fold)})')
  print(f'> Loss: {np.mean(loss_per_fold)}')
  print('------------------------------------------------------------------------')

  param_num += 1
#print ("[{} out of {} combinations]: {}".format(param_num, num_of_settings, param_set))
# Out:
# Grid Search: Trying 5292 different parameter settings...
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/300
# 1/1 - 4s - loss: 448.7850 - acc: 0.8414 - auc_roc: 0.3944 - auc_pr: 0.1100 - val_loss: 111.0207 - val_acc: 0.5292 - val_auc_roc: 0.4764 - val_auc_pr: 0.1295
# Epoch 2/300
# 1/1 - 0s - loss: 443.2090 - acc: 0.5600 - auc_roc: 0.4781 - auc_pr: 0.1297 - val_loss: 109.7650 - val_acc: 0.2337 - val_auc_roc: 0.5441 - val_auc_pr: 0.1619
# Epoch 3/300
# 1/1 - 0s - loss: 438.2148 - acc: 0.2538 - auc_roc: 0.5585 - auc_pr: 0.1551 - val_loss: 108.5977 - val_acc: 0.1698 - val_auc_roc: 0.6001 - val_auc_pr: 0.1940
# Epoch 4/300
# 1/1 - 0s - loss: 433.5778 - acc: 0.1688 - auc_roc: 0.6180 - auc_pr: 0.1895 - val_loss: 107.4760 - val_acc: 0.1477 - val_auc_roc: 0.6313 - val_auc_pr: 0.2193
# Epoch 5/300
# 1/1 - 0s - loss: 429.1927 - acc: 0.1481 - auc_roc: 0.6394 - auc_pr: 0.2086 - val_loss: 106.3709 - val_acc: 0.1400 - val_auc_roc: 0.6505 - val_auc_pr: 0.2382
# Epoch 6/300
# 1/1 - 0s - loss: 424.7671 - acc: 0.1410 - auc_roc: 0.6409 - auc_pr: 0.2197 - val_loss: 105.2695 - val_acc: 0.1400 - val_auc_roc: 0.6461 - val_auc_pr: 0.2436
# Epoch 7/300
# 1/1 - 0s - loss: 420.3774 - acc: 0.1399 - auc_roc: 0.6539 - auc_pr: 0.2344 - val_loss: 104.1583 - val_acc: 0.1400 - val_auc_roc: 0.6524 - val_auc_pr: 0.2576
# Epoch 8/300
# 1/1 - 0s - loss: 416.0122 - acc: 0.1399 - auc_roc: 0.6562 - auc_pr: 0.2411 - val_loss: 103.0373 - val_acc: 0.1400 - val_auc_roc: 0.6579 - val_auc_pr: 0.2631
# Epoch 9/300
# 1/1 - 0s - loss: 411.5583 - acc: 0.1399 - auc_roc: 0.6589 - auc_pr: 0.2472 - val_loss: 101.9053 - val_acc: 0.1400 - val_auc_roc: 0.6615 - val_auc_pr: 0.2663
# Epoch 10/300
# 1/1 - 0s - loss: 407.0060 - acc: 0.1399 - auc_roc: 0.6662 - auc_pr: 0.2550 - val_loss: 100.7592 - val_acc: 0.1400 - val_auc_roc: 0.6605 - val_auc_pr: 0.2772
# Epoch 11/300
# 1/1 - 0s - loss: 402.5820 - acc: 0.1399 - auc_roc: 0.6686 - auc_pr: 0.2584 - val_loss: 99.6063 - val_acc: 0.1400 - val_auc_roc: 0.6682 - val_auc_pr: 0.2861
# Epoch 12/300
# 1/1 - 0s - loss: 397.8588 - acc: 0.1399 - auc_roc: 0.6690 - auc_pr: 0.2627 - val_loss: 98.4522 - val_acc: 0.1400 - val_auc_roc: 0.6739 - val_auc_pr: 0.2877
# Epoch 13/300
# 1/1 - 0s - loss: 393.1169 - acc: 0.1399 - auc_roc: 0.6750 - auc_pr: 0.2698 - val_loss: 97.2967 - val_acc: 0.1400 - val_auc_roc: 0.6690 - val_auc_pr: 0.2869
# Epoch 14/300
# 1/1 - 0s - loss: 388.5162 - acc: 0.1399 - auc_roc: 0.6760 - auc_pr: 0.2727 - val_loss: 96.1417 - val_acc: 0.1400 - val_auc_roc: 0.6750 - val_auc_pr: 0.2899
# Epoch 15/300
# 1/1 - 0s - loss: 383.8622 - acc: 0.1399 - auc_roc: 0.6779 - auc_pr: 0.2756 - val_loss: 94.9919 - val_acc: 0.1400 - val_auc_roc: 0.6781 - val_auc_pr: 0.2930
# Epoch 16/300
# 1/1 - 0s - loss: 379.3552 - acc: 0.1399 - auc_roc: 0.6788 - auc_pr: 0.2768 - val_loss: 93.8504 - val_acc: 0.1400 - val_auc_roc: 0.6749 - val_auc_pr: 0.2936
# Epoch 17/300
# 1/1 - 0s - loss: 374.6333 - acc: 0.1399 - auc_roc: 0.6829 - auc_pr: 0.2808 - val_loss: 92.7226 - val_acc: 0.1400 - val_auc_roc: 0.6768 - val_auc_pr: 0.2938
# Epoch 18/300
# 1/1 - 0s - loss: 370.1003 - acc: 0.1399 - auc_roc: 0.6843 - auc_pr: 0.2838 - val_loss: 91.6148 - val_acc: 0.1400 - val_auc_roc: 0.6790 - val_auc_pr: 0.2954
# Epoch 19/300
# 1/1 - 0s - loss: 365.5362 - acc: 0.1399 - auc_roc: 0.6862 - auc_pr: 0.2868 - val_loss: 90.5331 - val_acc: 0.1400 - val_auc_roc: 0.6812 - val_auc_pr: 0.2985
# Epoch 20/300
# 1/1 - 0s - loss: 361.2397 - acc: 0.1399 - auc_roc: 0.6864 - auc_pr: 0.2878 - val_loss: 89.4865 - val_acc: 0.1400 - val_auc_roc: 0.6812 - val_auc_pr: 0.2993
# Epoch 21/300
# 1/1 - 0s - loss: 357.0477 - acc: 0.1399 - auc_roc: 0.6877 - auc_pr: 0.2906 - val_loss: 88.4852 - val_acc: 0.1400 - val_auc_roc: 0.6834 - val_auc_pr: 0.3012
# Epoch 22/300
# 1/1 - 0s - loss: 353.0058 - acc: 0.1399 - auc_roc: 0.6892 - auc_pr: 0.2912 - val_loss: 87.5390 - val_acc: 0.1400 - val_auc_roc: 0.6825 - val_auc_pr: 0.3016
# Epoch 23/300
# 1/1 - 0s - loss: 349.1590 - acc: 0.1399 - auc_roc: 0.6911 - auc_pr: 0.2934 - val_loss: 86.6567 - val_acc: 0.1400 - val_auc_roc: 0.6848 - val_auc_pr: 0.3033
# Epoch 24/300
# 1/1 - 0s - loss: 345.6904 - acc: 0.1399 - auc_roc: 0.6911 - auc_pr: 0.2953 - val_loss: 85.8499 - val_acc: 0.1400 - val_auc_roc: 0.6833 - val_auc_pr: 0.3038
# Epoch 25/300
# 1/1 - 0s - loss: 342.3468 - acc: 0.1399 - auc_roc: 0.6921 - auc_pr: 0.2973 - val_loss: 85.1270 - val_acc: 0.1400 - val_auc_roc: 0.6859 - val_auc_pr: 0.3051
# Epoch 26/300
# 1/1 - 0s - loss: 339.3736 - acc: 0.1399 - auc_roc: 0.6940 - auc_pr: 0.2988 - val_loss: 84.4912 - val_acc: 0.1400 - val_auc_roc: 0.6861 - val_auc_pr: 0.3064
# Epoch 27/300
# 1/1 - 0s - loss: 336.8146 - acc: 0.1399 - auc_roc: 0.6951 - auc_pr: 0.3010 - val_loss: 83.9490 - val_acc: 0.1400 - val_auc_roc: 0.6877 - val_auc_pr: 0.3074
# Epoch 28/300
# 1/1 - 0s - loss: 334.7580 - acc: 0.1399 - auc_roc: 0.6947 - auc_pr: 0.3008 - val_loss: 83.5026 - val_acc: 0.1400 - val_auc_roc: 0.6875 - val_auc_pr: 0.3089
# Epoch 29/300
# 1/1 - 0s - loss: 332.8439 - acc: 0.1399 - auc_roc: 0.6967 - auc_pr: 0.3032 - val_loss: 83.1556 - val_acc: 0.1400 - val_auc_roc: 0.6889 - val_auc_pr: 0.3092
# Epoch 30/300
# 1/1 - 0s - loss: 331.4213 - acc: 0.1399 - auc_roc: 0.6977 - auc_pr: 0.3053 - val_loss: 82.9053 - val_acc: 0.1400 - val_auc_roc: 0.6875 - val_auc_pr: 0.3087
# Epoch 31/300
# 1/1 - 0s - loss: 330.2793 - acc: 0.1399 - auc_roc: 0.6989 - auc_pr: 0.3066 - val_loss: 82.7451 - val_acc: 0.1400 - val_auc_roc: 0.6901 - val_auc_pr: 0.3117
# Epoch 32/300
# 1/1 - 0s - loss: 329.7020 - acc: 0.1399 - auc_roc: 0.6995 - auc_pr: 0.3075 - val_loss: 82.6646 - val_acc: 0.1400 - val_auc_roc: 0.6898 - val_auc_pr: 0.3113
# Epoch 33/300
# 1/1 - 0s - loss: 329.4761 - acc: 0.1399 - auc_roc: 0.7007 - auc_pr: 0.3083 - val_loss: 82.6493 - val_acc: 0.1400 - val_auc_roc: 0.6920 - val_auc_pr: 0.3137
# Epoch 34/300
# 1/1 - 0s - loss: 329.4683 - acc: 0.1399 - auc_roc: 0.7012 - auc_pr: 0.3098 - val_loss: 82.6776 - val_acc: 0.1400 - val_auc_roc: 0.6926 - val_auc_pr: 0.3131
# Epoch 35/300
# 1/1 - 0s - loss: 329.5725 - acc: 0.1399 - auc_roc: 0.7018 - auc_pr: 0.3108 - val_loss: 82.7294 - val_acc: 0.1400 - val_auc_roc: 0.6920 - val_auc_pr: 0.3146
# Epoch 36/300
# 1/1 - 0s - loss: 329.6346 - acc: 0.1399 - auc_roc: 0.7024 - auc_pr: 0.3135 - val_loss: 82.7839 - val_acc: 0.1400 - val_auc_roc: 0.6931 - val_auc_pr: 0.3157
# Epoch 37/300
# 1/1 - 0s - loss: 329.9747 - acc: 0.1399 - auc_roc: 0.7032 - auc_pr: 0.3122 - val_loss: 82.8238 - val_acc: 0.1400 - val_auc_roc: 0.6938 - val_auc_pr: 0.3161
# Epoch 38/300
# 1/1 - 0s - loss: 330.0607 - acc: 0.1399 - auc_roc: 0.7035 - auc_pr: 0.3138 - val_loss: 82.8393 - val_acc: 0.1400 - val_auc_roc: 0.6938 - val_auc_pr: 0.3159
# Epoch 39/300
# 1/1 - 0s - loss: 330.0751 - acc: 0.1399 - auc_roc: 0.7046 - auc_pr: 0.3153 - val_loss: 82.8262 - val_acc: 0.1400 - val_auc_roc: 0.6938 - val_auc_pr: 0.3167
# Epoch 40/300
# 1/1 - 0s - loss: 330.2550 - acc: 0.1399 - auc_roc: 0.7042 - auc_pr: 0.3136 - val_loss: 82.7824 - val_acc: 0.1400 - val_auc_roc: 0.6942 - val_auc_pr: 0.3175
# Epoch 41/300
# 1/1 - 0s - loss: 329.8232 - acc: 0.1399 - auc_roc: 0.7061 - auc_pr: 0.3154 - val_loss: 82.7119 - val_acc: 0.1400 - val_auc_roc: 0.6957 - val_auc_pr: 0.3173
# Epoch 42/300
# 1/1 - 0s - loss: 329.4035 - acc: 0.1399 - auc_roc: 0.7061 - auc_pr: 0.3186 - val_loss: 82.6185 - val_acc: 0.1400 - val_auc_roc: 0.6956 - val_auc_pr: 0.3186
# Epoch 43/300
# 1/1 - 0s - loss: 328.9892 - acc: 0.1399 - auc_roc: 0.7073 - auc_pr: 0.3191 - val_loss: 82.5085 - val_acc: 0.1400 - val_auc_roc: 0.6957 - val_auc_pr: 0.3197
# Epoch 44/300
# 1/1 - 0s - loss: 328.3694 - acc: 0.1399 - auc_roc: 0.7088 - auc_pr: 0.3207 - val_loss: 82.3941 - val_acc: 0.1400 - val_auc_roc: 0.6972 - val_auc_pr: 0.3203
# Epoch 45/300
# 1/1 - 0s - loss: 327.8482 - acc: 0.1399 - auc_roc: 0.7094 - auc_pr: 0.3214 - val_loss: 82.2865 - val_acc: 0.1400 - val_auc_roc: 0.6977 - val_auc_pr: 0.3216
# Epoch 46/300
# 1/1 - 0s - loss: 327.3291 - acc: 0.1399 - auc_roc: 0.7098 - auc_pr: 0.3234 - val_loss: 82.1941 - val_acc: 0.1400 - val_auc_roc: 0.6981 - val_auc_pr: 0.3214
# Epoch 47/300
# 1/1 - 0s - loss: 326.7629 - acc: 0.1399 - auc_roc: 0.7113 - auc_pr: 0.3262 - val_loss: 82.1249 - val_acc: 0.1400 - val_auc_roc: 0.6988 - val_auc_pr: 0.3228
# Epoch 48/300
# 1/1 - 0s - loss: 326.3925 - acc: 0.1399 - auc_roc: 0.7124 - auc_pr: 0.3258 - val_loss: 82.0800 - val_acc: 0.1400 - val_auc_roc: 0.6992 - val_auc_pr: 0.3229
# Epoch 49/300
# 1/1 - 0s - loss: 326.2457 - acc: 0.1399 - auc_roc: 0.7125 - auc_pr: 0.3263 - val_loss: 82.0528 - val_acc: 0.1400 - val_auc_roc: 0.7000 - val_auc_pr: 0.3251
# Epoch 50/300
# 1/1 - 0s - loss: 325.8635 - acc: 0.1399 - auc_roc: 0.7148 - auc_pr: 0.3295 - val_loss: 82.0401 - val_acc: 0.1400 - val_auc_roc: 0.7020 - val_auc_pr: 0.3262
# Epoch 51/300
# 1/1 - 0s - loss: 325.5075 - acc: 0.1399 - auc_roc: 0.7168 - auc_pr: 0.3326 - val_loss: 82.0337 - val_acc: 0.1400 - val_auc_roc: 0.7028 - val_auc_pr: 0.3285
# Epoch 52/300
# 1/1 - 0s - loss: 325.4868 - acc: 0.1399 - auc_roc: 0.7177 - auc_pr: 0.3337 - val_loss: 82.0264 - val_acc: 0.1400 - val_auc_roc: 0.7030 - val_auc_pr: 0.3276
# Epoch 53/300
# 1/1 - 0s - loss: 325.1873 - acc: 0.1399 - auc_roc: 0.7192 - auc_pr: 0.3369 - val_loss: 82.0092 - val_acc: 0.1400 - val_auc_roc: 0.7041 - val_auc_pr: 0.3300
# Epoch 54/300
# 1/1 - 0s - loss: 324.9626 - acc: 0.1399 - auc_roc: 0.7214 - auc_pr: 0.3389 - val_loss: 81.9747 - val_acc: 0.1400 - val_auc_roc: 0.7046 - val_auc_pr: 0.3304
# Epoch 55/300
# 1/1 - 0s - loss: 324.6620 - acc: 0.1399 - auc_roc: 0.7231 - auc_pr: 0.3404 - val_loss: 81.9182 - val_acc: 0.1400 - val_auc_roc: 0.7065 - val_auc_pr: 0.3317
# Epoch 56/300
# 1/1 - 0s - loss: 324.2135 - acc: 0.1399 - auc_roc: 0.7252 - auc_pr: 0.3446 - val_loss: 81.8415 - val_acc: 0.1400 - val_auc_roc: 0.7069 - val_auc_pr: 0.3335
# Epoch 57/300
# 1/1 - 0s - loss: 323.9637 - acc: 0.1399 - auc_roc: 0.7253 - auc_pr: 0.3452 - val_loss: 81.7519 - val_acc: 0.1400 - val_auc_roc: 0.7083 - val_auc_pr: 0.3352
# Epoch 58/300
# 1/1 - 0s - loss: 323.4352 - acc: 0.1399 - auc_roc: 0.7277 - auc_pr: 0.3481 - val_loss: 81.6550 - val_acc: 0.1400 - val_auc_roc: 0.7096 - val_auc_pr: 0.3349
# Epoch 59/300
# 1/1 - 0s - loss: 322.9909 - acc: 0.1399 - auc_roc: 0.7290 - auc_pr: 0.3505 - val_loss: 81.5554 - val_acc: 0.1400 - val_auc_roc: 0.7110 - val_auc_pr: 0.3382
# Epoch 60/300
# 1/1 - 0s - loss: 322.3481 - acc: 0.1404 - auc_roc: 0.7313 - auc_pr: 0.3543 - val_loss: 81.4581 - val_acc: 0.1400 - val_auc_roc: 0.7119 - val_auc_pr: 0.3370
# Epoch 61/300
# 1/1 - 0s - loss: 321.9590 - acc: 0.1412 - auc_roc: 0.7325 - auc_pr: 0.3551 - val_loss: 81.3635 - val_acc: 0.1400 - val_auc_roc: 0.7131 - val_auc_pr: 0.3401
# Epoch 62/300
# 1/1 - 0s - loss: 321.5848 - acc: 0.1407 - auc_roc: 0.7333 - auc_pr: 0.3569 - val_loss: 81.2719 - val_acc: 0.1400 - val_auc_roc: 0.7144 - val_auc_pr: 0.3413
# Epoch 63/300
# 1/1 - 0s - loss: 320.9510 - acc: 0.1412 - auc_roc: 0.7353 - auc_pr: 0.3594 - val_loss: 81.1844 - val_acc: 0.1400 - val_auc_roc: 0.7151 - val_auc_pr: 0.3421
# Epoch 64/300
# 1/1 - 0s - loss: 320.4777 - acc: 0.1412 - auc_roc: 0.7370 - auc_pr: 0.3618 - val_loss: 81.0975 - val_acc: 0.1400 - val_auc_roc: 0.7159 - val_auc_pr: 0.3443
# Epoch 65/300
# 1/1 - 0s - loss: 319.9345 - acc: 0.1412 - auc_roc: 0.7395 - auc_pr: 0.3663 - val_loss: 81.0085 - val_acc: 0.1400 - val_auc_roc: 0.7180 - val_auc_pr: 0.3465
# Epoch 66/300
# 1/1 - 0s - loss: 319.4037 - acc: 0.1412 - auc_roc: 0.7418 - auc_pr: 0.3694 - val_loss: 80.9215 - val_acc: 0.1400 - val_auc_roc: 0.7192 - val_auc_pr: 0.3492
# Epoch 67/300
# 1/1 - 0s - loss: 318.8859 - acc: 0.1412 - auc_roc: 0.7435 - auc_pr: 0.3725 - val_loss: 80.8375 - val_acc: 0.1411 - val_auc_roc: 0.7198 - val_auc_pr: 0.3511
# Epoch 68/300
# 1/1 - 0s - loss: 318.2184 - acc: 0.1418 - auc_roc: 0.7461 - auc_pr: 0.3765 - val_loss: 80.7554 - val_acc: 0.1411 - val_auc_roc: 0.7206 - val_auc_pr: 0.3540
# Epoch 69/300
# 1/1 - 0s - loss: 317.6783 - acc: 0.1423 - auc_roc: 0.7485 - auc_pr: 0.3796 - val_loss: 80.6782 - val_acc: 0.1411 - val_auc_roc: 0.7220 - val_auc_pr: 0.3561
# Epoch 70/300
# 1/1 - 0s - loss: 317.1040 - acc: 0.1434 - auc_roc: 0.7511 - auc_pr: 0.3834 - val_loss: 80.6045 - val_acc: 0.1411 - val_auc_roc: 0.7231 - val_auc_pr: 0.3593
# Epoch 71/300
# 1/1 - 0s - loss: 316.5514 - acc: 0.1437 - auc_roc: 0.7534 - auc_pr: 0.3874 - val_loss: 80.5297 - val_acc: 0.1411 - val_auc_roc: 0.7254 - val_auc_pr: 0.3613
# Epoch 72/300
# 1/1 - 0s - loss: 315.7164 - acc: 0.1448 - auc_roc: 0.7574 - auc_pr: 0.3922 - val_loss: 80.4500 - val_acc: 0.1422 - val_auc_roc: 0.7266 - val_auc_pr: 0.3645
# Epoch 73/300
# 1/1 - 0s - loss: 315.3823 - acc: 0.1448 - auc_roc: 0.7585 - auc_pr: 0.3977 - val_loss: 80.3581 - val_acc: 0.1433 - val_auc_roc: 0.7288 - val_auc_pr: 0.3679
# Epoch 74/300
# 1/1 - 0s - loss: 314.7522 - acc: 0.1465 - auc_roc: 0.7602 - auc_pr: 0.4020 - val_loss: 80.2508 - val_acc: 0.1455 - val_auc_roc: 0.7283 - val_auc_pr: 0.3674
# Epoch 75/300
# 1/1 - 0s - loss: 314.1395 - acc: 0.1465 - auc_roc: 0.7615 - auc_pr: 0.4044 - val_loss: 80.1337 - val_acc: 0.1455 - val_auc_roc: 0.7301 - val_auc_pr: 0.3717
# Epoch 76/300
# 1/1 - 0s - loss: 313.3079 - acc: 0.1462 - auc_roc: 0.7646 - auc_pr: 0.4067 - val_loss: 80.0121 - val_acc: 0.1455 - val_auc_roc: 0.7307 - val_auc_pr: 0.3724
# Epoch 77/300
# 1/1 - 0s - loss: 312.7837 - acc: 0.1473 - auc_roc: 0.7656 - auc_pr: 0.4111 - val_loss: 79.8912 - val_acc: 0.1455 - val_auc_roc: 0.7316 - val_auc_pr: 0.3743
# Epoch 78/300
# 1/1 - 0s - loss: 312.0964 - acc: 0.1473 - auc_roc: 0.7675 - auc_pr: 0.4132 - val_loss: 79.7742 - val_acc: 0.1466 - val_auc_roc: 0.7316 - val_auc_pr: 0.3751
# Epoch 79/300
# 1/1 - 0s - loss: 311.2715 - acc: 0.1484 - auc_roc: 0.7695 - auc_pr: 0.4173 - val_loss: 79.6635 - val_acc: 0.1466 - val_auc_roc: 0.7332 - val_auc_pr: 0.3756
# Epoch 80/300
# 1/1 - 0s - loss: 310.4463 - acc: 0.1492 - auc_roc: 0.7716 - auc_pr: 0.4199 - val_loss: 79.5603 - val_acc: 0.1477 - val_auc_roc: 0.7339 - val_auc_pr: 0.3783
# Epoch 81/300
# 1/1 - 0s - loss: 309.7780 - acc: 0.1498 - auc_roc: 0.7737 - auc_pr: 0.4235 - val_loss: 79.4643 - val_acc: 0.1488 - val_auc_roc: 0.7342 - val_auc_pr: 0.3808
# Epoch 82/300
# 1/1 - 0s - loss: 308.8916 - acc: 0.1506 - auc_roc: 0.7762 - auc_pr: 0.4280 - val_loss: 79.3766 - val_acc: 0.1488 - val_auc_roc: 0.7351 - val_auc_pr: 0.3830
# Epoch 83/300
# 1/1 - 0s - loss: 308.1986 - acc: 0.1526 - auc_roc: 0.7777 - auc_pr: 0.4315 - val_loss: 79.2988 - val_acc: 0.1510 - val_auc_roc: 0.7355 - val_auc_pr: 0.3837
# Epoch 84/300
# 1/1 - 0s - loss: 307.6129 - acc: 0.1548 - auc_roc: 0.7790 - auc_pr: 0.4356 - val_loss: 79.2259 - val_acc: 0.1544 - val_auc_roc: 0.7356 - val_auc_pr: 0.3851
# Epoch 85/300
# 1/1 - 0s - loss: 306.8587 - acc: 0.1564 - auc_roc: 0.7802 - auc_pr: 0.4372 - val_loss: 79.1510 - val_acc: 0.1566 - val_auc_roc: 0.7354 - val_auc_pr: 0.3872
# Epoch 86/300
# 1/1 - 0s - loss: 305.8484 - acc: 0.1575 - auc_roc: 0.7831 - auc_pr: 0.4452 - val_loss: 79.0698 - val_acc: 0.1588 - val_auc_roc: 0.7360 - val_auc_pr: 0.3886
# Epoch 87/300
# 1/1 - 0s - loss: 305.0576 - acc: 0.1594 - auc_roc: 0.7844 - auc_pr: 0.4465 - val_loss: 78.9835 - val_acc: 0.1632 - val_auc_roc: 0.7351 - val_auc_pr: 0.3887
# Epoch 88/300
# 1/1 - 0s - loss: 304.1829 - acc: 0.1619 - auc_roc: 0.7856 - auc_pr: 0.4493 - val_loss: 78.8944 - val_acc: 0.1643 - val_auc_roc: 0.7360 - val_auc_pr: 0.3915
# Epoch 89/300
# 1/1 - 0s - loss: 303.8744 - acc: 0.1641 - auc_roc: 0.7853 - auc_pr: 0.4500 - val_loss: 78.8052 - val_acc: 0.1676 - val_auc_roc: 0.7379 - val_auc_pr: 0.3943
# Epoch 90/300
# 1/1 - 0s - loss: 303.2170 - acc: 0.1661 - auc_roc: 0.7857 - auc_pr: 0.4514 - val_loss: 78.7233 - val_acc: 0.1676 - val_auc_roc: 0.7371 - val_auc_pr: 0.3908
# Epoch 91/300
# 1/1 - 0s - loss: 302.4944 - acc: 0.1699 - auc_roc: 0.7863 - auc_pr: 0.4558 - val_loss: 78.6506 - val_acc: 0.1720 - val_auc_roc: 0.7377 - val_auc_pr: 0.3937
# Epoch 92/300
# 1/1 - 0s - loss: 301.6921 - acc: 0.1724 - auc_roc: 0.7869 - auc_pr: 0.4573 - val_loss: 78.5871 - val_acc: 0.1731 - val_auc_roc: 0.7370 - val_auc_pr: 0.3955
# Epoch 93/300
# 1/1 - 0s - loss: 301.4509 - acc: 0.1774 - auc_roc: 0.7867 - auc_pr: 0.4584 - val_loss: 78.5310 - val_acc: 0.1753 - val_auc_roc: 0.7378 - val_auc_pr: 0.3973
# Epoch 94/300
# 1/1 - 0s - loss: 300.0754 - acc: 0.1788 - auc_roc: 0.7903 - auc_pr: 0.4624 - val_loss: 78.4856 - val_acc: 0.1819 - val_auc_roc: 0.7381 - val_auc_pr: 0.3974
# Epoch 95/300
# 1/1 - 0s - loss: 298.9483 - acc: 0.1851 - auc_roc: 0.7915 - auc_pr: 0.4671 - val_loss: 78.4451 - val_acc: 0.1852 - val_auc_roc: 0.7384 - val_auc_pr: 0.4001
# Epoch 96/300
# 1/1 - 0s - loss: 298.6832 - acc: 0.1876 - auc_roc: 0.7916 - auc_pr: 0.4681 - val_loss: 78.4040 - val_acc: 0.1896 - val_auc_roc: 0.7389 - val_auc_pr: 0.4022
# Epoch 97/300
# 1/1 - 0s - loss: 298.2475 - acc: 0.1917 - auc_roc: 0.7910 - auc_pr: 0.4691 - val_loss: 78.3487 - val_acc: 0.1929 - val_auc_roc: 0.7399 - val_auc_pr: 0.4031
# Epoch 98/300
# 1/1 - 0s - loss: 297.1815 - acc: 0.1986 - auc_roc: 0.7927 - auc_pr: 0.4706 - val_loss: 78.2955 - val_acc: 0.1963 - val_auc_roc: 0.7406 - val_auc_pr: 0.4061
# Epoch 99/300
# 1/1 - 0s - loss: 296.5695 - acc: 0.2039 - auc_roc: 0.7935 - auc_pr: 0.4742 - val_loss: 78.2415 - val_acc: 0.2029 - val_auc_roc: 0.7405 - val_auc_pr: 0.4064
# Epoch 100/300
# 1/1 - 0s - loss: 295.5013 - acc: 0.2077 - auc_roc: 0.7948 - auc_pr: 0.4772 - val_loss: 78.1896 - val_acc: 0.2095 - val_auc_roc: 0.7414 - val_auc_pr: 0.4082
# Epoch 101/300
# 1/1 - 0s - loss: 294.7817 - acc: 0.2166 - auc_roc: 0.7961 - auc_pr: 0.4805 - val_loss: 78.1363 - val_acc: 0.2150 - val_auc_roc: 0.7418 - val_auc_pr: 0.4086
# Epoch 102/300
# 1/1 - 0s - loss: 294.1031 - acc: 0.2218 - auc_roc: 0.7969 - auc_pr: 0.4828 - val_loss: 78.0850 - val_acc: 0.2249 - val_auc_roc: 0.7423 - val_auc_pr: 0.4085
# Epoch 103/300
# 1/1 - 0s - loss: 293.4169 - acc: 0.2243 - auc_roc: 0.7973 - auc_pr: 0.4820 - val_loss: 78.0380 - val_acc: 0.2326 - val_auc_roc: 0.7430 - val_auc_pr: 0.4115
# Epoch 104/300
# 1/1 - 0s - loss: 292.5830 - acc: 0.2290 - auc_roc: 0.7994 - auc_pr: 0.4861 - val_loss: 77.9890 - val_acc: 0.2381 - val_auc_roc: 0.7438 - val_auc_pr: 0.4126
# Epoch 105/300
# 1/1 - 0s - loss: 291.2664 - acc: 0.2372 - auc_roc: 0.8012 - auc_pr: 0.4878 - val_loss: 77.9473 - val_acc: 0.2426 - val_auc_roc: 0.7441 - val_auc_pr: 0.4141
# Epoch 106/300
# 1/1 - 0s - loss: 291.0747 - acc: 0.2414 - auc_roc: 0.8011 - auc_pr: 0.4906 - val_loss: 77.8901 - val_acc: 0.2481 - val_auc_roc: 0.7454 - val_auc_pr: 0.4139
# Epoch 107/300
# 1/1 - 0s - loss: 290.1100 - acc: 0.2516 - auc_roc: 0.8021 - auc_pr: 0.4914 - val_loss: 77.8249 - val_acc: 0.2514 - val_auc_roc: 0.7462 - val_auc_pr: 0.4137
# Epoch 108/300
# 1/1 - 0s - loss: 289.3953 - acc: 0.2568 - auc_roc: 0.8033 - auc_pr: 0.4934 - val_loss: 77.7558 - val_acc: 0.2569 - val_auc_roc: 0.7472 - val_auc_pr: 0.4155
# Epoch 109/300
# 1/1 - 0s - loss: 288.9452 - acc: 0.2626 - auc_roc: 0.8029 - auc_pr: 0.4930 - val_loss: 77.6923 - val_acc: 0.2646 - val_auc_roc: 0.7481 - val_auc_pr: 0.4128
# Epoch 110/300
# 1/1 - 0s - loss: 287.9020 - acc: 0.2690 - auc_roc: 0.8048 - auc_pr: 0.4990 - val_loss: 77.6349 - val_acc: 0.2701 - val_auc_roc: 0.7488 - val_auc_pr: 0.4129
# Epoch 111/300
# 1/1 - 0s - loss: 287.3520 - acc: 0.2759 - auc_roc: 0.8049 - auc_pr: 0.4972 - val_loss: 77.5978 - val_acc: 0.2789 - val_auc_roc: 0.7496 - val_auc_pr: 0.4168
# Epoch 112/300
# 1/1 - 0s - loss: 286.0513 - acc: 0.2830 - auc_roc: 0.8075 - auc_pr: 0.5006 - val_loss: 77.5789 - val_acc: 0.2900 - val_auc_roc: 0.7500 - val_auc_pr: 0.4160
# Epoch 113/300
# 1/1 - 0s - loss: 286.2086 - acc: 0.2897 - auc_roc: 0.8063 - auc_pr: 0.5005 - val_loss: 77.5491 - val_acc: 0.3021 - val_auc_roc: 0.7508 - val_auc_pr: 0.4178
# Epoch 114/300
# 1/1 - 0s - loss: 284.9696 - acc: 0.2971 - auc_roc: 0.8084 - auc_pr: 0.5014 - val_loss: 77.5155 - val_acc: 0.3131 - val_auc_roc: 0.7509 - val_auc_pr: 0.4176
# Epoch 115/300
# 1/1 - 0s - loss: 284.4341 - acc: 0.3048 - auc_roc: 0.8085 - auc_pr: 0.5046 - val_loss: 77.4614 - val_acc: 0.3153 - val_auc_roc: 0.7526 - val_auc_pr: 0.4199
# Epoch 116/300
# 1/1 - 0s - loss: 283.8162 - acc: 0.3101 - auc_roc: 0.8093 - auc_pr: 0.5034 - val_loss: 77.4047 - val_acc: 0.3197 - val_auc_roc: 0.7531 - val_auc_pr: 0.4207
# Epoch 117/300
# 1/1 - 0s - loss: 282.3733 - acc: 0.3123 - auc_roc: 0.8117 - auc_pr: 0.5055 - val_loss: 77.3732 - val_acc: 0.3264 - val_auc_roc: 0.7532 - val_auc_pr: 0.4220
# Epoch 118/300
# 1/1 - 0s - loss: 281.7375 - acc: 0.3225 - auc_roc: 0.8119 - auc_pr: 0.5078 - val_loss: 77.3532 - val_acc: 0.3396 - val_auc_roc: 0.7543 - val_auc_pr: 0.4225
# Epoch 119/300
# 1/1 - 0s - loss: 280.9914 - acc: 0.3263 - auc_roc: 0.8134 - auc_pr: 0.5088 - val_loss: 77.3202 - val_acc: 0.3484 - val_auc_roc: 0.7552 - val_auc_pr: 0.4247
# Epoch 120/300
# 1/1 - 0s - loss: 280.5656 - acc: 0.3324 - auc_roc: 0.8130 - auc_pr: 0.5053 - val_loss: 77.2683 - val_acc: 0.3528 - val_auc_roc: 0.7553 - val_auc_pr: 0.4247
# Epoch 121/300
# 1/1 - 0s - loss: 280.0731 - acc: 0.3346 - auc_roc: 0.8135 - auc_pr: 0.5081 - val_loss: 77.1998 - val_acc: 0.3572 - val_auc_roc: 0.7562 - val_auc_pr: 0.4261
# Epoch 122/300
# 1/1 - 0s - loss: 279.4473 - acc: 0.3429 - auc_roc: 0.8142 - auc_pr: 0.5104 - val_loss: 77.1182 - val_acc: 0.3594 - val_auc_roc: 0.7567 - val_auc_pr: 0.4264
# Epoch 123/300
# 1/1 - 0s - loss: 278.2262 - acc: 0.3451 - auc_roc: 0.8163 - auc_pr: 0.5118 - val_loss: 77.0999 - val_acc: 0.3660 - val_auc_roc: 0.7579 - val_auc_pr: 0.4289
# Epoch 124/300
# 1/1 - 0s - loss: 278.1586 - acc: 0.3542 - auc_roc: 0.8165 - auc_pr: 0.5123 - val_loss: 77.0800 - val_acc: 0.3693 - val_auc_roc: 0.7585 - val_auc_pr: 0.4293
# Epoch 125/300
# 1/1 - 0s - loss: 276.9257 - acc: 0.3603 - auc_roc: 0.8170 - auc_pr: 0.5128 - val_loss: 77.0474 - val_acc: 0.3705 - val_auc_roc: 0.7590 - val_auc_pr: 0.4300
# Epoch 126/300
# 1/1 - 0s - loss: 276.9224 - acc: 0.3636 - auc_roc: 0.8171 - auc_pr: 0.5145 - val_loss: 76.9711 - val_acc: 0.3705 - val_auc_roc: 0.7597 - val_auc_pr: 0.4316
# Epoch 127/300
# 1/1 - 0s - loss: 276.0442 - acc: 0.3677 - auc_roc: 0.8183 - auc_pr: 0.5163 - val_loss: 76.8834 - val_acc: 0.3749 - val_auc_roc: 0.7607 - val_auc_pr: 0.4311
# Epoch 128/300
# 1/1 - 0s - loss: 275.5289 - acc: 0.3716 - auc_roc: 0.8185 - auc_pr: 0.5161 - val_loss: 76.8455 - val_acc: 0.3859 - val_auc_roc: 0.7615 - val_auc_pr: 0.4323
# Epoch 129/300
# 1/1 - 0s - loss: 275.2946 - acc: 0.3766 - auc_roc: 0.8183 - auc_pr: 0.5163 - val_loss: 76.8074 - val_acc: 0.3903 - val_auc_roc: 0.7620 - val_auc_pr: 0.4332
# Epoch 130/300
# 1/1 - 0s - loss: 274.3414 - acc: 0.3796 - auc_roc: 0.8200 - auc_pr: 0.5152 - val_loss: 76.7415 - val_acc: 0.3936 - val_auc_roc: 0.7624 - val_auc_pr: 0.4321
# Epoch 131/300
# 1/1 - 0s - loss: 273.6335 - acc: 0.3870 - auc_roc: 0.8206 - auc_pr: 0.5197 - val_loss: 76.6817 - val_acc: 0.4002 - val_auc_roc: 0.7637 - val_auc_pr: 0.4346
# Epoch 132/300
# 1/1 - 0s - loss: 272.6864 - acc: 0.3895 - auc_roc: 0.8223 - auc_pr: 0.5188 - val_loss: 76.6203 - val_acc: 0.4057 - val_auc_roc: 0.7642 - val_auc_pr: 0.4351
# Epoch 133/300
# 1/1 - 0s - loss: 273.6003 - acc: 0.3912 - auc_roc: 0.8197 - auc_pr: 0.5185 - val_loss: 76.5368 - val_acc: 0.4068 - val_auc_roc: 0.7652 - val_auc_pr: 0.4406
# Epoch 134/300
# 1/1 - 0s - loss: 272.6753 - acc: 0.3948 - auc_roc: 0.8212 - auc_pr: 0.5215 - val_loss: 76.5100 - val_acc: 0.4090 - val_auc_roc: 0.7658 - val_auc_pr: 0.4414
# Epoch 135/300
# 1/1 - 0s - loss: 271.3816 - acc: 0.3948 - auc_roc: 0.8240 - auc_pr: 0.5231 - val_loss: 76.5820 - val_acc: 0.4135 - val_auc_roc: 0.7656 - val_auc_pr: 0.4415
# Epoch 136/300
# 1/1 - 0s - loss: 271.8598 - acc: 0.4069 - auc_roc: 0.8218 - auc_pr: 0.5208 - val_loss: 76.5229 - val_acc: 0.4157 - val_auc_roc: 0.7663 - val_auc_pr: 0.4403
# Epoch 137/300
# 1/1 - 0s - loss: 270.1126 - acc: 0.4086 - auc_roc: 0.8252 - auc_pr: 0.5264 - val_loss: 76.4237 - val_acc: 0.4135 - val_auc_roc: 0.7674 - val_auc_pr: 0.4447
# Epoch 138/300
# 1/1 - 0s - loss: 269.7490 - acc: 0.4074 - auc_roc: 0.8251 - auc_pr: 0.5211 - val_loss: 76.3918 - val_acc: 0.4146 - val_auc_roc: 0.7682 - val_auc_pr: 0.4461
# Epoch 139/300
# 1/1 - 0s - loss: 269.1141 - acc: 0.4138 - auc_roc: 0.8265 - auc_pr: 0.5244 - val_loss: 76.4222 - val_acc: 0.4157 - val_auc_roc: 0.7689 - val_auc_pr: 0.4474
# Epoch 140/300
# 1/1 - 0s - loss: 269.5486 - acc: 0.4185 - auc_roc: 0.8255 - auc_pr: 0.5240 - val_loss: 76.4026 - val_acc: 0.4157 - val_auc_roc: 0.7697 - val_auc_pr: 0.4504
# Epoch 141/300
# 1/1 - 0s - loss: 268.5962 - acc: 0.4221 - auc_roc: 0.8261 - auc_pr: 0.5277 - val_loss: 76.3172 - val_acc: 0.4157 - val_auc_roc: 0.7707 - val_auc_pr: 0.4522
# Epoch 142/300
# 1/1 - 0s - loss: 268.1650 - acc: 0.4254 - auc_roc: 0.8268 - auc_pr: 0.5246 - val_loss: 76.1833 - val_acc: 0.4146 - val_auc_roc: 0.7715 - val_auc_pr: 0.4535
# Epoch 143/300
# 1/1 - 0s - loss: 267.3892 - acc: 0.4182 - auc_roc: 0.8288 - auc_pr: 0.5270 - val_loss: 76.2256 - val_acc: 0.4201 - val_auc_roc: 0.7719 - val_auc_pr: 0.4540
# Epoch 144/300
# 1/1 - 0s - loss: 266.8245 - acc: 0.4234 - auc_roc: 0.8306 - auc_pr: 0.5328 - val_loss: 76.2964 - val_acc: 0.4256 - val_auc_roc: 0.7723 - val_auc_pr: 0.4544
# Epoch 145/300
# 1/1 - 0s - loss: 267.4433 - acc: 0.4337 - auc_roc: 0.8284 - auc_pr: 0.5299 - val_loss: 76.2121 - val_acc: 0.4256 - val_auc_roc: 0.7730 - val_auc_pr: 0.4566
# Epoch 146/300
# 1/1 - 0s - loss: 266.8333 - acc: 0.4326 - auc_roc: 0.8291 - auc_pr: 0.5302 - val_loss: 76.0735 - val_acc: 0.4234 - val_auc_roc: 0.7736 - val_auc_pr: 0.4560
# Epoch 147/300
# 1/1 - 0s - loss: 265.3392 - acc: 0.4320 - auc_roc: 0.8311 - auc_pr: 0.5316 - val_loss: 76.0419 - val_acc: 0.4245 - val_auc_roc: 0.7743 - val_auc_pr: 0.4587
# Epoch 148/300
# 1/1 - 0s - loss: 265.2494 - acc: 0.4345 - auc_roc: 0.8317 - auc_pr: 0.5341 - val_loss: 76.0846 - val_acc: 0.4311 - val_auc_roc: 0.7748 - val_auc_pr: 0.4583
# Epoch 149/300
# 1/1 - 0s - loss: 265.1640 - acc: 0.4414 - auc_roc: 0.8317 - auc_pr: 0.5323 - val_loss: 76.0987 - val_acc: 0.4366 - val_auc_roc: 0.7749 - val_auc_pr: 0.4593
# Epoch 150/300
# 1/1 - 0s - loss: 264.6084 - acc: 0.4444 - auc_roc: 0.8321 - auc_pr: 0.5345 - val_loss: 76.0017 - val_acc: 0.4377 - val_auc_roc: 0.7758 - val_auc_pr: 0.4604
# Epoch 151/300
# 1/1 - 0s - loss: 264.5308 - acc: 0.4439 - auc_roc: 0.8316 - auc_pr: 0.5329 - val_loss: 75.8723 - val_acc: 0.4344 - val_auc_roc: 0.7763 - val_auc_pr: 0.4549
# Epoch 152/300
# 1/1 - 0s - loss: 264.2778 - acc: 0.4381 - auc_roc: 0.8319 - auc_pr: 0.5326 - val_loss: 75.9101 - val_acc: 0.4377 - val_auc_roc: 0.7768 - val_auc_pr: 0.4552
# Epoch 153/300
# 1/1 - 0s - loss: 263.5642 - acc: 0.4406 - auc_roc: 0.8330 - auc_pr: 0.5359 - val_loss: 76.0461 - val_acc: 0.4443 - val_auc_roc: 0.7766 - val_auc_pr: 0.4560
# Epoch 154/300
# 1/1 - 0s - loss: 263.1750 - acc: 0.4546 - auc_roc: 0.8335 - auc_pr: 0.5370 - val_loss: 76.0574 - val_acc: 0.4454 - val_auc_roc: 0.7775 - val_auc_pr: 0.4586
# Epoch 155/300
# 1/1 - 0s - loss: 263.4966 - acc: 0.4552 - auc_roc: 0.8325 - auc_pr: 0.5347 - val_loss: 75.8603 - val_acc: 0.4432 - val_auc_roc: 0.7782 - val_auc_pr: 0.4572
# Epoch 156/300
# 1/1 - 0s - loss: 262.0516 - acc: 0.4502 - auc_roc: 0.8356 - auc_pr: 0.5364 - val_loss: 75.8184 - val_acc: 0.4421 - val_auc_roc: 0.7784 - val_auc_pr: 0.4591
# Epoch 157/300
# 1/1 - 0s - loss: 261.8310 - acc: 0.4502 - auc_roc: 0.8355 - auc_pr: 0.5363 - val_loss: 75.9752 - val_acc: 0.4498 - val_auc_roc: 0.7787 - val_auc_pr: 0.4592
# Epoch 158/300
# 1/1 - 0s - loss: 261.8756 - acc: 0.4524 - auc_roc: 0.8348 - auc_pr: 0.5369 - val_loss: 76.0966 - val_acc: 0.4542 - val_auc_roc: 0.7786 - val_auc_pr: 0.4596
# Epoch 159/300
# 1/1 - 0s - loss: 261.4475 - acc: 0.4621 - auc_roc: 0.8351 - auc_pr: 0.5379 - val_loss: 76.0329 - val_acc: 0.4531 - val_auc_roc: 0.7794 - val_auc_pr: 0.4618
# Epoch 160/300
# 1/1 - 0s - loss: 260.9439 - acc: 0.4585 - auc_roc: 0.8362 - auc_pr: 0.5405 - val_loss: 75.9346 - val_acc: 0.4509 - val_auc_roc: 0.7800 - val_auc_pr: 0.4639
# Epoch 161/300
# 1/1 - 0s - loss: 260.4523 - acc: 0.4582 - auc_roc: 0.8362 - auc_pr: 0.5371 - val_loss: 75.9267 - val_acc: 0.4520 - val_auc_roc: 0.7804 - val_auc_pr: 0.4645
# Epoch 162/300
# 1/1 - 0s - loss: 259.4211 - acc: 0.4590 - auc_roc: 0.8380 - auc_pr: 0.5404 - val_loss: 75.9848 - val_acc: 0.4531 - val_auc_roc: 0.7805 - val_auc_pr: 0.4641
# Epoch 163/300
# 1/1 - 0s - loss: 259.5094 - acc: 0.4601 - auc_roc: 0.8379 - auc_pr: 0.5422 - val_loss: 76.1924 - val_acc: 0.4587 - val_auc_roc: 0.7803 - val_auc_pr: 0.4649
# Epoch 164/300
# 1/1 - 0s - loss: 259.0758 - acc: 0.4720 - auc_roc: 0.8388 - auc_pr: 0.5426 - val_loss: 76.2488 - val_acc: 0.4598 - val_auc_roc: 0.7806 - val_auc_pr: 0.4653
# Epoch 165/300
# 1/1 - 0s - loss: 259.7738 - acc: 0.4670 - auc_roc: 0.8371 - auc_pr: 0.5391 - val_loss: 76.1262 - val_acc: 0.4587 - val_auc_roc: 0.7810 - val_auc_pr: 0.4671
# Epoch 166/300
# 1/1 - 0s - loss: 259.1058 - acc: 0.4621 - auc_roc: 0.8378 - auc_pr: 0.5415 - val_loss: 76.1087 - val_acc: 0.4598 - val_auc_roc: 0.7810 - val_auc_pr: 0.4675
# Epoch 167/300
# 1/1 - 0s - loss: 258.3315 - acc: 0.4659 - auc_roc: 0.8394 - auc_pr: 0.5418 - val_loss: 76.2269 - val_acc: 0.4631 - val_auc_roc: 0.7812 - val_auc_pr: 0.4671
# Epoch 168/300
# 1/1 - 0s - loss: 258.2364 - acc: 0.4662 - auc_roc: 0.8391 - auc_pr: 0.5442 - val_loss: 76.4011 - val_acc: 0.4686 - val_auc_roc: 0.7812 - val_auc_pr: 0.4663
# Epoch 169/300
# 1/1 - 0s - loss: 257.2024 - acc: 0.4742 - auc_roc: 0.8409 - auc_pr: 0.5436 - val_loss: 76.4842 - val_acc: 0.4730 - val_auc_roc: 0.7810 - val_auc_pr: 0.4664
# Epoch 170/300
# 1/1 - 0s - loss: 257.4527 - acc: 0.4817 - auc_roc: 0.8398 - auc_pr: 0.5433 - val_loss: 76.3088 - val_acc: 0.4697 - val_auc_roc: 0.7821 - val_auc_pr: 0.4687
# Epoch 171/300
# 1/1 - 0s - loss: 257.1226 - acc: 0.4759 - auc_roc: 0.8414 - auc_pr: 0.5451 - val_loss: 76.1568 - val_acc: 0.4675 - val_auc_roc: 0.7826 - val_auc_pr: 0.4701
# Epoch 172/300
# 1/1 - 0s - loss: 257.3025 - acc: 0.4673 - auc_roc: 0.8403 - auc_pr: 0.5457 - val_loss: 76.3057 - val_acc: 0.4763 - val_auc_roc: 0.7827 - val_auc_pr: 0.4688
# Epoch 173/300
# 1/1 - 0s - loss: 256.8944 - acc: 0.4759 - auc_roc: 0.8408 - auc_pr: 0.5439 - val_loss: 76.6057 - val_acc: 0.4818 - val_auc_roc: 0.7823 - val_auc_pr: 0.4678
# Epoch 174/300
# 1/1 - 0s - loss: 256.4991 - acc: 0.4919 - auc_roc: 0.8414 - auc_pr: 0.5461 - val_loss: 76.5806 - val_acc: 0.4807 - val_auc_roc: 0.7827 - val_auc_pr: 0.4703
# Epoch 175/300
# 1/1 - 0s - loss: 256.1416 - acc: 0.4858 - auc_roc: 0.8418 - auc_pr: 0.5458 - val_loss: 76.2844 - val_acc: 0.4763 - val_auc_roc: 0.7836 - val_auc_pr: 0.4722
# Epoch 176/300
# 1/1 - 0s - loss: 255.0646 - acc: 0.4770 - auc_roc: 0.8431 - auc_pr: 0.5468 - val_loss: 76.2359 - val_acc: 0.4752 - val_auc_roc: 0.7841 - val_auc_pr: 0.4720
# Epoch 177/300
# 1/1 - 0s - loss: 255.9550 - acc: 0.4745 - auc_roc: 0.8424 - auc_pr: 0.5447 - val_loss: 76.4352 - val_acc: 0.4818 - val_auc_roc: 0.7839 - val_auc_pr: 0.4735
# Epoch 178/300
# 1/1 - 0s - loss: 254.4783 - acc: 0.4855 - auc_roc: 0.8441 - auc_pr: 0.5479 - val_loss: 76.7736 - val_acc: 0.4862 - val_auc_roc: 0.7831 - val_auc_pr: 0.4701
# Epoch 179/300
# 1/1 - 0s - loss: 254.8375 - acc: 0.4935 - auc_roc: 0.8438 - auc_pr: 0.5487 - val_loss: 76.7010 - val_acc: 0.4840 - val_auc_roc: 0.7837 - val_auc_pr: 0.4720
# Epoch 180/300
# 1/1 - 0s - loss: 253.9072 - acc: 0.4924 - auc_roc: 0.8451 - auc_pr: 0.5501 - val_loss: 76.5203 - val_acc: 0.4818 - val_auc_roc: 0.7842 - val_auc_pr: 0.4741
# Epoch 181/300
# 1/1 - 0s - loss: 254.2832 - acc: 0.4833 - auc_roc: 0.8438 - auc_pr: 0.5455 - val_loss: 76.5309 - val_acc: 0.4829 - val_auc_roc: 0.7840 - val_auc_pr: 0.4729
# Epoch 182/300
# 1/1 - 0s - loss: 252.8407 - acc: 0.4839 - auc_roc: 0.8464 - auc_pr: 0.5496 - val_loss: 76.8052 - val_acc: 0.4895 - val_auc_roc: 0.7839 - val_auc_pr: 0.4722
# Epoch 183/300
# 1/1 - 0s - loss: 253.6855 - acc: 0.4943 - auc_roc: 0.8444 - auc_pr: 0.5462 - val_loss: 76.9435 - val_acc: 0.4972 - val_auc_roc: 0.7841 - val_auc_pr: 0.4724
# Epoch 184/300
# 1/1 - 0s - loss: 254.2574 - acc: 0.4985 - auc_roc: 0.8439 - auc_pr: 0.5486 - val_loss: 76.8090 - val_acc: 0.4906 - val_auc_roc: 0.7845 - val_auc_pr: 0.4738
# Epoch 185/300
# 1/1 - 0s - loss: 253.8396 - acc: 0.4916 - auc_roc: 0.8444 - auc_pr: 0.5473 - val_loss: 76.6742 - val_acc: 0.4873 - val_auc_roc: 0.7849 - val_auc_pr: 0.4738
# Epoch 186/300
# 1/1 - 0s - loss: 253.7428 - acc: 0.4872 - auc_roc: 0.8442 - auc_pr: 0.5459 - val_loss: 76.7884 - val_acc: 0.4895 - val_auc_roc: 0.7846 - val_auc_pr: 0.4733
# Epoch 187/300
# 1/1 - 0s - loss: 252.9076 - acc: 0.4946 - auc_roc: 0.8457 - auc_pr: 0.5465 - val_loss: 77.0264 - val_acc: 0.4994 - val_auc_roc: 0.7848 - val_auc_pr: 0.4746
# Epoch 188/300
# 1/1 - 0s - loss: 252.4377 - acc: 0.4982 - auc_roc: 0.8465 - auc_pr: 0.5476 - val_loss: 77.1079 - val_acc: 0.5028 - val_auc_roc: 0.7850 - val_auc_pr: 0.4755
# Epoch 189/300
# 1/1 - 0s - loss: 252.5118 - acc: 0.5001 - auc_roc: 0.8454 - auc_pr: 0.5496 - val_loss: 77.0160 - val_acc: 0.5006 - val_auc_roc: 0.7852 - val_auc_pr: 0.4725
# Epoch 190/300
# 1/1 - 0s - loss: 251.4480 - acc: 0.4966 - auc_roc: 0.8476 - auc_pr: 0.5487 - val_loss: 76.9539 - val_acc: 0.4961 - val_auc_roc: 0.7858 - val_auc_pr: 0.4759
# Epoch 191/300
# 1/1 - 0s - loss: 251.5880 - acc: 0.4990 - auc_roc: 0.8472 - auc_pr: 0.5492 - val_loss: 77.1115 - val_acc: 0.5006 - val_auc_roc: 0.7858 - val_auc_pr: 0.4755
# Epoch 192/300
# 1/1 - 0s - loss: 251.8015 - acc: 0.5010 - auc_roc: 0.8469 - auc_pr: 0.5515 - val_loss: 77.3215 - val_acc: 0.5050 - val_auc_roc: 0.7854 - val_auc_pr: 0.4739
# Epoch 193/300
# 1/1 - 0s - loss: 251.3015 - acc: 0.5043 - auc_roc: 0.8475 - auc_pr: 0.5502 - val_loss: 77.4031 - val_acc: 0.5061 - val_auc_roc: 0.7858 - val_auc_pr: 0.4752
# Epoch 194/300
# 1/1 - 0s - loss: 250.7726 - acc: 0.5065 - auc_roc: 0.8485 - auc_pr: 0.5528 - val_loss: 77.3890 - val_acc: 0.5017 - val_auc_roc: 0.7859 - val_auc_pr: 0.4767
# Epoch 195/300
# 1/1 - 0s - loss: 250.1919 - acc: 0.5034 - auc_roc: 0.8492 - auc_pr: 0.5526 - val_loss: 77.3970 - val_acc: 0.5017 - val_auc_roc: 0.7859 - val_auc_pr: 0.4751
# Epoch 196/300
# 1/1 - 0s - loss: 251.5873 - acc: 0.5037 - auc_roc: 0.8473 - auc_pr: 0.5507 - val_loss: 77.4985 - val_acc: 0.5017 - val_auc_roc: 0.7858 - val_auc_pr: 0.4752
# Epoch 197/300
# 1/1 - 0s - loss: 250.3513 - acc: 0.4996 - auc_roc: 0.8488 - auc_pr: 0.5537 - val_loss: 77.8152 - val_acc: 0.5083 - val_auc_roc: 0.7860 - val_auc_pr: 0.4770
# Epoch 198/300
# 1/1 - 0s - loss: 250.7182 - acc: 0.5145 - auc_roc: 0.8480 - auc_pr: 0.5529 - val_loss: 77.8186 - val_acc: 0.5050 - val_auc_roc: 0.7864 - val_auc_pr: 0.4779
# Epoch 199/300
# 1/1 - 0s - loss: 249.3750 - acc: 0.5101 - auc_roc: 0.8499 - auc_pr: 0.5547 - val_loss: 77.7823 - val_acc: 0.5039 - val_auc_roc: 0.7863 - val_auc_pr: 0.4778
# Epoch 200/300
# 1/1 - 0s - loss: 250.0114 - acc: 0.5076 - auc_roc: 0.8492 - auc_pr: 0.5549 - val_loss: 77.8116 - val_acc: 0.5017 - val_auc_roc: 0.7867 - val_auc_pr: 0.4786
# Epoch 201/300
# 1/1 - 0s - loss: 249.6284 - acc: 0.5081 - auc_roc: 0.8494 - auc_pr: 0.5538 - val_loss: 77.9911 - val_acc: 0.5061 - val_auc_roc: 0.7866 - val_auc_pr: 0.4787
# Epoch 202/300
# 1/1 - 0s - loss: 249.0807 - acc: 0.5103 - auc_roc: 0.8495 - auc_pr: 0.5528 - val_loss: 78.0670 - val_acc: 0.5061 - val_auc_roc: 0.7868 - val_auc_pr: 0.4793
# Epoch 203/300
# 1/1 - 0s - loss: 250.8316 - acc: 0.5128 - auc_roc: 0.8476 - auc_pr: 0.5505 - val_loss: 77.9596 - val_acc: 0.5017 - val_auc_roc: 0.7869 - val_auc_pr: 0.4795
# Epoch 204/300
# 1/1 - 0s - loss: 248.7400 - acc: 0.5026 - auc_roc: 0.8504 - auc_pr: 0.5556 - val_loss: 78.2772 - val_acc: 0.5083 - val_auc_roc: 0.7866 - val_auc_pr: 0.4804
# Epoch 205/300
# 1/1 - 0s - loss: 249.7760 - acc: 0.5112 - auc_roc: 0.8487 - auc_pr: 0.5499 - val_loss: 78.5057 - val_acc: 0.5105 - val_auc_roc: 0.7869 - val_auc_pr: 0.4810
# Epoch 206/300
# 1/1 - 0s - loss: 248.1665 - acc: 0.5150 - auc_roc: 0.8516 - auc_pr: 0.5579 - val_loss: 78.5685 - val_acc: 0.5116 - val_auc_roc: 0.7867 - val_auc_pr: 0.4809
# Epoch 207/300
# 1/1 - 0s - loss: 247.4388 - acc: 0.5178 - auc_roc: 0.8516 - auc_pr: 0.5543 - val_loss: 78.3837 - val_acc: 0.5050 - val_auc_roc: 0.7869 - val_auc_pr: 0.4799
# Epoch 208/300
# 1/1 - 0s - loss: 247.5370 - acc: 0.5178 - auc_roc: 0.8532 - auc_pr: 0.5577 - val_loss: 78.5804 - val_acc: 0.5083 - val_auc_roc: 0.7870 - val_auc_pr: 0.4810
# Epoch 209/300
# 1/1 - 0s - loss: 248.6685 - acc: 0.5126 - auc_roc: 0.8509 - auc_pr: 0.5576 - val_loss: 78.9557 - val_acc: 0.5248 - val_auc_roc: 0.7869 - val_auc_pr: 0.4833
# Epoch 210/300
# 1/1 - 0s - loss: 248.4889 - acc: 0.5239 - auc_roc: 0.8515 - auc_pr: 0.5572 - val_loss: 78.9636 - val_acc: 0.5226 - val_auc_roc: 0.7868 - val_auc_pr: 0.4825
# Epoch 211/300
# 1/1 - 0s - loss: 247.2295 - acc: 0.5263 - auc_roc: 0.8524 - auc_pr: 0.5560 - val_loss: 78.7309 - val_acc: 0.5116 - val_auc_roc: 0.7872 - val_auc_pr: 0.4821
# Epoch 212/300
# 1/1 - 0s - loss: 246.5668 - acc: 0.5142 - auc_roc: 0.8527 - auc_pr: 0.5567 - val_loss: 78.7698 - val_acc: 0.5127 - val_auc_roc: 0.7874 - val_auc_pr: 0.4823
# Epoch 213/300
# 1/1 - 0s - loss: 246.7625 - acc: 0.5206 - auc_roc: 0.8529 - auc_pr: 0.5586 - val_loss: 78.8819 - val_acc: 0.5171 - val_auc_roc: 0.7875 - val_auc_pr: 0.4817
# Epoch 214/300
# 1/1 - 0s - loss: 245.6336 - acc: 0.5214 - auc_roc: 0.8542 - auc_pr: 0.5573 - val_loss: 79.1095 - val_acc: 0.5237 - val_auc_roc: 0.7878 - val_auc_pr: 0.4846
# Epoch 215/300
# 1/1 - 0s - loss: 244.5833 - acc: 0.5255 - auc_roc: 0.8556 - auc_pr: 0.5622 - val_loss: 79.1241 - val_acc: 0.5226 - val_auc_roc: 0.7876 - val_auc_pr: 0.4823
# Epoch 216/300
# 1/1 - 0s - loss: 245.0887 - acc: 0.5272 - auc_roc: 0.8550 - auc_pr: 0.5589 - val_loss: 79.0551 - val_acc: 0.5215 - val_auc_roc: 0.7878 - val_auc_pr: 0.4827
# Epoch 217/300
# 1/1 - 0s - loss: 244.7192 - acc: 0.5250 - auc_roc: 0.8554 - auc_pr: 0.5606 - val_loss: 79.0406 - val_acc: 0.5182 - val_auc_roc: 0.7880 - val_auc_pr: 0.4836
# Epoch 218/300
# 1/1 - 0s - loss: 244.1861 - acc: 0.5170 - auc_roc: 0.8566 - auc_pr: 0.5596 - val_loss: 79.4603 - val_acc: 0.5292 - val_auc_roc: 0.7877 - val_auc_pr: 0.4844
# Epoch 219/300
# 1/1 - 0s - loss: 245.1864 - acc: 0.5330 - auc_roc: 0.8546 - auc_pr: 0.5608 - val_loss: 79.4443 - val_acc: 0.5270 - val_auc_roc: 0.7878 - val_auc_pr: 0.4833
# Epoch 220/300
# 1/1 - 0s - loss: 243.8970 - acc: 0.5308 - auc_roc: 0.8564 - auc_pr: 0.5621 - val_loss: 79.3899 - val_acc: 0.5248 - val_auc_roc: 0.7887 - val_auc_pr: 0.4863
# Epoch 221/300
# 1/1 - 0s - loss: 244.5457 - acc: 0.5297 - auc_roc: 0.8556 - auc_pr: 0.5593 - val_loss: 79.4795 - val_acc: 0.5248 - val_auc_roc: 0.7882 - val_auc_pr: 0.4857
# Epoch 222/300
# 1/1 - 0s - loss: 243.9431 - acc: 0.5266 - auc_roc: 0.8562 - auc_pr: 0.5625 - val_loss: 79.6128 - val_acc: 0.5259 - val_auc_roc: 0.7880 - val_auc_pr: 0.4862
# Epoch 223/300
# 1/1 - 0s - loss: 244.7613 - acc: 0.5280 - auc_roc: 0.8554 - auc_pr: 0.5611 - val_loss: 79.8599 - val_acc: 0.5314 - val_auc_roc: 0.7879 - val_auc_pr: 0.4855
# Epoch 224/300
# 1/1 - 0s - loss: 244.1127 - acc: 0.5335 - auc_roc: 0.8556 - auc_pr: 0.5613 - val_loss: 79.7277 - val_acc: 0.5259 - val_auc_roc: 0.7883 - val_auc_pr: 0.4862
# Epoch 225/300
# 1/1 - 0s - loss: 244.1288 - acc: 0.5299 - auc_roc: 0.8565 - auc_pr: 0.5641 - val_loss: 79.6548 - val_acc: 0.5237 - val_auc_roc: 0.7886 - val_auc_pr: 0.4856
# Epoch 226/300
# 1/1 - 0s - loss: 243.3702 - acc: 0.5277 - auc_roc: 0.8567 - auc_pr: 0.5609 - val_loss: 79.8602 - val_acc: 0.5292 - val_auc_roc: 0.7887 - val_auc_pr: 0.4869
# Epoch 227/300
# 1/1 - 0s - loss: 242.2250 - acc: 0.5330 - auc_roc: 0.8586 - auc_pr: 0.5608 - val_loss: 79.9895 - val_acc: 0.5369 - val_auc_roc: 0.7889 - val_auc_pr: 0.4852
# Epoch 228/300
# 1/1 - 0s - loss: 242.3967 - acc: 0.5352 - auc_roc: 0.8580 - auc_pr: 0.5627 - val_loss: 80.0144 - val_acc: 0.5369 - val_auc_roc: 0.7890 - val_auc_pr: 0.4854
# Epoch 229/300
# 1/1 - 0s - loss: 242.0825 - acc: 0.5379 - auc_roc: 0.8588 - auc_pr: 0.5659 - val_loss: 80.0085 - val_acc: 0.5358 - val_auc_roc: 0.7895 - val_auc_pr: 0.4874
# Epoch 230/300
# 1/1 - 0s - loss: 242.9817 - acc: 0.5316 - auc_roc: 0.8573 - auc_pr: 0.5610 - val_loss: 80.0816 - val_acc: 0.5347 - val_auc_roc: 0.7892 - val_auc_pr: 0.4868
# Epoch 231/300
# 1/1 - 0s - loss: 241.9515 - acc: 0.5366 - auc_roc: 0.8589 - auc_pr: 0.5601 - val_loss: 80.2128 - val_acc: 0.5369 - val_auc_roc: 0.7892 - val_auc_pr: 0.4869
# Epoch 232/300
# 1/1 - 0s - loss: 242.3930 - acc: 0.5407 - auc_roc: 0.8585 - auc_pr: 0.5629 - val_loss: 80.1355 - val_acc: 0.5325 - val_auc_roc: 0.7894 - val_auc_pr: 0.4866
# Epoch 233/300
# 1/1 - 0s - loss: 241.2509 - acc: 0.5335 - auc_roc: 0.8591 - auc_pr: 0.5639 - val_loss: 80.4946 - val_acc: 0.5380 - val_auc_roc: 0.7890 - val_auc_pr: 0.4854
# Epoch 234/300
# 1/1 - 0s - loss: 240.5448 - acc: 0.5446 - auc_roc: 0.8600 - auc_pr: 0.5636 - val_loss: 80.7232 - val_acc: 0.5424 - val_auc_roc: 0.7888 - val_auc_pr: 0.4863
# Epoch 235/300
# 1/1 - 0s - loss: 240.9198 - acc: 0.5492 - auc_roc: 0.8599 - auc_pr: 0.5638 - val_loss: 80.5656 - val_acc: 0.5369 - val_auc_roc: 0.7890 - val_auc_pr: 0.4862
# Epoch 236/300
# 1/1 - 0s - loss: 241.0831 - acc: 0.5457 - auc_roc: 0.8598 - auc_pr: 0.5628 - val_loss: 80.3112 - val_acc: 0.5292 - val_auc_roc: 0.7890 - val_auc_pr: 0.4850
# Epoch 237/300
# 1/1 - 0s - loss: 241.2853 - acc: 0.5330 - auc_roc: 0.8598 - auc_pr: 0.5618 - val_loss: 80.6209 - val_acc: 0.5336 - val_auc_roc: 0.7890 - val_auc_pr: 0.4862
# Epoch 238/300
# 1/1 - 0s - loss: 240.0306 - acc: 0.5385 - auc_roc: 0.8604 - auc_pr: 0.5646 - val_loss: 81.1182 - val_acc: 0.5469 - val_auc_roc: 0.7891 - val_auc_pr: 0.4871
# Epoch 239/300
# 1/1 - 0s - loss: 242.1339 - acc: 0.5501 - auc_roc: 0.8582 - auc_pr: 0.5631 - val_loss: 80.6510 - val_acc: 0.5336 - val_auc_roc: 0.7893 - val_auc_pr: 0.4871
# Epoch 240/300
# 1/1 - 0s - loss: 241.5367 - acc: 0.5437 - auc_roc: 0.8586 - auc_pr: 0.5619 - val_loss: 80.1679 - val_acc: 0.5193 - val_auc_roc: 0.7897 - val_auc_pr: 0.4863
# Epoch 241/300
# 1/1 - 0s - loss: 239.5544 - acc: 0.5261 - auc_roc: 0.8627 - auc_pr: 0.5652 - val_loss: 81.0321 - val_acc: 0.5413 - val_auc_roc: 0.7894 - val_auc_pr: 0.4874
# Epoch 242/300
# 1/1 - 0s - loss: 238.7267 - acc: 0.5473 - auc_roc: 0.8624 - auc_pr: 0.5659 - val_loss: 81.8293 - val_acc: 0.5579 - val_auc_roc: 0.7891 - val_auc_pr: 0.4883
# Epoch 243/300
# 1/1 - 0s - loss: 240.6164 - acc: 0.5647 - auc_roc: 0.8602 - auc_pr: 0.5665 - val_loss: 80.8628 - val_acc: 0.5380 - val_auc_roc: 0.7896 - val_auc_pr: 0.4856
# Epoch 244/300
# 1/1 - 0s - loss: 239.0312 - acc: 0.5426 - auc_roc: 0.8620 - auc_pr: 0.5657 - val_loss: 80.3228 - val_acc: 0.5204 - val_auc_roc: 0.7901 - val_auc_pr: 0.4874
# Epoch 245/300
# 1/1 - 0s - loss: 240.6587 - acc: 0.5233 - auc_roc: 0.8607 - auc_pr: 0.5639 - val_loss: 80.9094 - val_acc: 0.5369 - val_auc_roc: 0.7898 - val_auc_pr: 0.4876
# Epoch 246/300
# 1/1 - 0s - loss: 239.2601 - acc: 0.5440 - auc_roc: 0.8616 - auc_pr: 0.5664 - val_loss: 81.8290 - val_acc: 0.5546 - val_auc_roc: 0.7889 - val_auc_pr: 0.4861
# Epoch 247/300
# 1/1 - 0s - loss: 240.1370 - acc: 0.5586 - auc_roc: 0.8602 - auc_pr: 0.5648 - val_loss: 81.4666 - val_acc: 0.5480 - val_auc_roc: 0.7894 - val_auc_pr: 0.4860
# Epoch 248/300
# 1/1 - 0s - loss: 238.3139 - acc: 0.5531 - auc_roc: 0.8630 - auc_pr: 0.5665 - val_loss: 81.0466 - val_acc: 0.5380 - val_auc_roc: 0.7898 - val_auc_pr: 0.4871
# Epoch 249/300
# 1/1 - 0s - loss: 237.7767 - acc: 0.5446 - auc_roc: 0.8635 - auc_pr: 0.5680 - val_loss: 81.1420 - val_acc: 0.5380 - val_auc_roc: 0.7896 - val_auc_pr: 0.4873
# Epoch 250/300
# 1/1 - 0s - loss: 237.7656 - acc: 0.5423 - auc_roc: 0.8632 - auc_pr: 0.5654 - val_loss: 81.8154 - val_acc: 0.5535 - val_auc_roc: 0.7893 - val_auc_pr: 0.4877
# Epoch 251/300
# 1/1 - 0s - loss: 237.6342 - acc: 0.5567 - auc_roc: 0.8639 - auc_pr: 0.5711 - val_loss: 81.8768 - val_acc: 0.5524 - val_auc_roc: 0.7892 - val_auc_pr: 0.4872
# Epoch 252/300
# 1/1 - 0s - loss: 236.5755 - acc: 0.5514 - auc_roc: 0.8655 - auc_pr: 0.5725 - val_loss: 81.7749 - val_acc: 0.5469 - val_auc_roc: 0.7897 - val_auc_pr: 0.4870
# Epoch 253/300
# 1/1 - 0s - loss: 238.1438 - acc: 0.5523 - auc_roc: 0.8635 - auc_pr: 0.5686 - val_loss: 81.5662 - val_acc: 0.5413 - val_auc_roc: 0.7899 - val_auc_pr: 0.4877
# Epoch 254/300
# 1/1 - 0s - loss: 238.2002 - acc: 0.5468 - auc_roc: 0.8633 - auc_pr: 0.5651 - val_loss: 81.5765 - val_acc: 0.5402 - val_auc_roc: 0.7899 - val_auc_pr: 0.4884
# Epoch 255/300
# 1/1 - 0s - loss: 237.7613 - acc: 0.5484 - auc_roc: 0.8633 - auc_pr: 0.5675 - val_loss: 81.9395 - val_acc: 0.5491 - val_auc_roc: 0.7896 - val_auc_pr: 0.4863
# Epoch 256/300
# 1/1 - 0s - loss: 235.6579 - acc: 0.5545 - auc_roc: 0.8663 - auc_pr: 0.5705 - val_loss: 82.3518 - val_acc: 0.5590 - val_auc_roc: 0.7897 - val_auc_pr: 0.4877
# Epoch 257/300
# 1/1 - 0s - loss: 236.1214 - acc: 0.5652 - auc_roc: 0.8657 - auc_pr: 0.5727 - val_loss: 82.3442 - val_acc: 0.5557 - val_auc_roc: 0.7895 - val_auc_pr: 0.4869
# Epoch 258/300
# 1/1 - 0s - loss: 236.4023 - acc: 0.5622 - auc_roc: 0.8652 - auc_pr: 0.5720 - val_loss: 82.0221 - val_acc: 0.5424 - val_auc_roc: 0.7898 - val_auc_pr: 0.4884
# Epoch 259/300
# 1/1 - 0s - loss: 235.9818 - acc: 0.5531 - auc_roc: 0.8658 - auc_pr: 0.5676 - val_loss: 82.0588 - val_acc: 0.5424 - val_auc_roc: 0.7900 - val_auc_pr: 0.4884
# Epoch 260/300
# 1/1 - 0s - loss: 236.8743 - acc: 0.5531 - auc_roc: 0.8646 - auc_pr: 0.5699 - val_loss: 82.3013 - val_acc: 0.5480 - val_auc_roc: 0.7898 - val_auc_pr: 0.4862
# Epoch 261/300
# 1/1 - 0s - loss: 236.5589 - acc: 0.5559 - auc_roc: 0.8646 - auc_pr: 0.5698 - val_loss: 82.5110 - val_acc: 0.5546 - val_auc_roc: 0.7895 - val_auc_pr: 0.4863
# Epoch 262/300
# 1/1 - 0s - loss: 235.9599 - acc: 0.5617 - auc_roc: 0.8651 - auc_pr: 0.5700 - val_loss: 82.3620 - val_acc: 0.5469 - val_auc_roc: 0.7898 - val_auc_pr: 0.4876
# Epoch 263/300
# 1/1 - 0s - loss: 237.9633 - acc: 0.5534 - auc_roc: 0.8639 - auc_pr: 0.5694 - val_loss: 82.1452 - val_acc: 0.5402 - val_auc_roc: 0.7900 - val_auc_pr: 0.4892
# Epoch 264/300
# 1/1 - 0s - loss: 235.8470 - acc: 0.5501 - auc_roc: 0.8654 - auc_pr: 0.5684 - val_loss: 82.4299 - val_acc: 0.5524 - val_auc_roc: 0.7901 - val_auc_pr: 0.4864
# Epoch 265/300
# 1/1 - 0s - loss: 234.8252 - acc: 0.5578 - auc_roc: 0.8670 - auc_pr: 0.5738 - val_loss: 82.8562 - val_acc: 0.5667 - val_auc_roc: 0.7899 - val_auc_pr: 0.4882
# Epoch 266/300
# 1/1 - 0s - loss: 233.8378 - acc: 0.5677 - auc_roc: 0.8685 - auc_pr: 0.5743 - val_loss: 82.7020 - val_acc: 0.5623 - val_auc_roc: 0.7901 - val_auc_pr: 0.4867
# Epoch 267/300
# 1/1 - 0s - loss: 234.1780 - acc: 0.5683 - auc_roc: 0.8682 - auc_pr: 0.5750 - val_loss: 82.3612 - val_acc: 0.5469 - val_auc_roc: 0.7904 - val_auc_pr: 0.4907
# Epoch 268/300
# 1/1 - 0s - loss: 234.8593 - acc: 0.5559 - auc_roc: 0.8672 - auc_pr: 0.5719 - val_loss: 82.5571 - val_acc: 0.5546 - val_auc_roc: 0.7905 - val_auc_pr: 0.4898
# Epoch 269/300
# 1/1 - 0s - loss: 233.2311 - acc: 0.5572 - auc_roc: 0.8688 - auc_pr: 0.5733 - val_loss: 83.2777 - val_acc: 0.5700 - val_auc_roc: 0.7901 - val_auc_pr: 0.4905
# Epoch 270/300
# 1/1 - 0s - loss: 233.4085 - acc: 0.5735 - auc_roc: 0.8693 - auc_pr: 0.5782 - val_loss: 83.2901 - val_acc: 0.5711 - val_auc_roc: 0.7899 - val_auc_pr: 0.4897
# Epoch 271/300
# 1/1 - 0s - loss: 232.9661 - acc: 0.5743 - auc_roc: 0.8697 - auc_pr: 0.5788 - val_loss: 82.6541 - val_acc: 0.5513 - val_auc_roc: 0.7903 - val_auc_pr: 0.4896
# Epoch 272/300
# 1/1 - 0s - loss: 233.9195 - acc: 0.5583 - auc_roc: 0.8680 - auc_pr: 0.5732 - val_loss: 82.3538 - val_acc: 0.5402 - val_auc_roc: 0.7905 - val_auc_pr: 0.4935
# Epoch 273/300
# 1/1 - 0s - loss: 232.5075 - acc: 0.5501 - auc_roc: 0.8701 - auc_pr: 0.5753 - val_loss: 83.1429 - val_acc: 0.5678 - val_auc_roc: 0.7901 - val_auc_pr: 0.4879
# Epoch 274/300
# 1/1 - 0s - loss: 232.8147 - acc: 0.5724 - auc_roc: 0.8692 - auc_pr: 0.5726 - val_loss: 83.6424 - val_acc: 0.5733 - val_auc_roc: 0.7902 - val_auc_pr: 0.4902
# Epoch 275/300
# 1/1 - 0s - loss: 232.0011 - acc: 0.5757 - auc_roc: 0.8710 - auc_pr: 0.5812 - val_loss: 83.1201 - val_acc: 0.5656 - val_auc_roc: 0.7901 - val_auc_pr: 0.4889
# Epoch 276/300
# 1/1 - 0s - loss: 233.2626 - acc: 0.5625 - auc_roc: 0.8685 - auc_pr: 0.5726 - val_loss: 82.6004 - val_acc: 0.5469 - val_auc_roc: 0.7907 - val_auc_pr: 0.4931
# Epoch 277/300
# 1/1 - 0s - loss: 233.7484 - acc: 0.5542 - auc_roc: 0.8682 - auc_pr: 0.5733 - val_loss: 82.9262 - val_acc: 0.5568 - val_auc_roc: 0.7906 - val_auc_pr: 0.4893
# Epoch 278/300
# 1/1 - 0s - loss: 232.6703 - acc: 0.5608 - auc_roc: 0.8693 - auc_pr: 0.5723 - val_loss: 83.8168 - val_acc: 0.5755 - val_auc_roc: 0.7904 - val_auc_pr: 0.4904
# Epoch 279/300
# 1/1 - 0s - loss: 231.7455 - acc: 0.5782 - auc_roc: 0.8706 - auc_pr: 0.5766 - val_loss: 83.5456 - val_acc: 0.5711 - val_auc_roc: 0.7905 - val_auc_pr: 0.4886
# Epoch 280/300
# 1/1 - 0s - loss: 231.3243 - acc: 0.5763 - auc_roc: 0.8715 - auc_pr: 0.5799 - val_loss: 83.0248 - val_acc: 0.5579 - val_auc_roc: 0.7909 - val_auc_pr: 0.4920
# Epoch 281/300
# 1/1 - 0s - loss: 231.0549 - acc: 0.5614 - auc_roc: 0.8720 - auc_pr: 0.5779 - val_loss: 83.3888 - val_acc: 0.5601 - val_auc_roc: 0.7906 - val_auc_pr: 0.4911
# Epoch 282/300
# 1/1 - 0s - loss: 232.6221 - acc: 0.5641 - auc_roc: 0.8693 - auc_pr: 0.5763 - val_loss: 83.8551 - val_acc: 0.5700 - val_auc_roc: 0.7903 - val_auc_pr: 0.4887
# Epoch 283/300
# 1/1 - 0s - loss: 230.6565 - acc: 0.5768 - auc_roc: 0.8720 - auc_pr: 0.5818 - val_loss: 83.8480 - val_acc: 0.5678 - val_auc_roc: 0.7904 - val_auc_pr: 0.4902
# Epoch 284/300
# 1/1 - 0s - loss: 231.4284 - acc: 0.5777 - auc_roc: 0.8711 - auc_pr: 0.5786 - val_loss: 83.3760 - val_acc: 0.5557 - val_auc_roc: 0.7905 - val_auc_pr: 0.4918
# Epoch 285/300
# 1/1 - 0s - loss: 230.5152 - acc: 0.5630 - auc_roc: 0.8719 - auc_pr: 0.5750 - val_loss: 83.4280 - val_acc: 0.5568 - val_auc_roc: 0.7904 - val_auc_pr: 0.4917
# Epoch 286/300
# 1/1 - 0s - loss: 231.8030 - acc: 0.5619 - auc_roc: 0.8713 - auc_pr: 0.5735 - val_loss: 84.2273 - val_acc: 0.5678 - val_auc_roc: 0.7900 - val_auc_pr: 0.4878
# Epoch 287/300
# 1/1 - 0s - loss: 230.7461 - acc: 0.5823 - auc_roc: 0.8722 - auc_pr: 0.5787 - val_loss: 84.2551 - val_acc: 0.5689 - val_auc_roc: 0.7902 - val_auc_pr: 0.4897
# Epoch 288/300
# 1/1 - 0s - loss: 231.0157 - acc: 0.5832 - auc_roc: 0.8717 - auc_pr: 0.5805 - val_loss: 83.4530 - val_acc: 0.5502 - val_auc_roc: 0.7909 - val_auc_pr: 0.4944
# Epoch 289/300
# 1/1 - 0s - loss: 229.9810 - acc: 0.5680 - auc_roc: 0.8724 - auc_pr: 0.5777 - val_loss: 83.5636 - val_acc: 0.5546 - val_auc_roc: 0.7908 - val_auc_pr: 0.4943
# Epoch 290/300
# 1/1 - 0s - loss: 229.5977 - acc: 0.5636 - auc_roc: 0.8731 - auc_pr: 0.5774 - val_loss: 84.6352 - val_acc: 0.5777 - val_auc_roc: 0.7906 - val_auc_pr: 0.4894
# Epoch 291/300
# 1/1 - 0s - loss: 230.1919 - acc: 0.5854 - auc_roc: 0.8721 - auc_pr: 0.5827 - val_loss: 84.4788 - val_acc: 0.5722 - val_auc_roc: 0.7907 - val_auc_pr: 0.4906
# Epoch 292/300
# 1/1 - 0s - loss: 230.9249 - acc: 0.5848 - auc_roc: 0.8719 - auc_pr: 0.5790 - val_loss: 83.5812 - val_acc: 0.5502 - val_auc_roc: 0.7915 - val_auc_pr: 0.4949
# Epoch 293/300
# 1/1 - 0s - loss: 230.0581 - acc: 0.5594 - auc_roc: 0.8723 - auc_pr: 0.5786 - val_loss: 83.8558 - val_acc: 0.5601 - val_auc_roc: 0.7916 - val_auc_pr: 0.4944
# Epoch 294/300
# 1/1 - 0s - loss: 228.1213 - acc: 0.5738 - auc_roc: 0.8751 - auc_pr: 0.5836 - val_loss: 84.7602 - val_acc: 0.5755 - val_auc_roc: 0.7914 - val_auc_pr: 0.4894
# Epoch 295/300
# 1/1 - 0s - loss: 228.5084 - acc: 0.5851 - auc_roc: 0.8747 - auc_pr: 0.5851 - val_loss: 84.8350 - val_acc: 0.5755 - val_auc_roc: 0.7912 - val_auc_pr: 0.4891
# Epoch 296/300
# 1/1 - 0s - loss: 228.0524 - acc: 0.5876 - auc_roc: 0.8749 - auc_pr: 0.5844 - val_loss: 84.1646 - val_acc: 0.5623 - val_auc_roc: 0.7918 - val_auc_pr: 0.4951
# Epoch 297/300
# 1/1 - 0s - loss: 227.6149 - acc: 0.5730 - auc_roc: 0.8757 - auc_pr: 0.5842 - val_loss: 83.9955 - val_acc: 0.5579 - val_auc_roc: 0.7915 - val_auc_pr: 0.4945
# Epoch 298/300
# 1/1 - 0s - loss: 227.0797 - acc: 0.5732 - auc_roc: 0.8761 - auc_pr: 0.5855 - val_loss: 84.5682 - val_acc: 0.5678 - val_auc_roc: 0.7911 - val_auc_pr: 0.4932
# Epoch 299/300
# 1/1 - 0s - loss: 227.3976 - acc: 0.5796 - auc_roc: 0.8756 - auc_pr: 0.5835 - val_loss: 85.2518 - val_acc: 0.5810 - val_auc_roc: 0.7908 - val_auc_pr: 0.4890
# Epoch 300/300
# 1/1 - 0s - loss: 226.4069 - acc: 0.5914 - auc_roc: 0.8770 - auc_pr: 0.5854 - val_loss: 84.6776 - val_acc: 0.5656 - val_auc_roc: 0.7912 - val_auc_pr: 0.4943
#
#
# Score for fold 1: loss of 84.67761993408203; auc_pr of 49.42553639411926%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/300
# 1/1 - 5s - loss: 444.4176 - acc: 0.7390 - auc_roc: 0.4398 - auc_pr: 0.1175 - val_loss: 110.0411 - val_acc: 0.2525 - val_auc_roc: 0.5632 - val_auc_pr: 0.1574
# Epoch 2/300
# 1/1 - 0s - loss: 439.5634 - acc: 0.2577 - auc_roc: 0.5466 - auc_pr: 0.1479 - val_loss: 108.7231 - val_acc: 0.1510 - val_auc_roc: 0.6308 - val_auc_pr: 0.2038
# Epoch 3/300
# 1/1 - 0s - loss: 434.7090 - acc: 0.1531 - auc_roc: 0.6114 - auc_pr: 0.1872 - val_loss: 107.3958 - val_acc: 0.1400 - val_auc_roc: 0.6692 - val_auc_pr: 0.2447
# Epoch 4/300
# 1/1 - 1s - loss: 429.7624 - acc: 0.1421 - auc_roc: 0.6321 - auc_pr: 0.2197 - val_loss: 106.0569 - val_acc: 0.1400 - val_auc_roc: 0.6840 - val_auc_pr: 0.2619
# Epoch 5/300
# 1/1 - 0s - loss: 424.9272 - acc: 0.1404 - auc_roc: 0.6450 - auc_pr: 0.2301 - val_loss: 104.7268 - val_acc: 0.1400 - val_auc_roc: 0.6885 - val_auc_pr: 0.2726
# Epoch 6/300
# 1/1 - 0s - loss: 420.0348 - acc: 0.1399 - auc_roc: 0.6483 - auc_pr: 0.2393 - val_loss: 103.4194 - val_acc: 0.1400 - val_auc_roc: 0.6938 - val_auc_pr: 0.2810
# Epoch 7/300
# 1/1 - 1s - loss: 415.0840 - acc: 0.1399 - auc_roc: 0.6530 - auc_pr: 0.2463 - val_loss: 102.1330 - val_acc: 0.1400 - val_auc_roc: 0.6991 - val_auc_pr: 0.2817
# Epoch 8/300
# 1/1 - 1s - loss: 410.2565 - acc: 0.1399 - auc_roc: 0.6561 - auc_pr: 0.2501 - val_loss: 100.8646 - val_acc: 0.1400 - val_auc_roc: 0.7010 - val_auc_pr: 0.2829
# Epoch 9/300
# 1/1 - 0s - loss: 405.7021 - acc: 0.1399 - auc_roc: 0.6574 - auc_pr: 0.2527 - val_loss: 99.6177 - val_acc: 0.1400 - val_auc_roc: 0.7009 - val_auc_pr: 0.2855
# Epoch 10/300
# 1/1 - 0s - loss: 401.0011 - acc: 0.1399 - auc_roc: 0.6546 - auc_pr: 0.2536 - val_loss: 98.3814 - val_acc: 0.1400 - val_auc_roc: 0.7004 - val_auc_pr: 0.2895
# Epoch 11/300
# 1/1 - 0s - loss: 396.5284 - acc: 0.1399 - auc_roc: 0.6545 - auc_pr: 0.2532 - val_loss: 97.1294 - val_acc: 0.1400 - val_auc_roc: 0.7004 - val_auc_pr: 0.2915
# Epoch 12/300
# 1/1 - 0s - loss: 391.8599 - acc: 0.1399 - auc_roc: 0.6563 - auc_pr: 0.2558 - val_loss: 95.8686 - val_acc: 0.1400 - val_auc_roc: 0.7000 - val_auc_pr: 0.2924
# Epoch 13/300
# 1/1 - 1s - loss: 387.2774 - acc: 0.1399 - auc_roc: 0.6557 - auc_pr: 0.2566 - val_loss: 94.6063 - val_acc: 0.1400 - val_auc_roc: 0.7057 - val_auc_pr: 0.2969
# Epoch 14/300
# 1/1 - 1s - loss: 382.5992 - acc: 0.1399 - auc_roc: 0.6575 - auc_pr: 0.2591 - val_loss: 93.3318 - val_acc: 0.1400 - val_auc_roc: 0.7088 - val_auc_pr: 0.2989
# Epoch 15/300
# 1/1 - 0s - loss: 377.8642 - acc: 0.1399 - auc_roc: 0.6605 - auc_pr: 0.2617 - val_loss: 92.0532 - val_acc: 0.1400 - val_auc_roc: 0.7078 - val_auc_pr: 0.2999
# Epoch 16/300
# 1/1 - 0s - loss: 373.1523 - acc: 0.1399 - auc_roc: 0.6608 - auc_pr: 0.2626 - val_loss: 90.7822 - val_acc: 0.1400 - val_auc_roc: 0.7118 - val_auc_pr: 0.3047
# Epoch 17/300
# 1/1 - 0s - loss: 368.3914 - acc: 0.1399 - auc_roc: 0.6627 - auc_pr: 0.2647 - val_loss: 89.5315 - val_acc: 0.1400 - val_auc_roc: 0.7126 - val_auc_pr: 0.3064
# Epoch 18/300
# 1/1 - 0s - loss: 363.8958 - acc: 0.1399 - auc_roc: 0.6641 - auc_pr: 0.2670 - val_loss: 88.3097 - val_acc: 0.1400 - val_auc_roc: 0.7155 - val_auc_pr: 0.3106
# Epoch 19/300
# 1/1 - 0s - loss: 359.3563 - acc: 0.1399 - auc_roc: 0.6653 - auc_pr: 0.2697 - val_loss: 87.1343 - val_acc: 0.1400 - val_auc_roc: 0.7166 - val_auc_pr: 0.3139
# Epoch 20/300
# 1/1 - 0s - loss: 354.9294 - acc: 0.1399 - auc_roc: 0.6676 - auc_pr: 0.2715 - val_loss: 86.0236 - val_acc: 0.1400 - val_auc_roc: 0.7172 - val_auc_pr: 0.3159
# Epoch 21/300
# 1/1 - 0s - loss: 350.7889 - acc: 0.1399 - auc_roc: 0.6693 - auc_pr: 0.2746 - val_loss: 84.9954 - val_acc: 0.1400 - val_auc_roc: 0.7195 - val_auc_pr: 0.3177
# Epoch 22/300
# 1/1 - 0s - loss: 346.8883 - acc: 0.1399 - auc_roc: 0.6706 - auc_pr: 0.2768 - val_loss: 84.0661 - val_acc: 0.1400 - val_auc_roc: 0.7232 - val_auc_pr: 0.3230
# Epoch 23/300
# 1/1 - 1s - loss: 343.4879 - acc: 0.1399 - auc_roc: 0.6724 - auc_pr: 0.2785 - val_loss: 83.2500 - val_acc: 0.1400 - val_auc_roc: 0.7240 - val_auc_pr: 0.3286
# Epoch 24/300
# 1/1 - 0s - loss: 340.4460 - acc: 0.1399 - auc_roc: 0.6738 - auc_pr: 0.2807 - val_loss: 82.5608 - val_acc: 0.1400 - val_auc_roc: 0.7240 - val_auc_pr: 0.3322
# Epoch 25/300
# 1/1 - 0s - loss: 337.7322 - acc: 0.1399 - auc_roc: 0.6767 - auc_pr: 0.2831 - val_loss: 82.0045 - val_acc: 0.1400 - val_auc_roc: 0.7256 - val_auc_pr: 0.3363
# Epoch 26/300
# 1/1 - 1s - loss: 335.5583 - acc: 0.1399 - auc_roc: 0.6783 - auc_pr: 0.2855 - val_loss: 81.5849 - val_acc: 0.1400 - val_auc_roc: 0.7280 - val_auc_pr: 0.3426
# Epoch 27/300
# 1/1 - 0s - loss: 334.0821 - acc: 0.1399 - auc_roc: 0.6788 - auc_pr: 0.2861 - val_loss: 81.3012 - val_acc: 0.1400 - val_auc_roc: 0.7290 - val_auc_pr: 0.3401
# Epoch 28/300
# 1/1 - 1s - loss: 332.9460 - acc: 0.1399 - auc_roc: 0.6804 - auc_pr: 0.2889 - val_loss: 81.1408 - val_acc: 0.1400 - val_auc_roc: 0.7303 - val_auc_pr: 0.3473
# Epoch 29/300
# 1/1 - 1s - loss: 332.3164 - acc: 0.1399 - auc_roc: 0.6814 - auc_pr: 0.2896 - val_loss: 81.0821 - val_acc: 0.1400 - val_auc_roc: 0.7301 - val_auc_pr: 0.3480
# Epoch 30/300
# 1/1 - 0s - loss: 331.9530 - acc: 0.1399 - auc_roc: 0.6831 - auc_pr: 0.2918 - val_loss: 81.0957 - val_acc: 0.1400 - val_auc_roc: 0.7319 - val_auc_pr: 0.3465
# Epoch 31/300
# 1/1 - 1s - loss: 331.8355 - acc: 0.1399 - auc_roc: 0.6856 - auc_pr: 0.2946 - val_loss: 81.1534 - val_acc: 0.1400 - val_auc_roc: 0.7317 - val_auc_pr: 0.3505
# Epoch 32/300
# 1/1 - 0s - loss: 332.2445 - acc: 0.1399 - auc_roc: 0.6852 - auc_pr: 0.2964 - val_loss: 81.2263 - val_acc: 0.1400 - val_auc_roc: 0.7329 - val_auc_pr: 0.3517
# Epoch 33/300
# 1/1 - 1s - loss: 332.4672 - acc: 0.1399 - auc_roc: 0.6864 - auc_pr: 0.2958 - val_loss: 81.2860 - val_acc: 0.1400 - val_auc_roc: 0.7347 - val_auc_pr: 0.3556
# Epoch 34/300
# 1/1 - 1s - loss: 332.5265 - acc: 0.1399 - auc_roc: 0.6878 - auc_pr: 0.2984 - val_loss: 81.3118 - val_acc: 0.1400 - val_auc_roc: 0.7349 - val_auc_pr: 0.3572
# Epoch 35/300
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-577c0ac610d1> in <module>
#      54     print(f'Training for fold {fold_no} ...')
#      55
# ---> 56     history = model.fit(
#      57       train_gen,
#      58       epochs=param_set['epochs'],
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1213                 model=self,
#    1214                 steps_per_execution=self._steps_per_execution)
# -> 1215           val_logs = self.evaluate(
#    1216               x=val_x,
#    1217               y=val_y,
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\keras\engine\training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1493       self._test_counter.assign(0)
#    1494       callbacks.on_test_begin()
# -> 1495       for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    1496         self.reset_metrics()
#    1497         with data_handler.catch_stop_iteration():
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\keras\engine\data_adapter.py in enumerate_epochs(self)
#    1183           break
#    1184         if self._adapter.should_recreate_iterator():
# -> 1185           data_iterator = iter(self._dataset)
#    1186         yield epoch, data_iterator
#    1187         self._adapter.on_epoch_end()
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\tensorflow\python\data\ops\dataset_ops.py in __iter__(self)
#     409     if context.executing_eagerly() or ops.inside_function():
#     410       with ops.colocate_with(self._variant_tensor):
# --> 411         return iterator_ops.OwnedIterator(self)
#     412     else:
#     413       raise RuntimeError("__iter__() is only supported inside of tf.function "
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\tensorflow\python\data\ops\iterator_ops.py in __init__(self, dataset, components, element_spec)
#     694       if (components is not None or element_spec is not None):
#     695         raise ValueError(error_message)
# --> 696       self._create_iterator(dataset)
#     697
#     698   def _create_iterator(self, dataset):
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\tensorflow\python\data\ops\iterator_ops.py in _create_iterator(self, dataset)
#     717               output_types=self._flat_output_types,
#     718               output_shapes=self._flat_output_shapes))
# --> 719       gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     720       # Delete the resource when this object is deleted
#     721       self._resource_deleter = IteratorResourceDeleter(
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\tensorflow\python\ops\gen_dataset_ops.py in make_iterator(dataset, iterator, name)
#    3117   if tld.is_eager:
#    3118     try:
# -> 3119       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3120         _ctx, "MakeIterator", name, dataset, iterator)
#    3121       return _result
#
# KeyboardInterrupt:

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import ParameterGrid




param_grid = {'layer_sizes':[[64, 64], [128, 128], [256, 256]],
        'activations': [["ReLU", "ReLU"], ["PReLU", "PReLU"]],
        'dropout':[0.01, 0.001, 0.1],
        'learning_rate':[0.001, 0.0001, 0.00001],
        'epochs':[300, 700],
        'gamma':[0, 0.1, 0.2, 0.5, 1, 2, 5],
        'alpha':[0.95, 0.90, 0.85, 0.80, 0.75, 0.50, 0.25]
        }


num_of_settings = len(list(ParameterGrid(param_grid)))
print ("Grid Search: Trying {} different parameter settings...".format(num_of_settings))
param_num = 0

for param_set in list(RandomizedSearchCV(estimator= gcn,  param_distributions = param_grid)):
        print(param_set['layer_sizes'])
# Out:
# Grid Search: Trying 5292 different parameter settings...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-c6ba500cc892> in <module>
#      19 param_num = 0
#      20
# ---> 21 for param_set in RandomizedSearchCV(estimator= gcn,  param_distributions = param_grid):
#      22         print(param_set['layer_sizes'])
#
# TypeError: 'RandomizedSearchCV' object is not iterable

# %%
params['layer_sizes']

params['activations']
# Out:
# [['ReLU', 'ReLU'], ['PReLU', 'PReLU']]

# %%
# Execução para os dados de teste

test_gen = generator.flow(labeled_test.index, test_targets)
test_metrics = model.evaluate(test_gen)

print("\nTest Set Metrics:")
for name, val in zip(model.metrics_names, test_metrics):
    print("\t{}: {:0.4f}".format(name, val))
# Out:
# 1/1 [==============================] - 0s 237ms/step - loss: 0.2463 - acc: 0.9123 - auc_roc: 0.8162 - auc_pr: 0.4019
#
# Test Set Metrics:
# 	loss: 0.2463
# 	acc: 0.9123
# 	auc_roc: 0.8162
# 	auc_pr: 0.4019

# %%
all_nodes = series_classes.index
all_gen = generator.flow(all_nodes)
all_predictions = model.predict(all_gen)

# %%
node_predictions = target_encoding.inverse_transform(all_predictions.squeeze())
df = pd.DataFrame({"Predicted": node_predictions, "True": series_classes})

#df.head(20)

print(df['True'].value_counts(), "\n")
df['Predicted'].value_counts()
# Out:
#  0.0    8486
# -1.0    4633
#  1.0     868
# Name: True, dtype: int64
# 0.0    13597
# 1.0      390
# Name: Predicted, dtype: int64

# %%
# Salvar a variável all_predictions e a node_predictions para comparar
# Usar a all_predictions para gerar gráficos da fig3 do artigo, sobre distribuição de nós 

df_predictions = pd.DataFrame({"percent": all_predictions.squeeze(), "binary": node_predictions, "true": series_classes})

# Save to csv
pred_csv_file = f'predictions_hprd_6a.csv'
with open(pred_csv_file, mode='w') as f:
    df_predictions.to_csv(f)
f.close()
