# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mygene
import h5py
import networkx as nx
import seaborn as sns
# %matplotlib inline

# %%
# a = crossentropy          = cross entropy 
# b = undersampling         = undersampling
# d = weighted_focalloss    = weighted focal loss (gamma=0, alpha=0.85) 
# e = focalloss_05          = focal loss (gamma=0.5, alpha=0.50) 
# f = focalloss_1           = focal loss (gamma=1, alpha=0.25) 
# g = focalloss_2           = focal loss (gamma=2, alpha=0.25) 

rede = 'iref'
algoritmo = 'GraphSAGE'
loss_code = 'g'
concat_name = 'focalloss_2'

# %%
# Criando um dataframe unico com todos os folds de treinamento e validação
# Inserindo uma coluna com legenda para cada um dos folds 

# Todos os 6 conjuntos de features serão concatenados em um dataframe, serão 6 dataframes, um para cada diferente aplicação de loss 

# Concatenação de experimentos com features MUTAÇÃO (1)

fold1 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold1_{rede}_1{loss_code}.csv')
fold1 = fold1.rename(columns={"Unnamed: 0": "epochs"})
fold1['fold']=1

fold2 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold2_{rede}_1{loss_code}.csv')
fold2 = fold2.rename(columns={"Unnamed: 0": "epochs"})
fold2['fold']=2

fold3 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold3_{rede}_1{loss_code}.csv')
fold3 = fold3.rename(columns={"Unnamed: 0": "epochs"})
fold3['fold']=3

fold4 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold4_{rede}_1{loss_code}.csv')
fold4 = fold4.rename(columns={"Unnamed: 0": "epochs"})
fold4['fold']=4

fold5 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold5_{rede}_1{loss_code}.csv')
fold5 = fold5.rename(columns={"Unnamed: 0": "epochs"})
fold5['fold']=5

# --------------------------------------------------------------
hprd_mutation = pd.concat([fold1, fold2, fold3, fold4, fold5])
hprd_mutation['feature']='mutations'

# %%
# Concatenação de experimentos com features CNA (2)

fold1 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold1_{rede}_2{loss_code}.csv')
fold1 = fold1.rename(columns={"Unnamed: 0": "epochs"})
fold1['fold']=1

fold2 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold2_{rede}_2{loss_code}.csv')
fold2 = fold2.rename(columns={"Unnamed: 0": "epochs"})
fold2['fold']=2

fold3 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold3_{rede}_2{loss_code}.csv')
fold3 = fold3.rename(columns={"Unnamed: 0": "epochs"})
fold3['fold']=3

fold4 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold4_{rede}_2{loss_code}.csv')
fold4 = fold4.rename(columns={"Unnamed: 0": "epochs"})
fold4['fold']=4

fold5 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold5_{rede}_2{loss_code}.csv')
fold5 = fold5.rename(columns={"Unnamed: 0": "epochs"})
fold5['fold']=5

# --------------------------------------------------------------
hprd_cna = pd.concat([fold1, fold2, fold3, fold4, fold5])
hprd_cna['feature']='cna'

# %%
# Concatenação de experimentos com features METHYLATION (3)

fold1 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold1_{rede}_3{loss_code}.csv')
fold1 = fold1.rename(columns={"Unnamed: 0": "epochs"})
fold1['fold']=1

fold2 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold2_{rede}_3{loss_code}.csv')
fold2 = fold2.rename(columns={"Unnamed: 0": "epochs"})
fold2['fold']=2

fold3 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold3_{rede}_3{loss_code}.csv')
fold3 = fold3.rename(columns={"Unnamed: 0": "epochs"})
fold3['fold']=3

fold4 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold4_{rede}_3{loss_code}.csv')
fold4 = fold4.rename(columns={"Unnamed: 0": "epochs"})
fold4['fold']=4

fold5 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold5_{rede}_3{loss_code}.csv')
fold5 = fold5.rename(columns={"Unnamed: 0": "epochs"})
fold5['fold']=5

# --------------------------------------------------------------
hprd_methylation = pd.concat([fold1, fold2, fold3, fold4, fold5])
hprd_methylation['feature']='methylation'

# %%
# Concatenação de experimentos com features EXPRESSION (4)

fold1 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold1_{rede}_4{loss_code}.csv')
fold1 = fold1.rename(columns={"Unnamed: 0": "epochs"})
fold1['fold']=1

fold2 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold2_{rede}_4{loss_code}.csv')
fold2 = fold2.rename(columns={"Unnamed: 0": "epochs"})
fold2['fold']=2

fold3 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold3_{rede}_4{loss_code}.csv')
fold3 = fold3.rename(columns={"Unnamed: 0": "epochs"})
fold3['fold']=3

fold4 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold4_{rede}_4{loss_code}.csv')
fold4 = fold4.rename(columns={"Unnamed: 0": "epochs"})
fold4['fold']=4

fold5 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold5_{rede}_4{loss_code}.csv')
fold5 = fold5.rename(columns={"Unnamed: 0": "epochs"})
fold5['fold']=5

# --------------------------------------------------------------
hprd_expression = pd.concat([fold1, fold2, fold3, fold4, fold5])
hprd_expression['feature']='expression'

# %%
# Concatenação de experimentos com features OMICS (5)

fold1 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold1_{rede}_5{loss_code}.csv')
fold1 = fold1.rename(columns={"Unnamed: 0": "epochs"})
fold1['fold']=1

fold2 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold2_{rede}_5{loss_code}.csv')
fold2 = fold2.rename(columns={"Unnamed: 0": "epochs"})
fold2['fold']=2

fold3 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold3_{rede}_5{loss_code}.csv')
fold3 = fold3.rename(columns={"Unnamed: 0": "epochs"})
fold3['fold']=3

fold4 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold4_{rede}_5{loss_code}.csv')
fold4 = fold4.rename(columns={"Unnamed: 0": "epochs"})
fold4['fold']=4

fold5 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold5_{rede}_5{loss_code}.csv')
fold5 = fold5.rename(columns={"Unnamed: 0": "epochs"})
fold5['fold']=5

# --------------------------------------------------------------
hprd_omics = pd.concat([fold1, fold2, fold3, fold4, fold5])
hprd_omics['feature']='omics'

# %%
# Concatenação de experimentos com features OMICS AND CENTRALITY (6)

fold1 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold1_{rede}_6{loss_code}.csv')
fold1 = fold1.rename(columns={"Unnamed: 0": "epochs"})
fold1['fold']=1

fold2 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold2_{rede}_6{loss_code}.csv')
fold2 = fold2.rename(columns={"Unnamed: 0": "epochs"})
fold2['fold']=2

fold3 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold3_{rede}_6{loss_code}.csv')
fold3 = fold3.rename(columns={"Unnamed: 0": "epochs"})
fold3['fold']=3

fold4 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold4_{rede}_6{loss_code}.csv')
fold4 = fold4.rename(columns={"Unnamed: 0": "epochs"})
fold4['fold']=4

fold5 = pd.read_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_crossval/fold5_{rede}_6{loss_code}.csv')
fold5 = fold5.rename(columns={"Unnamed: 0": "epochs"})
fold5['fold']=5

# --------------------------------------------------------------
hprd_omics_centrality = pd.concat([fold1, fold2, fold3, fold4, fold5])
hprd_omics_centrality['feature']='omics_centrality'

# %%
concat_loss = pd.concat([hprd_mutation, hprd_cna, hprd_methylation, hprd_expression, hprd_omics, hprd_omics_centrality])
concat_loss
# Out:
#      epochs      loss       acc   auc_roc    auc_pr  val_loss   val_acc  \
# 0         0  0.028105  0.909413  0.683023  0.164209  0.025865  0.909910
# 1         1  0.025823  0.910700  0.742020  0.293184  0.024871  0.909910
# 2         2  0.025245  0.911665  0.753932  0.320705  0.024439  0.910553
# 3         3  0.025043  0.912631  0.757609  0.333009  0.024391  0.911840
# 4         4  0.024788  0.913113  0.770056  0.334850  0.023828  0.911840
# ..      ...       ...       ...       ...       ...       ...       ...
# 295     295  0.005621  0.977317  0.992276  0.956234  0.059123  0.896974
# 296     296  0.006223  0.975547  0.991885  0.948906  0.050464  0.904701
# 297     297  0.006141  0.976351  0.990638  0.950519  0.053959  0.902769
# 298     298  0.006041  0.976030  0.992567  0.951014  0.052758  0.905344
# 299     299  0.006105  0.977960  0.990837  0.951271  0.051819  0.904701
#
#      val_auc_roc  val_auc_pr  fold           feature
# ...

# %%
concat_loss.to_csv(f'C:/Users/renan/Desktop/experiments/{algoritmo}/history_complete/{rede}_{concat_name}.tsv', sep='\t', index=False)
