# %% [markdown]
# # Node classification with Graph Convolutional Network (GCN)

# %%
import numpy as np

import mygene
import h5py
import pickle
import argparse
import networkx as nx
import seaborn as sns

import pandas as pd
import os

import stellargraph as sg
from stellargraph.layer import GCN
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import sys

from stellargraph import StellarGraph
from stellargraph import datasets
from stellargraph.mapper import (
    CorruptedGenerator,
    FullBatchNodeGenerator,
    GraphSAGENodeGenerator,
    HinSAGENodeGenerator,
    ClusterNodeGenerator,
)

from stellargraph.layer import GCN, DeepGraphInfomax, GraphSAGE, GAT, APPNP, HinSAGE
from stellargraph.utils import plot_history

from tensorflow.keras import layers, optimizers, losses, metrics, Model
from sklearn import preprocessing, feature_extraction, model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold, ParameterGrid
from sklearn.manifold import TSNE
from sklearn.metrics import average_precision_score
from IPython.display import display, HTML

import tensorflow as tf
from scipy.sparse import csr_matrix, lil_matrix
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras import Model
from keras.models import Sequential
from keras.layers import Dense

from imblearn.over_sampling import SMOTE

# %%
network = pd.read_csv('C:/Users/renan/Desktop/UFRGS/GNN/data/data_final_v2/IREF_network.tsv', sep='\t')

features = pd.read_csv('C:/Users/renan/Desktop/UFRGS/GNN/data/data_final_v2/IREF_features_omics.tsv', sep='\t', index_col='gene')

labels = pd.read_csv('C:/Users/renan/Desktop/UFRGS/GNN/data/data_final_v2/IREF_labels_semisupervised.tsv', sep='\t', index_col='gene')

# %%
# Mutations 0:48
# CNA 16:64
# DNA Methylation 0:32 e 16:48
# Gene Expression 0:16 e 16:48


features.drop(features.iloc[:, 16:64], inplace = True, axis = 1)
#features.drop(features.iloc[:, 16:48], inplace = True, axis = 1)
features
# Out:
#         CNA: BLCA  CNA: BRCA  CNA: CESC  CNA: COAD  CNA: ESCA  CNA: HNSC  \
# gene
# A1BG          0.0   0.000000   0.167401   0.000000   0.000000   0.255263
# A1CF          0.0   0.000000   0.000000   0.000000   0.283951   0.000000
# A2M           0.0   0.000000   0.000000   0.174419   0.000000   0.000000
# AAAS          0.0   0.000000   0.000000   0.000000   0.000000   0.000000
# AACS          0.0   0.227126   0.000000   0.000000   0.000000   0.159091
# ...           ...        ...        ...        ...        ...        ...
# ZYG11A        0.0   0.000000   0.000000   0.000000   0.000000   0.000000
# ZYG11B        0.0   0.000000   0.000000   0.000000   0.000000   0.000000
# ZYX           0.0   0.000000   0.264317   0.000000   0.000000   0.000000
# ZZEF1         0.0   0.000000   0.000000   0.000000   0.000000   0.000000
# ZZZ3          0.0   0.000000   0.000000   0.345930   0.000000   0.000000
#
#         CNA: KIRC  CNA: KIRP  CNA: LIHC  CNA: LUAD  CNA: LUSC  CNA: PRAD  \
# gene
# A1BG     0.000000   0.095477   0.000000   0.000000   0.000000   0.000000
# A1CF     0.000000   0.082251   0.000000   0.000000   0.000000   0.000000
# A2M      0.000000   0.000000   0.000000   0.289256   0.000000   0.000000
# AAAS     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# AACS     0.000000   0.000000   0.175074   0.274793   0.178794   0.129129
# ...           ...        ...        ...        ...        ...        ...
# ZYG11A   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# ZYG11B   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# ZYX      0.376344   0.000000   0.100890   0.000000   0.000000   0.000000
# ZZEF1    0.000000   0.000000   0.670623   0.000000   0.000000   0.000000
# ZZZ3     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
#
#         CNA: READ  CNA: STAD  CNA: THCA  CNA: UCEC
# gene
# A1BG     0.244898    0.00000   0.000000   0.261719
# A1CF     0.000000    0.00000   0.000000   0.165017
# A2M      0.129870    0.23913   0.000000   0.000000
# AAAS     0.129870    0.18323   0.000000   0.000000
# AACS     0.000000    0.00000   0.000000   0.217822
# ...           ...        ...        ...        ...
# ZYG11A   0.000000    0.00000   0.000000   0.000000
# ZYG11B   0.000000    0.00000   0.000000   0.000000
# ZYX      0.000000    0.00000   0.010526   0.207921
# ZZEF1    0.000000    0.00000   0.084211   0.000000
# ZZZ3     0.000000    0.28882   0.000000   0.000000
#
# [14627 rows x 16 columns]

# %%
# Transformar as labels boleanas em 0/1
labels["label"].replace({False: 0, True: 1}, inplace=True)

# Transformar as labels vazias em -1
labels["label"] = labels.label.fillna(-1)

# %%
G = StellarGraph(edges=network, nodes=features)

print(G.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 14627, Edges: 133095
#
#  Node types:
#   default: [14627]
#     Features: float32 vector, length 16
#     Edge types: default-default->default
#
#  Edge types:
#     default-default->default: [133095]
#         Weights: all 1 (default)
#         Features: none

# %%
series_classes = labels['label']

series_classes.value_counts(dropna = False).to_frame()
# Out:
#       label
#  0.0   8838
# -1.0   4915
#  1.0    874

# %%
# Dividindo dados em treino/validação/teste

train_ratio = 0.80
test_ratio = 0.20

labeled_data = labels[labels['label'] != -1]
labeled_data = labeled_data.sample(frac=1)

# Aqui aplica-se então 20% do tamanho total da rede e o restante para treino
labeled_train, labeled_test = model_selection.train_test_split(
    labeled_data, test_size=test_ratio, stratify=labeled_data)


print("Train: ", len(labeled_train))
print("Test: ", len(labeled_test))
print("\nTotal: ", len(labeled_train)+len(labeled_test))
# Out:
# Train:  7769
# Test:  1943
#
# Total:  9712

# %%
# Difinição da função de custo Focal Loss

import dill

from keras import backend as K

def binary_focal_loss(gamma=2., alpha=.25):

    def binary_focal_loss_fixed(y_true, y_pred):
     
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)
        # Define epsilon so that the back-propagation will not result in NaN for 0 divisor case
        epsilon = K.epsilon()
        # Add the epsilon to prediction value
        # y_pred = y_pred + epsilon
        # Clip the prediciton value
        y_pred = K.clip(y_pred, epsilon, 1.0 - epsilon)
        # Calculate p_t
        p_t = tf.where(K.equal(y_true, 1), y_pred, 1 - y_pred)
        # Calculate alpha_t
        alpha_factor = K.ones_like(y_true) * alpha
        alpha_t = tf.where(K.equal(y_true, 1), alpha_factor, 1 - alpha_factor)
        # Calculate cross entropy
        cross_entropy = -K.log(p_t)
        weight = alpha_t * K.pow((1 - p_t), gamma)
        # Calculate focal loss
        loss = weight * cross_entropy
        # Sum the losses in mini_batch
        loss = K.mean(K.sum(loss, axis=1))
        return loss

    return binary_focal_loss_fixed

# %%
target_encoding = preprocessing.LabelBinarizer()

train_targets = target_encoding.fit_transform(labeled_train)
test_targets = target_encoding.transform(labeled_test)

# %%
from keras.models import Sequential
from keras.utils import np_utils
from keras.layers.core import Dense, Activation, Dropout

from sklearn.model_selection import KFold

num_folds = 5

auc_pr_per_fold = []
loss_per_fold = []

kfold = StratifiedKFold(n_splits=num_folds, shuffle=True)

fold_no = 1
for train, test in kfold.split(labeled_train.index, train_targets):

  nb_classes = train_targets.shape[1]
  input_dim = features.loc[labeled_train.index].values.shape[1]

  model = Sequential()
  model.add(Dense(64, input_dim=input_dim))
  model.add(Activation('ReLU'))
  model.add(Dropout(0.01))
  model.add(Dense(64))
  model.add(Activation('ReLU'))
  model.add(Dropout(0.01))
  model.add(Dense(nb_classes))
  model.add(Activation('sigmoid'))


  model.compile(
      loss='binary_crossentropy',
      #loss=[binary_focal_loss(gamma=0, alpha=0.85)],
      optimizer=optimizers.Adam(learning_rate=0.001), 
      metrics=["acc", metrics.AUC(curve="ROC", name="auc_roc"), metrics.AUC(curve="PR", name="auc_pr")]
  )

  X_train = features.loc[labeled_train.index[train]].values
  y_train = train_targets[train]

  X_val = features.loc[labeled_train.index[test]].values
  y_val = train_targets[test]

    
  # Generate a print
  print('------------------------------------------------------------------------')
  print(f'Training for fold {fold_no} ...')

  history = model.fit(X_train, y_train, epochs=300, validation_data=(X_val, y_val), batch_size=8, verbose=2)

  # Generate generalization metrics
  scores = model.evaluate(X_val, y_val, verbose=0)
  print('\n')
  print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[3]} of {scores[3]*100}%')
  auc_pr_per_fold.append(scores[3] * 100)
  loss_per_fold.append(scores[0])

  # Save history to csv
  hist_df = pd.DataFrame(history.history)

  hist_csv_file = f'fold{fold_no}_iref_2a.csv'
  with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)
  f.close()

  # Increase fold number
  fold_no = fold_no + 1

# Provide average scores
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(auc_pr_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - AUC PR: {auc_pr_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> AUC PR: {np.mean(auc_pr_per_fold)} (+- {np.std(auc_pr_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/300
# 777/777 - 4s - loss: 0.3236 - acc: 0.9099 - auc_roc: 0.4851 - auc_pr: 0.0889 - val_loss: 0.3043 - val_acc: 0.9099 - val_auc_roc: 0.5468 - val_auc_pr: 0.1140
# Epoch 2/300
# 777/777 - 2s - loss: 0.3022 - acc: 0.9101 - auc_roc: 0.5361 - auc_pr: 0.1147 - val_loss: 0.3087 - val_acc: 0.9099 - val_auc_roc: 0.5367 - val_auc_pr: 0.1099
# Epoch 3/300
# 777/777 - 2s - loss: 0.3012 - acc: 0.9101 - auc_roc: 0.5526 - auc_pr: 0.1314 - val_loss: 0.3039 - val_acc: 0.9099 - val_auc_roc: 0.5198 - val_auc_pr: 0.1062
# Epoch 4/300
# 777/777 - 1s - loss: 0.2995 - acc: 0.9101 - auc_roc: 0.5701 - auc_pr: 0.1233 - val_loss: 0.3036 - val_acc: 0.9099 - val_auc_roc: 0.5372 - val_auc_pr: 0.1146
# Epoch 5/300
# 777/777 - 2s - loss: 0.2987 - acc: 0.9101 - auc_roc: 0.5709 - auc_pr: 0.1380 - val_loss: 0.3058 - val_acc: 0.9099 - val_auc_roc: 0.5280 - val_auc_pr: 0.1123
# Epoch 6/300
# 777/777 - 2s - loss: 0.2975 - acc: 0.9101 - auc_roc: 0.5836 - auc_pr: 0.1415 - val_loss: 0.3022 - val_acc: 0.9099 - val_auc_roc: 0.5399 - val_auc_pr: 0.1149
# Epoch 7/300
# 777/777 - 2s - loss: 0.2964 - acc: 0.9101 - auc_roc: 0.5901 - auc_pr: 0.1505 - val_loss: 0.3021 - val_acc: 0.9099 - val_auc_roc: 0.5445 - val_auc_pr: 0.1187
# Epoch 8/300
# 777/777 - 2s - loss: 0.2953 - acc: 0.9104 - auc_roc: 0.6038 - auc_pr: 0.1477 - val_loss: 0.3036 - val_acc: 0.9099 - val_auc_roc: 0.5308 - val_auc_pr: 0.1131
# Epoch 9/300
# 777/777 - 2s - loss: 0.2950 - acc: 0.9107 - auc_roc: 0.5989 - auc_pr: 0.1593 - val_loss: 0.3030 - val_acc: 0.9093 - val_auc_roc: 0.5416 - val_auc_pr: 0.1170
# Epoch 10/300
# 777/777 - 2s - loss: 0.2934 - acc: 0.9105 - auc_roc: 0.6086 - auc_pr: 0.1621 - val_loss: 0.3074 - val_acc: 0.9093 - val_auc_roc: 0.5291 - val_auc_pr: 0.1138
# Epoch 11/300
# 777/777 - 2s - loss: 0.2922 - acc: 0.9109 - auc_roc: 0.6188 - auc_pr: 0.1694 - val_loss: 0.3049 - val_acc: 0.9093 - val_auc_roc: 0.5552 - val_auc_pr: 0.1200
# Epoch 12/300
# 777/777 - 2s - loss: 0.2919 - acc: 0.9105 - auc_roc: 0.6150 - auc_pr: 0.1749 - val_loss: 0.3039 - val_acc: 0.9093 - val_auc_roc: 0.5483 - val_auc_pr: 0.1179
# Epoch 13/300
# 777/777 - 2s - loss: 0.2912 - acc: 0.9105 - auc_roc: 0.6185 - auc_pr: 0.1764 - val_loss: 0.3038 - val_acc: 0.9099 - val_auc_roc: 0.5589 - val_auc_pr: 0.1196
# Epoch 14/300
# 777/777 - 2s - loss: 0.2907 - acc: 0.9109 - auc_roc: 0.6269 - auc_pr: 0.1790 - val_loss: 0.3116 - val_acc: 0.9086 - val_auc_roc: 0.5541 - val_auc_pr: 0.1191
# Epoch 15/300
# 777/777 - 2s - loss: 0.2894 - acc: 0.9110 - auc_roc: 0.6301 - auc_pr: 0.1853 - val_loss: 0.3098 - val_acc: 0.9099 - val_auc_roc: 0.5427 - val_auc_pr: 0.1162
# Epoch 16/300
# 777/777 - 2s - loss: 0.2891 - acc: 0.9110 - auc_roc: 0.6337 - auc_pr: 0.1862 - val_loss: 0.3055 - val_acc: 0.9093 - val_auc_roc: 0.5479 - val_auc_pr: 0.1154
# Epoch 17/300
# 777/777 - 2s - loss: 0.2875 - acc: 0.9112 - auc_roc: 0.6358 - auc_pr: 0.1981 - val_loss: 0.3057 - val_acc: 0.9099 - val_auc_roc: 0.5500 - val_auc_pr: 0.1155
# Epoch 18/300
# 777/777 - 2s - loss: 0.2872 - acc: 0.9107 - auc_roc: 0.6409 - auc_pr: 0.1967 - val_loss: 0.3056 - val_acc: 0.9086 - val_auc_roc: 0.5644 - val_auc_pr: 0.1231
# Epoch 19/300
# 777/777 - 2s - loss: 0.2862 - acc: 0.9112 - auc_roc: 0.6424 - auc_pr: 0.2068 - val_loss: 0.3071 - val_acc: 0.9086 - val_auc_roc: 0.5584 - val_auc_pr: 0.1167
# Epoch 20/300
# 777/777 - 2s - loss: 0.2865 - acc: 0.9112 - auc_roc: 0.6436 - auc_pr: 0.2017 - val_loss: 0.3086 - val_acc: 0.9093 - val_auc_roc: 0.5524 - val_auc_pr: 0.1139
# Epoch 21/300
# 777/777 - 1s - loss: 0.2844 - acc: 0.9120 - auc_roc: 0.6472 - auc_pr: 0.2162 - val_loss: 0.3113 - val_acc: 0.9080 - val_auc_roc: 0.5505 - val_auc_pr: 0.1142
# Epoch 22/300
# 777/777 - 2s - loss: 0.2845 - acc: 0.9115 - auc_roc: 0.6544 - auc_pr: 0.2093 - val_loss: 0.3079 - val_acc: 0.9086 - val_auc_roc: 0.5448 - val_auc_pr: 0.1125
# Epoch 23/300
# 777/777 - 2s - loss: 0.2845 - acc: 0.9117 - auc_roc: 0.6498 - auc_pr: 0.2131 - val_loss: 0.3107 - val_acc: 0.9073 - val_auc_roc: 0.5364 - val_auc_pr: 0.1052
# Epoch 24/300
# 777/777 - 2s - loss: 0.2839 - acc: 0.9123 - auc_roc: 0.6517 - auc_pr: 0.2144 - val_loss: 0.3083 - val_acc: 0.9067 - val_auc_roc: 0.5707 - val_auc_pr: 0.1170
# Epoch 25/300
# 777/777 - 2s - loss: 0.2841 - acc: 0.9118 - auc_roc: 0.6456 - auc_pr: 0.2177 - val_loss: 0.3094 - val_acc: 0.9093 - val_auc_roc: 0.5364 - val_auc_pr: 0.1064
# Epoch 26/300
# 777/777 - 2s - loss: 0.2822 - acc: 0.9130 - auc_roc: 0.6633 - auc_pr: 0.2245 - val_loss: 0.3109 - val_acc: 0.9080 - val_auc_roc: 0.5476 - val_auc_pr: 0.1087
# Epoch 27/300
# 777/777 - 2s - loss: 0.2817 - acc: 0.9126 - auc_roc: 0.6569 - auc_pr: 0.2361 - val_loss: 0.3090 - val_acc: 0.9099 - val_auc_roc: 0.5488 - val_auc_pr: 0.1136
# Epoch 28/300
# 777/777 - 2s - loss: 0.2818 - acc: 0.9120 - auc_roc: 0.6627 - auc_pr: 0.2257 - val_loss: 0.3075 - val_acc: 0.9086 - val_auc_roc: 0.5544 - val_auc_pr: 0.1185
# Epoch 29/300
# 777/777 - 1s - loss: 0.2822 - acc: 0.9125 - auc_roc: 0.6581 - auc_pr: 0.2280 - val_loss: 0.3088 - val_acc: 0.9086 - val_auc_roc: 0.5545 - val_auc_pr: 0.1116
# Epoch 30/300
# 777/777 - 2s - loss: 0.2817 - acc: 0.9123 - auc_roc: 0.6596 - auc_pr: 0.2274 - val_loss: 0.3098 - val_acc: 0.9086 - val_auc_roc: 0.5593 - val_auc_pr: 0.1143
# Epoch 31/300
# 777/777 - 2s - loss: 0.2810 - acc: 0.9128 - auc_roc: 0.6662 - auc_pr: 0.2283 - val_loss: 0.3093 - val_acc: 0.9099 - val_auc_roc: 0.5514 - val_auc_pr: 0.1100
# Epoch 32/300
# 777/777 - 2s - loss: 0.2797 - acc: 0.9136 - auc_roc: 0.6638 - auc_pr: 0.2437 - val_loss: 0.3127 - val_acc: 0.9086 - val_auc_roc: 0.5396 - val_auc_pr: 0.1080
# Epoch 33/300
# 777/777 - 2s - loss: 0.2811 - acc: 0.9121 - auc_roc: 0.6558 - auc_pr: 0.2314 - val_loss: 0.3109 - val_acc: 0.9099 - val_auc_roc: 0.5534 - val_auc_pr: 0.1140
# Epoch 34/300
# 777/777 - 2s - loss: 0.2792 - acc: 0.9130 - auc_roc: 0.6677 - auc_pr: 0.2421 - val_loss: 0.3086 - val_acc: 0.9086 - val_auc_roc: 0.5521 - val_auc_pr: 0.1126
# Epoch 35/300
# 777/777 - 2s - loss: 0.2774 - acc: 0.9131 - auc_roc: 0.6750 - auc_pr: 0.2494 - val_loss: 0.3166 - val_acc: 0.9060 - val_auc_roc: 0.5340 - val_auc_pr: 0.1030
# Epoch 36/300
# 777/777 - 1s - loss: 0.2779 - acc: 0.9130 - auc_roc: 0.6705 - auc_pr: 0.2470 - val_loss: 0.3110 - val_acc: 0.9041 - val_auc_roc: 0.5668 - val_auc_pr: 0.1215
# Epoch 37/300
# 777/777 - 2s - loss: 0.2770 - acc: 0.9136 - auc_roc: 0.6785 - auc_pr: 0.2504 - val_loss: 0.3103 - val_acc: 0.9099 - val_auc_roc: 0.5361 - val_auc_pr: 0.1179
# Epoch 38/300
# 777/777 - 1s - loss: 0.2775 - acc: 0.9128 - auc_roc: 0.6781 - auc_pr: 0.2464 - val_loss: 0.3159 - val_acc: 0.9099 - val_auc_roc: 0.5349 - val_auc_pr: 0.1120
# Epoch 39/300
# 777/777 - 2s - loss: 0.2769 - acc: 0.9130 - auc_roc: 0.6780 - auc_pr: 0.2480 - val_loss: 0.3183 - val_acc: 0.9060 - val_auc_roc: 0.5276 - val_auc_pr: 0.1071
# Epoch 40/300
# 777/777 - 2s - loss: 0.2763 - acc: 0.9138 - auc_roc: 0.6770 - auc_pr: 0.2576 - val_loss: 0.3152 - val_acc: 0.9086 - val_auc_roc: 0.5487 - val_auc_pr: 0.1151
# Epoch 41/300
# 777/777 - 2s - loss: 0.2760 - acc: 0.9141 - auc_roc: 0.6813 - auc_pr: 0.2560 - val_loss: 0.3131 - val_acc: 0.9073 - val_auc_roc: 0.5552 - val_auc_pr: 0.1140
# Epoch 42/300
# 777/777 - 2s - loss: 0.2748 - acc: 0.9134 - auc_roc: 0.6772 - auc_pr: 0.2647 - val_loss: 0.3117 - val_acc: 0.9086 - val_auc_roc: 0.5485 - val_auc_pr: 0.1134
# Epoch 43/300
# 777/777 - 2s - loss: 0.2751 - acc: 0.9149 - auc_roc: 0.6722 - auc_pr: 0.2633 - val_loss: 0.3171 - val_acc: 0.9054 - val_auc_roc: 0.5430 - val_auc_pr: 0.1117
# Epoch 44/300
# 777/777 - 2s - loss: 0.2745 - acc: 0.9144 - auc_roc: 0.6872 - auc_pr: 0.2593 - val_loss: 0.3205 - val_acc: 0.9048 - val_auc_roc: 0.5436 - val_auc_pr: 0.1052
# Epoch 45/300
# 777/777 - 2s - loss: 0.2753 - acc: 0.9136 - auc_roc: 0.6818 - auc_pr: 0.2609 - val_loss: 0.3209 - val_acc: 0.9022 - val_auc_roc: 0.5493 - val_auc_pr: 0.1064
# Epoch 46/300
# 777/777 - 2s - loss: 0.2742 - acc: 0.9147 - auc_roc: 0.6767 - auc_pr: 0.2698 - val_loss: 0.3206 - val_acc: 0.9093 - val_auc_roc: 0.5273 - val_auc_pr: 0.1038
# Epoch 47/300
# 777/777 - 2s - loss: 0.2730 - acc: 0.9134 - auc_roc: 0.6892 - auc_pr: 0.2697 - val_loss: 0.3171 - val_acc: 0.9022 - val_auc_roc: 0.5754 - val_auc_pr: 0.1185
# Epoch 48/300
# 777/777 - 2s - loss: 0.2740 - acc: 0.9144 - auc_roc: 0.6787 - auc_pr: 0.2698 - val_loss: 0.3155 - val_acc: 0.9080 - val_auc_roc: 0.5391 - val_auc_pr: 0.1148
# Epoch 49/300
# 777/777 - 2s - loss: 0.2720 - acc: 0.9142 - auc_roc: 0.6874 - auc_pr: 0.2792 - val_loss: 0.3264 - val_acc: 0.8990 - val_auc_roc: 0.5497 - val_auc_pr: 0.1121
# Epoch 50/300
# 777/777 - 2s - loss: 0.2730 - acc: 0.9157 - auc_roc: 0.6842 - auc_pr: 0.2738 - val_loss: 0.3162 - val_acc: 0.9048 - val_auc_roc: 0.5510 - val_auc_pr: 0.1105
# Epoch 51/300
# 777/777 - 2s - loss: 0.2735 - acc: 0.9142 - auc_roc: 0.6887 - auc_pr: 0.2674 - val_loss: 0.3149 - val_acc: 0.9022 - val_auc_roc: 0.5436 - val_auc_pr: 0.1087
# Epoch 52/300
# 777/777 - 2s - loss: 0.2720 - acc: 0.9152 - auc_roc: 0.6798 - auc_pr: 0.2825 - val_loss: 0.3185 - val_acc: 0.9048 - val_auc_roc: 0.5539 - val_auc_pr: 0.1087
# Epoch 53/300
# 777/777 - 2s - loss: 0.2715 - acc: 0.9147 - auc_roc: 0.6977 - auc_pr: 0.2766 - val_loss: 0.3162 - val_acc: 0.9060 - val_auc_roc: 0.5489 - val_auc_pr: 0.1095
# Epoch 54/300
# 777/777 - 2s - loss: 0.2726 - acc: 0.9147 - auc_roc: 0.6900 - auc_pr: 0.2718 - val_loss: 0.3179 - val_acc: 0.9080 - val_auc_roc: 0.5500 - val_auc_pr: 0.1115
# Epoch 55/300
# 777/777 - 2s - loss: 0.2731 - acc: 0.9162 - auc_roc: 0.6823 - auc_pr: 0.2751 - val_loss: 0.3171 - val_acc: 0.9048 - val_auc_roc: 0.5504 - val_auc_pr: 0.1077
# Epoch 56/300
# 777/777 - 2s - loss: 0.2699 - acc: 0.9158 - auc_roc: 0.6960 - auc_pr: 0.2881 - val_loss: 0.3152 - val_acc: 0.9080 - val_auc_roc: 0.5467 - val_auc_pr: 0.1126
# Epoch 57/300
# 777/777 - 2s - loss: 0.2709 - acc: 0.9147 - auc_roc: 0.6968 - auc_pr: 0.2795 - val_loss: 0.3189 - val_acc: 0.9054 - val_auc_roc: 0.5194 - val_auc_pr: 0.1011
# Epoch 58/300
# 777/777 - 2s - loss: 0.2713 - acc: 0.9141 - auc_roc: 0.6993 - auc_pr: 0.2760 - val_loss: 0.3228 - val_acc: 0.9048 - val_auc_roc: 0.5145 - val_auc_pr: 0.1006
# Epoch 59/300
# 777/777 - 1s - loss: 0.2697 - acc: 0.9147 - auc_roc: 0.6975 - auc_pr: 0.2865 - val_loss: 0.3198 - val_acc: 0.9054 - val_auc_roc: 0.5449 - val_auc_pr: 0.1058
# Epoch 60/300
# 777/777 - 2s - loss: 0.2693 - acc: 0.9144 - auc_roc: 0.7001 - auc_pr: 0.2909 - val_loss: 0.3271 - val_acc: 0.9015 - val_auc_roc: 0.5531 - val_auc_pr: 0.1083
# Epoch 61/300
# 777/777 - 2s - loss: 0.2692 - acc: 0.9154 - auc_roc: 0.7026 - auc_pr: 0.2895 - val_loss: 0.3231 - val_acc: 0.9080 - val_auc_roc: 0.5572 - val_auc_pr: 0.1145
# Epoch 62/300
# 777/777 - 1s - loss: 0.2717 - acc: 0.9152 - auc_roc: 0.6961 - auc_pr: 0.2744 - val_loss: 0.3248 - val_acc: 0.9060 - val_auc_roc: 0.5477 - val_auc_pr: 0.1100
# Epoch 63/300
# 777/777 - 1s - loss: 0.2700 - acc: 0.9160 - auc_roc: 0.6970 - auc_pr: 0.2825 - val_loss: 0.3233 - val_acc: 0.9048 - val_auc_roc: 0.5395 - val_auc_pr: 0.1060
# Epoch 64/300
# 777/777 - 2s - loss: 0.2678 - acc: 0.9163 - auc_roc: 0.7031 - auc_pr: 0.2954 - val_loss: 0.3197 - val_acc: 0.9041 - val_auc_roc: 0.5493 - val_auc_pr: 0.1068
# Epoch 65/300
# 777/777 - 2s - loss: 0.2681 - acc: 0.9170 - auc_roc: 0.7029 - auc_pr: 0.2972 - val_loss: 0.3201 - val_acc: 0.9073 - val_auc_roc: 0.5382 - val_auc_pr: 0.1065
# Epoch 66/300
# 777/777 - 2s - loss: 0.2684 - acc: 0.9150 - auc_roc: 0.7016 - auc_pr: 0.2923 - val_loss: 0.3180 - val_acc: 0.9048 - val_auc_roc: 0.5524 - val_auc_pr: 0.1101
# Epoch 67/300
# 777/777 - 2s - loss: 0.2696 - acc: 0.9163 - auc_roc: 0.6938 - auc_pr: 0.2860 - val_loss: 0.3238 - val_acc: 0.9035 - val_auc_roc: 0.5349 - val_auc_pr: 0.1046
# Epoch 68/300
# 777/777 - 1s - loss: 0.2685 - acc: 0.9162 - auc_roc: 0.6966 - auc_pr: 0.2919 - val_loss: 0.3224 - val_acc: 0.8990 - val_auc_roc: 0.5574 - val_auc_pr: 0.1115
# Epoch 69/300
# 777/777 - 2s - loss: 0.2686 - acc: 0.9141 - auc_roc: 0.7043 - auc_pr: 0.2921 - val_loss: 0.3233 - val_acc: 0.9009 - val_auc_roc: 0.5502 - val_auc_pr: 0.1067
# Epoch 70/300
# 777/777 - 2s - loss: 0.2665 - acc: 0.9160 - auc_roc: 0.7032 - auc_pr: 0.3016 - val_loss: 0.3255 - val_acc: 0.9022 - val_auc_roc: 0.5482 - val_auc_pr: 0.1061
# Epoch 71/300
# 777/777 - 2s - loss: 0.2681 - acc: 0.9158 - auc_roc: 0.7023 - auc_pr: 0.2939 - val_loss: 0.3276 - val_acc: 0.8990 - val_auc_roc: 0.5433 - val_auc_pr: 0.1049
# Epoch 72/300
# 777/777 - 2s - loss: 0.2685 - acc: 0.9167 - auc_roc: 0.6949 - auc_pr: 0.2954 - val_loss: 0.3233 - val_acc: 0.9054 - val_auc_roc: 0.5417 - val_auc_pr: 0.1057
# Epoch 73/300
# 777/777 - 2s - loss: 0.2675 - acc: 0.9157 - auc_roc: 0.7006 - auc_pr: 0.2962 - val_loss: 0.3217 - val_acc: 0.9022 - val_auc_roc: 0.5470 - val_auc_pr: 0.1072
# Epoch 74/300
# 777/777 - 2s - loss: 0.2673 - acc: 0.9142 - auc_roc: 0.7055 - auc_pr: 0.2969 - val_loss: 0.3204 - val_acc: 0.9022 - val_auc_roc: 0.5717 - val_auc_pr: 0.1170
# Epoch 75/300
# 777/777 - 1s - loss: 0.2664 - acc: 0.9167 - auc_roc: 0.7147 - auc_pr: 0.3005 - val_loss: 0.3196 - val_acc: 0.9035 - val_auc_roc: 0.5594 - val_auc_pr: 0.1092
# Epoch 76/300
# 777/777 - 2s - loss: 0.2677 - acc: 0.9158 - auc_roc: 0.7080 - auc_pr: 0.2933 - val_loss: 0.3217 - val_acc: 0.9022 - val_auc_roc: 0.5340 - val_auc_pr: 0.1039
# Epoch 77/300
# 777/777 - 1s - loss: 0.2682 - acc: 0.9162 - auc_roc: 0.6995 - auc_pr: 0.2933 - val_loss: 0.3213 - val_acc: 0.9073 - val_auc_roc: 0.5369 - val_auc_pr: 0.1101
# Epoch 78/300
# 777/777 - 2s - loss: 0.2683 - acc: 0.9154 - auc_roc: 0.7003 - auc_pr: 0.2888 - val_loss: 0.3188 - val_acc: 0.9003 - val_auc_roc: 0.5700 - val_auc_pr: 0.1136
# Epoch 79/300
# 777/777 - 1s - loss: 0.2680 - acc: 0.9163 - auc_roc: 0.7009 - auc_pr: 0.2949 - val_loss: 0.3210 - val_acc: 0.8990 - val_auc_roc: 0.5792 - val_auc_pr: 0.1131
# Epoch 80/300
# 777/777 - 2s - loss: 0.2676 - acc: 0.9165 - auc_roc: 0.7033 - auc_pr: 0.2934 - val_loss: 0.3265 - val_acc: 0.8958 - val_auc_roc: 0.5816 - val_auc_pr: 0.1142
# Epoch 81/300
# 777/777 - 2s - loss: 0.2665 - acc: 0.9165 - auc_roc: 0.7040 - auc_pr: 0.3058 - val_loss: 0.3243 - val_acc: 0.9015 - val_auc_roc: 0.5314 - val_auc_pr: 0.1067
# Epoch 82/300
# 777/777 - 2s - loss: 0.2652 - acc: 0.9173 - auc_roc: 0.7130 - auc_pr: 0.3084 - val_loss: 0.3249 - val_acc: 0.9015 - val_auc_roc: 0.5605 - val_auc_pr: 0.1080
# Epoch 83/300
# 777/777 - 2s - loss: 0.2667 - acc: 0.9170 - auc_roc: 0.7000 - auc_pr: 0.3053 - val_loss: 0.3180 - val_acc: 0.9067 - val_auc_roc: 0.5668 - val_auc_pr: 0.1133
# Epoch 84/300
# 777/777 - 2s - loss: 0.2647 - acc: 0.9170 - auc_roc: 0.7144 - auc_pr: 0.3052 - val_loss: 0.3400 - val_acc: 0.9093 - val_auc_roc: 0.5375 - val_auc_pr: 0.1048
# Epoch 85/300
# 777/777 - 2s - loss: 0.2655 - acc: 0.9165 - auc_roc: 0.7117 - auc_pr: 0.3048 - val_loss: 0.3191 - val_acc: 0.9060 - val_auc_roc: 0.5585 - val_auc_pr: 0.1099
# Epoch 86/300
# 777/777 - 2s - loss: 0.2650 - acc: 0.9175 - auc_roc: 0.7136 - auc_pr: 0.3096 - val_loss: 0.3218 - val_acc: 0.9048 - val_auc_roc: 0.5653 - val_auc_pr: 0.1085
# Epoch 87/300
# 777/777 - 2s - loss: 0.2654 - acc: 0.9176 - auc_roc: 0.7122 - auc_pr: 0.3047 - val_loss: 0.3222 - val_acc: 0.9003 - val_auc_roc: 0.5621 - val_auc_pr: 0.1100
# Epoch 88/300
# 777/777 - 2s - loss: 0.2653 - acc: 0.9173 - auc_roc: 0.7073 - auc_pr: 0.3089 - val_loss: 0.3240 - val_acc: 0.9041 - val_auc_roc: 0.5307 - val_auc_pr: 0.1007
# Epoch 89/300
# 777/777 - 2s - loss: 0.2651 - acc: 0.9158 - auc_roc: 0.7101 - auc_pr: 0.3095 - val_loss: 0.3267 - val_acc: 0.9035 - val_auc_roc: 0.5446 - val_auc_pr: 0.1076
# Epoch 90/300
# 777/777 - 2s - loss: 0.2660 - acc: 0.9168 - auc_roc: 0.7092 - auc_pr: 0.3046 - val_loss: 0.3207 - val_acc: 0.9041 - val_auc_roc: 0.5572 - val_auc_pr: 0.1127
# Epoch 91/300
# 777/777 - 2s - loss: 0.2657 - acc: 0.9162 - auc_roc: 0.7123 - auc_pr: 0.3026 - val_loss: 0.3195 - val_acc: 0.9067 - val_auc_roc: 0.5552 - val_auc_pr: 0.1090
# Epoch 92/300
# 777/777 - 2s - loss: 0.2659 - acc: 0.9173 - auc_roc: 0.7109 - auc_pr: 0.3051 - val_loss: 0.3184 - val_acc: 0.9035 - val_auc_roc: 0.5526 - val_auc_pr: 0.1095
# Epoch 93/300
# 777/777 - 2s - loss: 0.2646 - acc: 0.9179 - auc_roc: 0.7071 - auc_pr: 0.3079 - val_loss: 0.3220 - val_acc: 0.9054 - val_auc_roc: 0.5494 - val_auc_pr: 0.1079
# Epoch 94/300
# 777/777 - 2s - loss: 0.2647 - acc: 0.9165 - auc_roc: 0.7135 - auc_pr: 0.3065 - val_loss: 0.3224 - val_acc: 0.9015 - val_auc_roc: 0.5698 - val_auc_pr: 0.1152
# Epoch 95/300
# 777/777 - 1s - loss: 0.2661 - acc: 0.9163 - auc_roc: 0.7119 - auc_pr: 0.2964 - val_loss: 0.3219 - val_acc: 0.9060 - val_auc_roc: 0.5673 - val_auc_pr: 0.1107
# Epoch 96/300
# 777/777 - 2s - loss: 0.2637 - acc: 0.9173 - auc_roc: 0.7126 - auc_pr: 0.3162 - val_loss: 0.3281 - val_acc: 0.9041 - val_auc_roc: 0.5613 - val_auc_pr: 0.1102
# Epoch 97/300
# 777/777 - 1s - loss: 0.2645 - acc: 0.9168 - auc_roc: 0.7161 - auc_pr: 0.3095 - val_loss: 0.3251 - val_acc: 0.9060 - val_auc_roc: 0.5515 - val_auc_pr: 0.1090
# Epoch 98/300
# 777/777 - 2s - loss: 0.2647 - acc: 0.9168 - auc_roc: 0.7196 - auc_pr: 0.3042 - val_loss: 0.3209 - val_acc: 0.9035 - val_auc_roc: 0.5649 - val_auc_pr: 0.1116
# Epoch 99/300
# 777/777 - 2s - loss: 0.2655 - acc: 0.9167 - auc_roc: 0.7092 - auc_pr: 0.3051 - val_loss: 0.3241 - val_acc: 0.9048 - val_auc_roc: 0.5408 - val_auc_pr: 0.1032
# Epoch 100/300
# 777/777 - 2s - loss: 0.2637 - acc: 0.9154 - auc_roc: 0.7183 - auc_pr: 0.3137 - val_loss: 0.3250 - val_acc: 0.9022 - val_auc_roc: 0.5590 - val_auc_pr: 0.1116
# Epoch 101/300
# 777/777 - 2s - loss: 0.2644 - acc: 0.9168 - auc_roc: 0.7196 - auc_pr: 0.3021 - val_loss: 0.3266 - val_acc: 0.9009 - val_auc_roc: 0.5571 - val_auc_pr: 0.1073
# Epoch 102/300
# 777/777 - 2s - loss: 0.2650 - acc: 0.9152 - auc_roc: 0.7183 - auc_pr: 0.2986 - val_loss: 0.3228 - val_acc: 0.9035 - val_auc_roc: 0.5598 - val_auc_pr: 0.1076
# Epoch 103/300
# 777/777 - 2s - loss: 0.2638 - acc: 0.9179 - auc_roc: 0.7125 - auc_pr: 0.3101 - val_loss: 0.3230 - val_acc: 0.9041 - val_auc_roc: 0.5493 - val_auc_pr: 0.1074
# Epoch 104/300
# 777/777 - 2s - loss: 0.2632 - acc: 0.9168 - auc_roc: 0.7137 - auc_pr: 0.3148 - val_loss: 0.3233 - val_acc: 0.9009 - val_auc_roc: 0.5532 - val_auc_pr: 0.1083
# Epoch 105/300
# 777/777 - 2s - loss: 0.2648 - acc: 0.9160 - auc_roc: 0.7192 - auc_pr: 0.3061 - val_loss: 0.3212 - val_acc: 0.9060 - val_auc_roc: 0.5618 - val_auc_pr: 0.1096
# Epoch 106/300
# 777/777 - 2s - loss: 0.2654 - acc: 0.9160 - auc_roc: 0.7112 - auc_pr: 0.3041 - val_loss: 0.3226 - val_acc: 0.9048 - val_auc_roc: 0.5555 - val_auc_pr: 0.1078
# Epoch 107/300
# 777/777 - 2s - loss: 0.2624 - acc: 0.9168 - auc_roc: 0.7175 - auc_pr: 0.3208 - val_loss: 0.3249 - val_acc: 0.9035 - val_auc_roc: 0.5682 - val_auc_pr: 0.1093
# Epoch 108/300
# 777/777 - 2s - loss: 0.2645 - acc: 0.9173 - auc_roc: 0.7120 - auc_pr: 0.3113 - val_loss: 0.3208 - val_acc: 0.9048 - val_auc_roc: 0.5545 - val_auc_pr: 0.1082
# Epoch 109/300
# 777/777 - 2s - loss: 0.2631 - acc: 0.9160 - auc_roc: 0.7171 - auc_pr: 0.3126 - val_loss: 0.3252 - val_acc: 0.9035 - val_auc_roc: 0.5543 - val_auc_pr: 0.1058
# Epoch 110/300
# 777/777 - 2s - loss: 0.2627 - acc: 0.9183 - auc_roc: 0.7105 - auc_pr: 0.3217 - val_loss: 0.3209 - val_acc: 0.9060 - val_auc_roc: 0.5600 - val_auc_pr: 0.1085
# Epoch 111/300
# 777/777 - 2s - loss: 0.2623 - acc: 0.9155 - auc_roc: 0.7188 - auc_pr: 0.3174 - val_loss: 0.3236 - val_acc: 0.9073 - val_auc_roc: 0.5576 - val_auc_pr: 0.1110
# Epoch 112/300
# 777/777 - 2s - loss: 0.2626 - acc: 0.9179 - auc_roc: 0.7178 - auc_pr: 0.3164 - val_loss: 0.3282 - val_acc: 0.9067 - val_auc_roc: 0.5402 - val_auc_pr: 0.1053
# Epoch 113/300
# 777/777 - 2s - loss: 0.2631 - acc: 0.9167 - auc_roc: 0.7155 - auc_pr: 0.3150 - val_loss: 0.3278 - val_acc: 0.8996 - val_auc_roc: 0.5541 - val_auc_pr: 0.1047
# Epoch 114/300
# 777/777 - 2s - loss: 0.2632 - acc: 0.9168 - auc_roc: 0.7153 - auc_pr: 0.3167 - val_loss: 0.3243 - val_acc: 0.9054 - val_auc_roc: 0.5571 - val_auc_pr: 0.1094
# Epoch 115/300
# 777/777 - 2s - loss: 0.2627 - acc: 0.9170 - auc_roc: 0.7196 - auc_pr: 0.3188 - val_loss: 0.3241 - val_acc: 0.9048 - val_auc_roc: 0.5548 - val_auc_pr: 0.1082
# Epoch 116/300
# 777/777 - 2s - loss: 0.2627 - acc: 0.9158 - auc_roc: 0.7237 - auc_pr: 0.3119 - val_loss: 0.3247 - val_acc: 0.9086 - val_auc_roc: 0.5443 - val_auc_pr: 0.1066
# Epoch 117/300
# 777/777 - 2s - loss: 0.2627 - acc: 0.9170 - auc_roc: 0.7162 - auc_pr: 0.3152 - val_loss: 0.3248 - val_acc: 0.9054 - val_auc_roc: 0.5440 - val_auc_pr: 0.1096
# Epoch 118/300
# 777/777 - 2s - loss: 0.2622 - acc: 0.9163 - auc_roc: 0.7229 - auc_pr: 0.3126 - val_loss: 0.3280 - val_acc: 0.9054 - val_auc_roc: 0.5462 - val_auc_pr: 0.1039
# Epoch 119/300
# 777/777 - 1s - loss: 0.2615 - acc: 0.9171 - auc_roc: 0.7257 - auc_pr: 0.3169 - val_loss: 0.3267 - val_acc: 0.8977 - val_auc_roc: 0.5515 - val_auc_pr: 0.1059
# Epoch 120/300
# 777/777 - 1s - loss: 0.2628 - acc: 0.9176 - auc_roc: 0.7141 - auc_pr: 0.3164 - val_loss: 0.3237 - val_acc: 0.9041 - val_auc_roc: 0.5581 - val_auc_pr: 0.1090
# Epoch 121/300
# 777/777 - 2s - loss: 0.2611 - acc: 0.9165 - auc_roc: 0.7241 - auc_pr: 0.3242 - val_loss: 0.3285 - val_acc: 0.9022 - val_auc_roc: 0.5552 - val_auc_pr: 0.1053
# Epoch 122/300
# 777/777 - 2s - loss: 0.2638 - acc: 0.9181 - auc_roc: 0.7119 - auc_pr: 0.3123 - val_loss: 0.3238 - val_acc: 0.9022 - val_auc_roc: 0.5642 - val_auc_pr: 0.1107
# Epoch 123/300
# 777/777 - 2s - loss: 0.2617 - acc: 0.9176 - auc_roc: 0.7244 - auc_pr: 0.3219 - val_loss: 0.3292 - val_acc: 0.9080 - val_auc_roc: 0.5503 - val_auc_pr: 0.1069
# Epoch 124/300
# 777/777 - 2s - loss: 0.2622 - acc: 0.9154 - auc_roc: 0.7257 - auc_pr: 0.3158 - val_loss: 0.3248 - val_acc: 0.9048 - val_auc_roc: 0.5562 - val_auc_pr: 0.1095
# Epoch 125/300
# 777/777 - 2s - loss: 0.2614 - acc: 0.9189 - auc_roc: 0.7242 - auc_pr: 0.3215 - val_loss: 0.3247 - val_acc: 0.9060 - val_auc_roc: 0.5370 - val_auc_pr: 0.1050
# Epoch 126/300
# 777/777 - 2s - loss: 0.2634 - acc: 0.9168 - auc_roc: 0.7193 - auc_pr: 0.3125 - val_loss: 0.3235 - val_acc: 0.9073 - val_auc_roc: 0.5434 - val_auc_pr: 0.1024
# Epoch 127/300
# 777/777 - 2s - loss: 0.2600 - acc: 0.9176 - auc_roc: 0.7252 - auc_pr: 0.3266 - val_loss: 0.3294 - val_acc: 0.9035 - val_auc_roc: 0.5483 - val_auc_pr: 0.1080
# Epoch 128/300
# 777/777 - 2s - loss: 0.2619 - acc: 0.9176 - auc_roc: 0.7243 - auc_pr: 0.3164 - val_loss: 0.3267 - val_acc: 0.9048 - val_auc_roc: 0.5540 - val_auc_pr: 0.1033
# Epoch 129/300
# 777/777 - 1s - loss: 0.2616 - acc: 0.9187 - auc_roc: 0.7191 - auc_pr: 0.3231 - val_loss: 0.3258 - val_acc: 0.9080 - val_auc_roc: 0.5337 - val_auc_pr: 0.1019
# Epoch 130/300
# 777/777 - 2s - loss: 0.2598 - acc: 0.9176 - auc_roc: 0.7270 - auc_pr: 0.3287 - val_loss: 0.3294 - val_acc: 0.9073 - val_auc_roc: 0.5364 - val_auc_pr: 0.1050
# Epoch 131/300
# 777/777 - 1s - loss: 0.2616 - acc: 0.9170 - auc_roc: 0.7204 - auc_pr: 0.3183 - val_loss: 0.3283 - val_acc: 0.9048 - val_auc_roc: 0.5630 - val_auc_pr: 0.1079
# Epoch 132/300
# 777/777 - 2s - loss: 0.2609 - acc: 0.9176 - auc_roc: 0.7277 - auc_pr: 0.3205 - val_loss: 0.3236 - val_acc: 0.9048 - val_auc_roc: 0.5559 - val_auc_pr: 0.1073
# Epoch 133/300
# 777/777 - 1s - loss: 0.2603 - acc: 0.9183 - auc_roc: 0.7297 - auc_pr: 0.3252 - val_loss: 0.3267 - val_acc: 0.9054 - val_auc_roc: 0.5499 - val_auc_pr: 0.1061
# Epoch 134/300
# 777/777 - 2s - loss: 0.2609 - acc: 0.9171 - auc_roc: 0.7258 - auc_pr: 0.3229 - val_loss: 0.3297 - val_acc: 0.9086 - val_auc_roc: 0.5432 - val_auc_pr: 0.1052
# Epoch 135/300
# 777/777 - 2s - loss: 0.2600 - acc: 0.9176 - auc_roc: 0.7239 - auc_pr: 0.3284 - val_loss: 0.3275 - val_acc: 0.8983 - val_auc_roc: 0.5628 - val_auc_pr: 0.1095
# Epoch 136/300
# 777/777 - 2s - loss: 0.2618 - acc: 0.9167 - auc_roc: 0.7199 - auc_pr: 0.3187 - val_loss: 0.3272 - val_acc: 0.9060 - val_auc_roc: 0.5537 - val_auc_pr: 0.1047
# Epoch 137/300
# 777/777 - 2s - loss: 0.2590 - acc: 0.9173 - auc_roc: 0.7283 - auc_pr: 0.3295 - val_loss: 0.3270 - val_acc: 0.9035 - val_auc_roc: 0.5551 - val_auc_pr: 0.1113
# Epoch 138/300
# 777/777 - 2s - loss: 0.2598 - acc: 0.9176 - auc_roc: 0.7308 - auc_pr: 0.3257 - val_loss: 0.3256 - val_acc: 0.9041 - val_auc_roc: 0.5557 - val_auc_pr: 0.1094
# Epoch 139/300
# 777/777 - 2s - loss: 0.2611 - acc: 0.9173 - auc_roc: 0.7252 - auc_pr: 0.3194 - val_loss: 0.3226 - val_acc: 0.9060 - val_auc_roc: 0.5589 - val_auc_pr: 0.1147
# Epoch 140/300
# 777/777 - 1s - loss: 0.2600 - acc: 0.9187 - auc_roc: 0.7210 - auc_pr: 0.3296 - val_loss: 0.3286 - val_acc: 0.9060 - val_auc_roc: 0.5495 - val_auc_pr: 0.1079
# Epoch 141/300
# 777/777 - 2s - loss: 0.2607 - acc: 0.9171 - auc_roc: 0.7260 - auc_pr: 0.3216 - val_loss: 0.3395 - val_acc: 0.9060 - val_auc_roc: 0.5492 - val_auc_pr: 0.1049
# Epoch 142/300
# 777/777 - 2s - loss: 0.2624 - acc: 0.9158 - auc_roc: 0.7254 - auc_pr: 0.3145 - val_loss: 0.3269 - val_acc: 0.9041 - val_auc_roc: 0.5460 - val_auc_pr: 0.1040
# Epoch 143/300
# 777/777 - 2s - loss: 0.2602 - acc: 0.9173 - auc_roc: 0.7272 - auc_pr: 0.3235 - val_loss: 0.3333 - val_acc: 0.9048 - val_auc_roc: 0.5468 - val_auc_pr: 0.1024
# Epoch 144/300
# 777/777 - 2s - loss: 0.2608 - acc: 0.9163 - auc_roc: 0.7304 - auc_pr: 0.3214 - val_loss: 0.3321 - val_acc: 0.9048 - val_auc_roc: 0.5480 - val_auc_pr: 0.1036
# Epoch 145/300
# 777/777 - 2s - loss: 0.2591 - acc: 0.9178 - auc_roc: 0.7300 - auc_pr: 0.3285 - val_loss: 0.3289 - val_acc: 0.9054 - val_auc_roc: 0.5535 - val_auc_pr: 0.1064
# Epoch 146/300
# 777/777 - 2s - loss: 0.2598 - acc: 0.9181 - auc_roc: 0.7239 - auc_pr: 0.3278 - val_loss: 0.3282 - val_acc: 0.9067 - val_auc_roc: 0.5431 - val_auc_pr: 0.1028
# Epoch 147/300
# 777/777 - 2s - loss: 0.2595 - acc: 0.9176 - auc_roc: 0.7303 - auc_pr: 0.3254 - val_loss: 0.3256 - val_acc: 0.9067 - val_auc_roc: 0.5601 - val_auc_pr: 0.1094
# Epoch 148/300
# 777/777 - 2s - loss: 0.2598 - acc: 0.9163 - auc_roc: 0.7310 - auc_pr: 0.3227 - val_loss: 0.3328 - val_acc: 0.9086 - val_auc_roc: 0.5502 - val_auc_pr: 0.1075
# Epoch 149/300
# 777/777 - 2s - loss: 0.2592 - acc: 0.9175 - auc_roc: 0.7328 - auc_pr: 0.3275 - val_loss: 0.3280 - val_acc: 0.9054 - val_auc_roc: 0.5563 - val_auc_pr: 0.1059
# Epoch 150/300
# 777/777 - 2s - loss: 0.2581 - acc: 0.9179 - auc_roc: 0.7295 - auc_pr: 0.3336 - val_loss: 0.3297 - val_acc: 0.9060 - val_auc_roc: 0.5497 - val_auc_pr: 0.1038
# Epoch 151/300
# 777/777 - 2s - loss: 0.2592 - acc: 0.9175 - auc_roc: 0.7314 - auc_pr: 0.3297 - val_loss: 0.3253 - val_acc: 0.9086 - val_auc_roc: 0.5511 - val_auc_pr: 0.1076
# Epoch 152/300
# 777/777 - 2s - loss: 0.2585 - acc: 0.9184 - auc_roc: 0.7315 - auc_pr: 0.3296 - val_loss: 0.3335 - val_acc: 0.9048 - val_auc_roc: 0.5482 - val_auc_pr: 0.1063
# Epoch 153/300
# 777/777 - 2s - loss: 0.2590 - acc: 0.9162 - auc_roc: 0.7357 - auc_pr: 0.3247 - val_loss: 0.3338 - val_acc: 0.9048 - val_auc_roc: 0.5425 - val_auc_pr: 0.1063
# Epoch 154/300
# 777/777 - 2s - loss: 0.2606 - acc: 0.9171 - auc_roc: 0.7301 - auc_pr: 0.3208 - val_loss: 0.3286 - val_acc: 0.9060 - val_auc_roc: 0.5511 - val_auc_pr: 0.1050
# Epoch 155/300
# 777/777 - 2s - loss: 0.2570 - acc: 0.9176 - auc_roc: 0.7348 - auc_pr: 0.3381 - val_loss: 0.3336 - val_acc: 0.9015 - val_auc_roc: 0.5636 - val_auc_pr: 0.1074
# Epoch 156/300
# 777/777 - 1s - loss: 0.2590 - acc: 0.9167 - auc_roc: 0.7318 - auc_pr: 0.3253 - val_loss: 0.3319 - val_acc: 0.9080 - val_auc_roc: 0.5602 - val_auc_pr: 0.1108
# Epoch 157/300
# 777/777 - 2s - loss: 0.2576 - acc: 0.9184 - auc_roc: 0.7296 - auc_pr: 0.3340 - val_loss: 0.3363 - val_acc: 0.9054 - val_auc_roc: 0.5473 - val_auc_pr: 0.1056
# Epoch 158/300
# 777/777 - 1s - loss: 0.2582 - acc: 0.9186 - auc_roc: 0.7271 - auc_pr: 0.3355 - val_loss: 0.3301 - val_acc: 0.9041 - val_auc_roc: 0.5540 - val_auc_pr: 0.1072
# Epoch 159/300
# 777/777 - 2s - loss: 0.2574 - acc: 0.9176 - auc_roc: 0.7347 - auc_pr: 0.3349 - val_loss: 0.3301 - val_acc: 0.9080 - val_auc_roc: 0.5587 - val_auc_pr: 0.1118
# Epoch 160/300
# 777/777 - 2s - loss: 0.2583 - acc: 0.9173 - auc_roc: 0.7371 - auc_pr: 0.3288 - val_loss: 0.3316 - val_acc: 0.8970 - val_auc_roc: 0.5732 - val_auc_pr: 0.1160
# Epoch 161/300
# 777/777 - 2s - loss: 0.2598 - acc: 0.9179 - auc_roc: 0.7277 - auc_pr: 0.3232 - val_loss: 0.3303 - val_acc: 0.9041 - val_auc_roc: 0.5478 - val_auc_pr: 0.1080
# Epoch 162/300
# 777/777 - 2s - loss: 0.2575 - acc: 0.9163 - auc_roc: 0.7322 - auc_pr: 0.3345 - val_loss: 0.3236 - val_acc: 0.9054 - val_auc_roc: 0.5584 - val_auc_pr: 0.1113
# Epoch 163/300
# 777/777 - 2s - loss: 0.2581 - acc: 0.9181 - auc_roc: 0.7352 - auc_pr: 0.3306 - val_loss: 0.3303 - val_acc: 0.9035 - val_auc_roc: 0.5597 - val_auc_pr: 0.1093
# Epoch 164/300
# 777/777 - 2s - loss: 0.2579 - acc: 0.9179 - auc_roc: 0.7315 - auc_pr: 0.3320 - val_loss: 0.3271 - val_acc: 0.9048 - val_auc_roc: 0.5648 - val_auc_pr: 0.1081
# Epoch 165/300
# 777/777 - 2s - loss: 0.2573 - acc: 0.9184 - auc_roc: 0.7302 - auc_pr: 0.3365 - val_loss: 0.3302 - val_acc: 0.9009 - val_auc_roc: 0.5597 - val_auc_pr: 0.1080
# Epoch 166/300
# 777/777 - 2s - loss: 0.2569 - acc: 0.9181 - auc_roc: 0.7354 - auc_pr: 0.3343 - val_loss: 0.3304 - val_acc: 0.9041 - val_auc_roc: 0.5479 - val_auc_pr: 0.1054
# Epoch 167/300
# 777/777 - 2s - loss: 0.2581 - acc: 0.9176 - auc_roc: 0.7316 - auc_pr: 0.3331 - val_loss: 0.3318 - val_acc: 0.9009 - val_auc_roc: 0.5590 - val_auc_pr: 0.1068
# Epoch 168/300
# 777/777 - 2s - loss: 0.2574 - acc: 0.9183 - auc_roc: 0.7361 - auc_pr: 0.3334 - val_loss: 0.3295 - val_acc: 0.9035 - val_auc_roc: 0.5367 - val_auc_pr: 0.1057
# Epoch 169/300
# 777/777 - 2s - loss: 0.2589 - acc: 0.9191 - auc_roc: 0.7289 - auc_pr: 0.3277 - val_loss: 0.3271 - val_acc: 0.9022 - val_auc_roc: 0.5487 - val_auc_pr: 0.1062
# Epoch 170/300
# 777/777 - 2s - loss: 0.2572 - acc: 0.9181 - auc_roc: 0.7367 - auc_pr: 0.3338 - val_loss: 0.3309 - val_acc: 0.9028 - val_auc_roc: 0.5614 - val_auc_pr: 0.1095
# Epoch 171/300
# 777/777 - 2s - loss: 0.2588 - acc: 0.9168 - auc_roc: 0.7319 - auc_pr: 0.3270 - val_loss: 0.3341 - val_acc: 0.9022 - val_auc_roc: 0.5487 - val_auc_pr: 0.1042
# Epoch 172/300
# 777/777 - 2s - loss: 0.2551 - acc: 0.9189 - auc_roc: 0.7481 - auc_pr: 0.3392 - val_loss: 0.3329 - val_acc: 0.9015 - val_auc_roc: 0.5491 - val_auc_pr: 0.1089
# Epoch 173/300
# 777/777 - 2s - loss: 0.2563 - acc: 0.9181 - auc_roc: 0.7417 - auc_pr: 0.3324 - val_loss: 0.3318 - val_acc: 0.9009 - val_auc_roc: 0.5722 - val_auc_pr: 0.1091
# Epoch 174/300
# 777/777 - 2s - loss: 0.2582 - acc: 0.9173 - auc_roc: 0.7289 - auc_pr: 0.3327 - val_loss: 0.3301 - val_acc: 0.9015 - val_auc_roc: 0.5568 - val_auc_pr: 0.1091
# Epoch 175/300
# 777/777 - 2s - loss: 0.2569 - acc: 0.9176 - auc_roc: 0.7363 - auc_pr: 0.3359 - val_loss: 0.3332 - val_acc: 0.9048 - val_auc_roc: 0.5497 - val_auc_pr: 0.1073
# Epoch 176/300
# 777/777 - 1s - loss: 0.2566 - acc: 0.9183 - auc_roc: 0.7337 - auc_pr: 0.3339 - val_loss: 0.3351 - val_acc: 0.9009 - val_auc_roc: 0.5467 - val_auc_pr: 0.1092
# Epoch 177/300
# 777/777 - 2s - loss: 0.2576 - acc: 0.9181 - auc_roc: 0.7309 - auc_pr: 0.3359 - val_loss: 0.3288 - val_acc: 0.9015 - val_auc_roc: 0.5509 - val_auc_pr: 0.1099
# Epoch 178/300
# 777/777 - 2s - loss: 0.2562 - acc: 0.9178 - auc_roc: 0.7432 - auc_pr: 0.3368 - val_loss: 0.3381 - val_acc: 0.9073 - val_auc_roc: 0.5442 - val_auc_pr: 0.1066
# Epoch 179/300
# 777/777 - 2s - loss: 0.2575 - acc: 0.9170 - auc_roc: 0.7383 - auc_pr: 0.3300 - val_loss: 0.3377 - val_acc: 0.9067 - val_auc_roc: 0.5438 - val_auc_pr: 0.1103
# Epoch 180/300
# 777/777 - 2s - loss: 0.2570 - acc: 0.9163 - auc_roc: 0.7400 - auc_pr: 0.3326 - val_loss: 0.3294 - val_acc: 0.9054 - val_auc_roc: 0.5600 - val_auc_pr: 0.1123
# Epoch 181/300
# 777/777 - 2s - loss: 0.2562 - acc: 0.9192 - auc_roc: 0.7371 - auc_pr: 0.3402 - val_loss: 0.3323 - val_acc: 0.9086 - val_auc_roc: 0.5555 - val_auc_pr: 0.1132
# Epoch 182/300
# 777/777 - 2s - loss: 0.2549 - acc: 0.9173 - auc_roc: 0.7462 - auc_pr: 0.3399 - val_loss: 0.3334 - val_acc: 0.9054 - val_auc_roc: 0.5521 - val_auc_pr: 0.1082
# Epoch 183/300
# 777/777 - 2s - loss: 0.2571 - acc: 0.9179 - auc_roc: 0.7349 - auc_pr: 0.3303 - val_loss: 0.3334 - val_acc: 0.9035 - val_auc_roc: 0.5616 - val_auc_pr: 0.1118
# Epoch 184/300
# 777/777 - 2s - loss: 0.2571 - acc: 0.9176 - auc_roc: 0.7314 - auc_pr: 0.3379 - val_loss: 0.3352 - val_acc: 0.9086 - val_auc_roc: 0.5608 - val_auc_pr: 0.1088
# Epoch 185/300
# 777/777 - 2s - loss: 0.2556 - acc: 0.9179 - auc_roc: 0.7422 - auc_pr: 0.3372 - val_loss: 0.3367 - val_acc: 0.9009 - val_auc_roc: 0.5528 - val_auc_pr: 0.1122
# Epoch 186/300
# 777/777 - 1s - loss: 0.2553 - acc: 0.9178 - auc_roc: 0.7448 - auc_pr: 0.3390 - val_loss: 0.3348 - val_acc: 0.9041 - val_auc_roc: 0.5555 - val_auc_pr: 0.1068
# Epoch 187/300
# 777/777 - 2s - loss: 0.2568 - acc: 0.9181 - auc_roc: 0.7396 - auc_pr: 0.3342 - val_loss: 0.3374 - val_acc: 0.9028 - val_auc_roc: 0.5552 - val_auc_pr: 0.1063
# Epoch 188/300
# 777/777 - 2s - loss: 0.2569 - acc: 0.9175 - auc_roc: 0.7439 - auc_pr: 0.3337 - val_loss: 0.3314 - val_acc: 0.9035 - val_auc_roc: 0.5559 - val_auc_pr: 0.1063
# Epoch 189/300
# 777/777 - 2s - loss: 0.2554 - acc: 0.9191 - auc_roc: 0.7417 - auc_pr: 0.3406 - val_loss: 0.3432 - val_acc: 0.9086 - val_auc_roc: 0.5609 - val_auc_pr: 0.1126
# Epoch 190/300
# 777/777 - 2s - loss: 0.2561 - acc: 0.9179 - auc_roc: 0.7417 - auc_pr: 0.3327 - val_loss: 0.3342 - val_acc: 0.9022 - val_auc_roc: 0.5666 - val_auc_pr: 0.1145
# Epoch 191/300
# 777/777 - 2s - loss: 0.2563 - acc: 0.9175 - auc_roc: 0.7367 - auc_pr: 0.3391 - val_loss: 0.3343 - val_acc: 0.9054 - val_auc_roc: 0.5547 - val_auc_pr: 0.1112
# Epoch 192/300
# 777/777 - 1s - loss: 0.2557 - acc: 0.9186 - auc_roc: 0.7391 - auc_pr: 0.3404 - val_loss: 0.3382 - val_acc: 0.9041 - val_auc_roc: 0.5537 - val_auc_pr: 0.1089
# Epoch 193/300
# 777/777 - 1s - loss: 0.2544 - acc: 0.9191 - auc_roc: 0.7417 - auc_pr: 0.3452 - val_loss: 0.3374 - val_acc: 0.9054 - val_auc_roc: 0.5531 - val_auc_pr: 0.1083
# Epoch 194/300
# 777/777 - 2s - loss: 0.2534 - acc: 0.9183 - auc_roc: 0.7447 - auc_pr: 0.3513 - val_loss: 0.3329 - val_acc: 0.9003 - val_auc_roc: 0.5577 - val_auc_pr: 0.1094
# Epoch 195/300
# 777/777 - 2s - loss: 0.2542 - acc: 0.9186 - auc_roc: 0.7449 - auc_pr: 0.3465 - val_loss: 0.3433 - val_acc: 0.9060 - val_auc_roc: 0.5503 - val_auc_pr: 0.1056
# Epoch 196/300
# 777/777 - 2s - loss: 0.2568 - acc: 0.9170 - auc_roc: 0.7440 - auc_pr: 0.3313 - val_loss: 0.3387 - val_acc: 0.9060 - val_auc_roc: 0.5514 - val_auc_pr: 0.1080
# Epoch 197/300
# 777/777 - 2s - loss: 0.2554 - acc: 0.9175 - auc_roc: 0.7425 - auc_pr: 0.3384 - val_loss: 0.3396 - val_acc: 0.9048 - val_auc_roc: 0.5428 - val_auc_pr: 0.1065
# Epoch 198/300
# 777/777 - 2s - loss: 0.2550 - acc: 0.9183 - auc_roc: 0.7423 - auc_pr: 0.3418 - val_loss: 0.3408 - val_acc: 0.9067 - val_auc_roc: 0.5463 - val_auc_pr: 0.1084
# Epoch 199/300
# 777/777 - 2s - loss: 0.2550 - acc: 0.9195 - auc_roc: 0.7434 - auc_pr: 0.3394 - val_loss: 0.3424 - val_acc: 0.9041 - val_auc_roc: 0.5539 - val_auc_pr: 0.1073
# Epoch 200/300
# 777/777 - 2s - loss: 0.2555 - acc: 0.9191 - auc_roc: 0.7376 - auc_pr: 0.3430 - val_loss: 0.3416 - val_acc: 0.9022 - val_auc_roc: 0.5515 - val_auc_pr: 0.1086
# Epoch 201/300
# 777/777 - 1s - loss: 0.2557 - acc: 0.9181 - auc_roc: 0.7394 - auc_pr: 0.3356 - val_loss: 0.3360 - val_acc: 0.9054 - val_auc_roc: 0.5469 - val_auc_pr: 0.1103
# Epoch 202/300
# 777/777 - 2s - loss: 0.2557 - acc: 0.9179 - auc_roc: 0.7409 - auc_pr: 0.3395 - val_loss: 0.3351 - val_acc: 0.9080 - val_auc_roc: 0.5517 - val_auc_pr: 0.1069
# Epoch 203/300
# 777/777 - 2s - loss: 0.2546 - acc: 0.9184 - auc_roc: 0.7496 - auc_pr: 0.3445 - val_loss: 0.3383 - val_acc: 0.9015 - val_auc_roc: 0.5507 - val_auc_pr: 0.1060
# Epoch 204/300
# 777/777 - 2s - loss: 0.2546 - acc: 0.9171 - auc_roc: 0.7428 - auc_pr: 0.3419 - val_loss: 0.3422 - val_acc: 0.9067 - val_auc_roc: 0.5543 - val_auc_pr: 0.1098
# Epoch 205/300
# 777/777 - 2s - loss: 0.2550 - acc: 0.9199 - auc_roc: 0.7419 - auc_pr: 0.3433 - val_loss: 0.3371 - val_acc: 0.9041 - val_auc_roc: 0.5521 - val_auc_pr: 0.1104
# Epoch 206/300
# 777/777 - 1s - loss: 0.2534 - acc: 0.9183 - auc_roc: 0.7479 - auc_pr: 0.3447 - val_loss: 0.3416 - val_acc: 0.9041 - val_auc_roc: 0.5591 - val_auc_pr: 0.1114
# Epoch 207/300
# 777/777 - 2s - loss: 0.2552 - acc: 0.9175 - auc_roc: 0.7383 - auc_pr: 0.3404 - val_loss: 0.3455 - val_acc: 0.9060 - val_auc_roc: 0.5838 - val_auc_pr: 0.1209
# Epoch 208/300
# 777/777 - 2s - loss: 0.2555 - acc: 0.9167 - auc_roc: 0.7418 - auc_pr: 0.3429 - val_loss: 0.3388 - val_acc: 0.9073 - val_auc_roc: 0.5571 - val_auc_pr: 0.1086
# Epoch 209/300
# 777/777 - 1s - loss: 0.2539 - acc: 0.9181 - auc_roc: 0.7504 - auc_pr: 0.3429 - val_loss: 0.3402 - val_acc: 0.9022 - val_auc_roc: 0.5498 - val_auc_pr: 0.1097
# Epoch 210/300
# 777/777 - 1s - loss: 0.2532 - acc: 0.9184 - auc_roc: 0.7512 - auc_pr: 0.3481 - val_loss: 0.3406 - val_acc: 0.9067 - val_auc_roc: 0.5659 - val_auc_pr: 0.1121
# Epoch 211/300
# 777/777 - 2s - loss: 0.2548 - acc: 0.9171 - auc_roc: 0.7496 - auc_pr: 0.3384 - val_loss: 0.3403 - val_acc: 0.9054 - val_auc_roc: 0.5498 - val_auc_pr: 0.1075
# Epoch 212/300
# 777/777 - 2s - loss: 0.2529 - acc: 0.9189 - auc_roc: 0.7521 - auc_pr: 0.3474 - val_loss: 0.3441 - val_acc: 0.9048 - val_auc_roc: 0.5721 - val_auc_pr: 0.1140
# Epoch 213/300
# 777/777 - 2s - loss: 0.2530 - acc: 0.9187 - auc_roc: 0.7497 - auc_pr: 0.3513 - val_loss: 0.3448 - val_acc: 0.9054 - val_auc_roc: 0.5528 - val_auc_pr: 0.1084
# Epoch 214/300
# 777/777 - 2s - loss: 0.2548 - acc: 0.9187 - auc_roc: 0.7429 - auc_pr: 0.3413 - val_loss: 0.3433 - val_acc: 0.9073 - val_auc_roc: 0.5471 - val_auc_pr: 0.1077
# Epoch 215/300
# 777/777 - 2s - loss: 0.2541 - acc: 0.9176 - auc_roc: 0.7474 - auc_pr: 0.3457 - val_loss: 0.3380 - val_acc: 0.9060 - val_auc_roc: 0.5643 - val_auc_pr: 0.1157
# Epoch 216/300
# 777/777 - 2s - loss: 0.2546 - acc: 0.9178 - auc_roc: 0.7456 - auc_pr: 0.3457 - val_loss: 0.3367 - val_acc: 0.8983 - val_auc_roc: 0.5643 - val_auc_pr: 0.1151
# Epoch 217/300
# 777/777 - 2s - loss: 0.2547 - acc: 0.9179 - auc_roc: 0.7477 - auc_pr: 0.3415 - val_loss: 0.3328 - val_acc: 0.9054 - val_auc_roc: 0.5578 - val_auc_pr: 0.1096
# Epoch 218/300
# 777/777 - 2s - loss: 0.2544 - acc: 0.9183 - auc_roc: 0.7448 - auc_pr: 0.3437 - val_loss: 0.3383 - val_acc: 0.9028 - val_auc_roc: 0.5502 - val_auc_pr: 0.1077
# Epoch 219/300
# 777/777 - 2s - loss: 0.2531 - acc: 0.9187 - auc_roc: 0.7500 - auc_pr: 0.3509 - val_loss: 0.3392 - val_acc: 0.9015 - val_auc_roc: 0.5597 - val_auc_pr: 0.1120
# Epoch 220/300
# 777/777 - 2s - loss: 0.2539 - acc: 0.9189 - auc_roc: 0.7482 - auc_pr: 0.3476 - val_loss: 0.3411 - val_acc: 0.9060 - val_auc_roc: 0.5499 - val_auc_pr: 0.1105
# Epoch 221/300
# 777/777 - 2s - loss: 0.2529 - acc: 0.9187 - auc_roc: 0.7498 - auc_pr: 0.3490 - val_loss: 0.3384 - val_acc: 0.9060 - val_auc_roc: 0.5487 - val_auc_pr: 0.1101
# Epoch 222/300
# 777/777 - 2s - loss: 0.2532 - acc: 0.9187 - auc_roc: 0.7482 - auc_pr: 0.3498 - val_loss: 0.3403 - val_acc: 0.9086 - val_auc_roc: 0.5482 - val_auc_pr: 0.1080
# Epoch 223/300
# 777/777 - 2s - loss: 0.2531 - acc: 0.9191 - auc_roc: 0.7503 - auc_pr: 0.3528 - val_loss: 0.3409 - val_acc: 0.9022 - val_auc_roc: 0.5538 - val_auc_pr: 0.1084
# Epoch 224/300
# 777/777 - 2s - loss: 0.2544 - acc: 0.9175 - auc_roc: 0.7450 - auc_pr: 0.3461 - val_loss: 0.3333 - val_acc: 0.9028 - val_auc_roc: 0.5667 - val_auc_pr: 0.1178
# Epoch 225/300
# 777/777 - 2s - loss: 0.2528 - acc: 0.9200 - auc_roc: 0.7478 - auc_pr: 0.3561 - val_loss: 0.3416 - val_acc: 0.9028 - val_auc_roc: 0.5609 - val_auc_pr: 0.1140
# Epoch 226/300
# 777/777 - 2s - loss: 0.2539 - acc: 0.9179 - auc_roc: 0.7441 - auc_pr: 0.3491 - val_loss: 0.3403 - val_acc: 0.9048 - val_auc_roc: 0.5608 - val_auc_pr: 0.1151
# Epoch 227/300
# 777/777 - 2s - loss: 0.2535 - acc: 0.9191 - auc_roc: 0.7464 - auc_pr: 0.3485 - val_loss: 0.3431 - val_acc: 0.8983 - val_auc_roc: 0.5505 - val_auc_pr: 0.1103
# Epoch 228/300
# 777/777 - 2s - loss: 0.2545 - acc: 0.9179 - auc_roc: 0.7496 - auc_pr: 0.3399 - val_loss: 0.3415 - val_acc: 0.9067 - val_auc_roc: 0.5618 - val_auc_pr: 0.1114
# Epoch 229/300
# 777/777 - 1s - loss: 0.2526 - acc: 0.9189 - auc_roc: 0.7502 - auc_pr: 0.3516 - val_loss: 0.3415 - val_acc: 0.9035 - val_auc_roc: 0.5504 - val_auc_pr: 0.1123
# Epoch 230/300
# 777/777 - 2s - loss: 0.2525 - acc: 0.9184 - auc_roc: 0.7506 - auc_pr: 0.3521 - val_loss: 0.3440 - val_acc: 0.9003 - val_auc_roc: 0.5596 - val_auc_pr: 0.1116
# Epoch 231/300
# 777/777 - 2s - loss: 0.2528 - acc: 0.9179 - auc_roc: 0.7522 - auc_pr: 0.3473 - val_loss: 0.3396 - val_acc: 0.9035 - val_auc_roc: 0.5512 - val_auc_pr: 0.1110
# Epoch 232/300
# 777/777 - 2s - loss: 0.2530 - acc: 0.9184 - auc_roc: 0.7454 - auc_pr: 0.3509 - val_loss: 0.3460 - val_acc: 0.9015 - val_auc_roc: 0.5599 - val_auc_pr: 0.1112
# Epoch 233/300
# 777/777 - 1s - loss: 0.2530 - acc: 0.9179 - auc_roc: 0.7491 - auc_pr: 0.3488 - val_loss: 0.3452 - val_acc: 0.9003 - val_auc_roc: 0.5603 - val_auc_pr: 0.1103
# Epoch 234/300
# 777/777 - 2s - loss: 0.2518 - acc: 0.9195 - auc_roc: 0.7514 - auc_pr: 0.3551 - val_loss: 0.3425 - val_acc: 0.9073 - val_auc_roc: 0.5569 - val_auc_pr: 0.1128
# Epoch 235/300
# 777/777 - 2s - loss: 0.2540 - acc: 0.9178 - auc_roc: 0.7478 - auc_pr: 0.3445 - val_loss: 0.3453 - val_acc: 0.9048 - val_auc_roc: 0.5451 - val_auc_pr: 0.1056
# Epoch 236/300
# 777/777 - 2s - loss: 0.2526 - acc: 0.9192 - auc_roc: 0.7439 - auc_pr: 0.3527 - val_loss: 0.3511 - val_acc: 0.9009 - val_auc_roc: 0.5535 - val_auc_pr: 0.1076
# Epoch 237/300
# 777/777 - 2s - loss: 0.2532 - acc: 0.9183 - auc_roc: 0.7449 - auc_pr: 0.3532 - val_loss: 0.3419 - val_acc: 0.8990 - val_auc_roc: 0.5563 - val_auc_pr: 0.1084
# Epoch 238/300
# 777/777 - 2s - loss: 0.2536 - acc: 0.9186 - auc_roc: 0.7514 - auc_pr: 0.3435 - val_loss: 0.3407 - val_acc: 0.9028 - val_auc_roc: 0.5535 - val_auc_pr: 0.1077
# Epoch 239/300
# 777/777 - 2s - loss: 0.2528 - acc: 0.9195 - auc_roc: 0.7493 - auc_pr: 0.3498 - val_loss: 0.3462 - val_acc: 0.9054 - val_auc_roc: 0.5510 - val_auc_pr: 0.1094
# Epoch 240/300
# 777/777 - 2s - loss: 0.2534 - acc: 0.9178 - auc_roc: 0.7441 - auc_pr: 0.3485 - val_loss: 0.3374 - val_acc: 0.9003 - val_auc_roc: 0.5661 - val_auc_pr: 0.1124
# Epoch 241/300
# 777/777 - 1s - loss: 0.2510 - acc: 0.9178 - auc_roc: 0.7536 - auc_pr: 0.3595 - val_loss: 0.3534 - val_acc: 0.9028 - val_auc_roc: 0.5411 - val_auc_pr: 0.1080
# Epoch 242/300
# 777/777 - 2s - loss: 0.2525 - acc: 0.9178 - auc_roc: 0.7512 - auc_pr: 0.3536 - val_loss: 0.3420 - val_acc: 0.9041 - val_auc_roc: 0.5661 - val_auc_pr: 0.1135
# Epoch 243/300
# 777/777 - 1s - loss: 0.2528 - acc: 0.9184 - auc_roc: 0.7504 - auc_pr: 0.3514 - val_loss: 0.3374 - val_acc: 0.9028 - val_auc_roc: 0.5632 - val_auc_pr: 0.1156
# Epoch 244/300
# 777/777 - 2s - loss: 0.2529 - acc: 0.9189 - auc_roc: 0.7516 - auc_pr: 0.3494 - val_loss: 0.3405 - val_acc: 0.9028 - val_auc_roc: 0.5675 - val_auc_pr: 0.1184
# Epoch 245/300
# 777/777 - 2s - loss: 0.2511 - acc: 0.9194 - auc_roc: 0.7540 - auc_pr: 0.3614 - val_loss: 0.3477 - val_acc: 0.9028 - val_auc_roc: 0.5630 - val_auc_pr: 0.1170
# Epoch 246/300
# 777/777 - 2s - loss: 0.2539 - acc: 0.9192 - auc_roc: 0.7432 - auc_pr: 0.3497 - val_loss: 0.3419 - val_acc: 0.9028 - val_auc_roc: 0.5489 - val_auc_pr: 0.1107
# Epoch 247/300
# 777/777 - 2s - loss: 0.2526 - acc: 0.9197 - auc_roc: 0.7478 - auc_pr: 0.3501 - val_loss: 0.3387 - val_acc: 0.9015 - val_auc_roc: 0.5677 - val_auc_pr: 0.1187
# Epoch 248/300
# 777/777 - 2s - loss: 0.2529 - acc: 0.9187 - auc_roc: 0.7506 - auc_pr: 0.3474 - val_loss: 0.3431 - val_acc: 0.9028 - val_auc_roc: 0.5652 - val_auc_pr: 0.1119
# Epoch 249/300
# 777/777 - 1s - loss: 0.2532 - acc: 0.9181 - auc_roc: 0.7549 - auc_pr: 0.3499 - val_loss: 0.3378 - val_acc: 0.8983 - val_auc_roc: 0.5658 - val_auc_pr: 0.1130
# Epoch 250/300
# 777/777 - 2s - loss: 0.2518 - acc: 0.9189 - auc_roc: 0.7499 - auc_pr: 0.3551 - val_loss: 0.3400 - val_acc: 0.8996 - val_auc_roc: 0.5620 - val_auc_pr: 0.1126
# Epoch 251/300
# 777/777 - 2s - loss: 0.2523 - acc: 0.9183 - auc_roc: 0.7487 - auc_pr: 0.3510 - val_loss: 0.3394 - val_acc: 0.9022 - val_auc_roc: 0.5477 - val_auc_pr: 0.1084
# Epoch 252/300
# 777/777 - 2s - loss: 0.2517 - acc: 0.9184 - auc_roc: 0.7536 - auc_pr: 0.3526 - val_loss: 0.3505 - val_acc: 0.8996 - val_auc_roc: 0.5581 - val_auc_pr: 0.1123
# Epoch 253/300
# 777/777 - 2s - loss: 0.2521 - acc: 0.9179 - auc_roc: 0.7525 - auc_pr: 0.3518 - val_loss: 0.3468 - val_acc: 0.9015 - val_auc_roc: 0.5579 - val_auc_pr: 0.1127
# Epoch 254/300
# 777/777 - 2s - loss: 0.2504 - acc: 0.9197 - auc_roc: 0.7541 - auc_pr: 0.3609 - val_loss: 0.3477 - val_acc: 0.9022 - val_auc_roc: 0.5545 - val_auc_pr: 0.1127
# Epoch 255/300
# 777/777 - 2s - loss: 0.2508 - acc: 0.9197 - auc_roc: 0.7546 - auc_pr: 0.3573 - val_loss: 0.3432 - val_acc: 0.9041 - val_auc_roc: 0.5562 - val_auc_pr: 0.1128
# Epoch 256/300
# 777/777 - 2s - loss: 0.2524 - acc: 0.9192 - auc_roc: 0.7489 - auc_pr: 0.3540 - val_loss: 0.3406 - val_acc: 0.9028 - val_auc_roc: 0.5516 - val_auc_pr: 0.1112
# Epoch 257/300
# 777/777 - 2s - loss: 0.2518 - acc: 0.9187 - auc_roc: 0.7514 - auc_pr: 0.3552 - val_loss: 0.3465 - val_acc: 0.9028 - val_auc_roc: 0.5567 - val_auc_pr: 0.1114
# Epoch 258/300
# 777/777 - 2s - loss: 0.2534 - acc: 0.9184 - auc_roc: 0.7476 - auc_pr: 0.3465 - val_loss: 0.3438 - val_acc: 0.9035 - val_auc_roc: 0.5479 - val_auc_pr: 0.1096
# Epoch 259/300
# 777/777 - 2s - loss: 0.2524 - acc: 0.9195 - auc_roc: 0.7479 - auc_pr: 0.3499 - val_loss: 0.3467 - val_acc: 0.8983 - val_auc_roc: 0.5486 - val_auc_pr: 0.1097
# Epoch 260/300
# 777/777 - 2s - loss: 0.2510 - acc: 0.9187 - auc_roc: 0.7556 - auc_pr: 0.3601 - val_loss: 0.3485 - val_acc: 0.9015 - val_auc_roc: 0.5562 - val_auc_pr: 0.1094
# Epoch 261/300
# 777/777 - 2s - loss: 0.2536 - acc: 0.9187 - auc_roc: 0.7452 - auc_pr: 0.3574 - val_loss: 0.3427 - val_acc: 0.9015 - val_auc_roc: 0.5583 - val_auc_pr: 0.1122
# Epoch 262/300
# 777/777 - 2s - loss: 0.2508 - acc: 0.9202 - auc_roc: 0.7533 - auc_pr: 0.3577 - val_loss: 0.3529 - val_acc: 0.9015 - val_auc_roc: 0.5526 - val_auc_pr: 0.1103
# Epoch 263/300
# 777/777 - 2s - loss: 0.2528 - acc: 0.9186 - auc_roc: 0.7521 - auc_pr: 0.3516 - val_loss: 0.3476 - val_acc: 0.9048 - val_auc_roc: 0.5479 - val_auc_pr: 0.1099
# Epoch 264/300
# 777/777 - 2s - loss: 0.2508 - acc: 0.9192 - auc_roc: 0.7524 - auc_pr: 0.3570 - val_loss: 0.3493 - val_acc: 0.9048 - val_auc_roc: 0.5500 - val_auc_pr: 0.1091
# Epoch 265/300
# 777/777 - 2s - loss: 0.2527 - acc: 0.9186 - auc_roc: 0.7458 - auc_pr: 0.3526 - val_loss: 0.3446 - val_acc: 0.9022 - val_auc_roc: 0.5536 - val_auc_pr: 0.1123
# Epoch 266/300
# 777/777 - 2s - loss: 0.2521 - acc: 0.9184 - auc_roc: 0.7528 - auc_pr: 0.3537 - val_loss: 0.3468 - val_acc: 0.9060 - val_auc_roc: 0.5611 - val_auc_pr: 0.1143
# Epoch 267/300
# 777/777 - 2s - loss: 0.2505 - acc: 0.9208 - auc_roc: 0.7515 - auc_pr: 0.3592 - val_loss: 0.3642 - val_acc: 0.9067 - val_auc_roc: 0.5498 - val_auc_pr: 0.1117
# Epoch 268/300
# 777/777 - 2s - loss: 0.2505 - acc: 0.9199 - auc_roc: 0.7577 - auc_pr: 0.3563 - val_loss: 0.3575 - val_acc: 0.9015 - val_auc_roc: 0.5518 - val_auc_pr: 0.1167
# Epoch 269/300
# 777/777 - 2s - loss: 0.2507 - acc: 0.9197 - auc_roc: 0.7529 - auc_pr: 0.3574 - val_loss: 0.3450 - val_acc: 0.9054 - val_auc_roc: 0.5461 - val_auc_pr: 0.1096
# Epoch 270/300
# 777/777 - 2s - loss: 0.2520 - acc: 0.9194 - auc_roc: 0.7505 - auc_pr: 0.3537 - val_loss: 0.3563 - val_acc: 0.8983 - val_auc_roc: 0.5535 - val_auc_pr: 0.1134
# Epoch 271/300
# 777/777 - 2s - loss: 0.2515 - acc: 0.9197 - auc_roc: 0.7494 - auc_pr: 0.3558 - val_loss: 0.3628 - val_acc: 0.9022 - val_auc_roc: 0.5464 - val_auc_pr: 0.1056
# Epoch 272/300
# 777/777 - 2s - loss: 0.2515 - acc: 0.9192 - auc_roc: 0.7525 - auc_pr: 0.3557 - val_loss: 0.3484 - val_acc: 0.8996 - val_auc_roc: 0.5514 - val_auc_pr: 0.1126
# Epoch 273/300
# 777/777 - 2s - loss: 0.2532 - acc: 0.9189 - auc_roc: 0.7472 - auc_pr: 0.3473 - val_loss: 0.3544 - val_acc: 0.9022 - val_auc_roc: 0.5430 - val_auc_pr: 0.1077
# Epoch 274/300
# 777/777 - 2s - loss: 0.2522 - acc: 0.9176 - auc_roc: 0.7528 - auc_pr: 0.3516 - val_loss: 0.3520 - val_acc: 0.9060 - val_auc_roc: 0.5369 - val_auc_pr: 0.1069
# Epoch 275/300
# 777/777 - 2s - loss: 0.2509 - acc: 0.9195 - auc_roc: 0.7533 - auc_pr: 0.3565 - val_loss: 0.3534 - val_acc: 0.9009 - val_auc_roc: 0.5471 - val_auc_pr: 0.1103
# Epoch 276/300
# 777/777 - 2s - loss: 0.2513 - acc: 0.9181 - auc_roc: 0.7502 - auc_pr: 0.3564 - val_loss: 0.3473 - val_acc: 0.9048 - val_auc_roc: 0.5594 - val_auc_pr: 0.1123
# Epoch 277/300
# 777/777 - 2s - loss: 0.2526 - acc: 0.9184 - auc_roc: 0.7514 - auc_pr: 0.3488 - val_loss: 0.3575 - val_acc: 0.9009 - val_auc_roc: 0.5581 - val_auc_pr: 0.1110
# Epoch 278/300
# 777/777 - 2s - loss: 0.2519 - acc: 0.9187 - auc_roc: 0.7510 - auc_pr: 0.3527 - val_loss: 0.3559 - val_acc: 0.9015 - val_auc_roc: 0.5475 - val_auc_pr: 0.1077
# Epoch 279/300
# 777/777 - 2s - loss: 0.2503 - acc: 0.9200 - auc_roc: 0.7533 - auc_pr: 0.3594 - val_loss: 0.3502 - val_acc: 0.9022 - val_auc_roc: 0.5502 - val_auc_pr: 0.1096
# Epoch 280/300
# 777/777 - 1s - loss: 0.2518 - acc: 0.9184 - auc_roc: 0.7554 - auc_pr: 0.3509 - val_loss: 0.3553 - val_acc: 0.8990 - val_auc_roc: 0.5571 - val_auc_pr: 0.1151
# Epoch 281/300
# ...
# Epoch 214/300
# 777/777 - 2s - loss: 0.2537 - acc: 0.9181 - auc_roc: 0.7494 - auc_pr: 0.3449 - val_loss: 0.3579 - val_acc: 0.9086 - val_auc_roc: 0.5248 - val_auc_pr: 0.1147
# Epoch 215/300
# 777/777 - 2s - loss: 0.2525 - acc: 0.9199 - auc_roc: 0.7479 - auc_pr: 0.3523 - val_loss: 0.3582 - val_acc: 0.9047 - val_auc_roc: 0.5217 - val_auc_pr: 0.1182
# Epoch 216/300
# 777/777 - 2s - loss: 0.2531 - acc: 0.9191 - auc_roc: 0.7469 - auc_pr: 0.3510 - val_loss: 0.3590 - val_acc: 0.9060 - val_auc_roc: 0.5103 - val_auc_pr: 0.1169
# Epoch 217/300
# 777/777 - 2s - loss: 0.2516 - acc: 0.9197 - auc_roc: 0.7543 - auc_pr: 0.3573 - val_loss: 0.3590 - val_acc: 0.9073 - val_auc_roc: 0.5207 - val_auc_pr: 0.1111
# Epoch 218/300
# 777/777 - 2s - loss: 0.2526 - acc: 0.9194 - auc_roc: 0.7470 - auc_pr: 0.3526 - val_loss: 0.3621 - val_acc: 0.9060 - val_auc_roc: 0.5275 - val_auc_pr: 0.1136
# Epoch 219/300
# 777/777 - 2s - loss: 0.2543 - acc: 0.9188 - auc_roc: 0.7464 - auc_pr: 0.3440 - val_loss: 0.3526 - val_acc: 0.9047 - val_auc_roc: 0.5338 - val_auc_pr: 0.1143
# Epoch 220/300
# 777/777 - 2s - loss: 0.2526 - acc: 0.9194 - auc_roc: 0.7507 - auc_pr: 0.3520 - val_loss: 0.3605 - val_acc: 0.9066 - val_auc_roc: 0.5218 - val_auc_pr: 0.1153
# Epoch 221/300
# 777/777 - 2s - loss: 0.2516 - acc: 0.9204 - auc_roc: 0.7506 - auc_pr: 0.3575 - val_loss: 0.3605 - val_acc: 0.9047 - val_auc_roc: 0.5164 - val_auc_pr: 0.1130
# Epoch 222/300
# 777/777 - 2s - loss: 0.2524 - acc: 0.9191 - auc_roc: 0.7528 - auc_pr: 0.3508 - val_loss: 0.3691 - val_acc: 0.9041 - val_auc_roc: 0.5230 - val_auc_pr: 0.1105
# Epoch 223/300
# 777/777 - 1s - loss: 0.2524 - acc: 0.9189 - auc_roc: 0.7511 - auc_pr: 0.3504 - val_loss: 0.3687 - val_acc: 0.9066 - val_auc_roc: 0.5276 - val_auc_pr: 0.1152
# Epoch 224/300
# 777/777 - 1s - loss: 0.2514 - acc: 0.9186 - auc_roc: 0.7521 - auc_pr: 0.3567 - val_loss: 0.3518 - val_acc: 0.9066 - val_auc_roc: 0.5215 - val_auc_pr: 0.1176
# Epoch 225/300
# 777/777 - 2s - loss: 0.2513 - acc: 0.9192 - auc_roc: 0.7572 - auc_pr: 0.3534 - val_loss: 0.3624 - val_acc: 0.9053 - val_auc_roc: 0.5157 - val_auc_pr: 0.1105
# Epoch 226/300
# 777/777 - 1s - loss: 0.2526 - acc: 0.9192 - auc_roc: 0.7491 - auc_pr: 0.3518 - val_loss: 0.3695 - val_acc: 0.9073 - val_auc_roc: 0.5156 - val_auc_pr: 0.1097
# Epoch 227/300
# 777/777 - 1s - loss: 0.2523 - acc: 0.9194 - auc_roc: 0.7463 - auc_pr: 0.3536 - val_loss: 0.3565 - val_acc: 0.9047 - val_auc_roc: 0.5263 - val_auc_pr: 0.1150
# Epoch 228/300
# 777/777 - 1s - loss: 0.2523 - acc: 0.9188 - auc_roc: 0.7454 - auc_pr: 0.3525 - val_loss: 0.3654 - val_acc: 0.9060 - val_auc_roc: 0.5292 - val_auc_pr: 0.1175
# Epoch 229/300
# 777/777 - 1s - loss: 0.2514 - acc: 0.9192 - auc_roc: 0.7528 - auc_pr: 0.3569 - val_loss: 0.3724 - val_acc: 0.9041 - val_auc_roc: 0.5242 - val_auc_pr: 0.1150
# Epoch 230/300
# 777/777 - 1s - loss: 0.2517 - acc: 0.9194 - auc_roc: 0.7485 - auc_pr: 0.3565 - val_loss: 0.3687 - val_acc: 0.9066 - val_auc_roc: 0.5105 - val_auc_pr: 0.1077
# Epoch 231/300
# 777/777 - 2s - loss: 0.2512 - acc: 0.9199 - auc_roc: 0.7496 - auc_pr: 0.3590 - val_loss: 0.3748 - val_acc: 0.9060 - val_auc_roc: 0.5175 - val_auc_pr: 0.1101
# Epoch 232/300
# 777/777 - 1s - loss: 0.2519 - acc: 0.9183 - auc_roc: 0.7571 - auc_pr: 0.3523 - val_loss: 0.3636 - val_acc: 0.9060 - val_auc_roc: 0.5181 - val_auc_pr: 0.1113
# Epoch 233/300
# 777/777 - 1s - loss: 0.2520 - acc: 0.9200 - auc_roc: 0.7469 - auc_pr: 0.3564 - val_loss: 0.3620 - val_acc: 0.9047 - val_auc_roc: 0.5204 - val_auc_pr: 0.1148
# Epoch 234/300
# 777/777 - 2s - loss: 0.2507 - acc: 0.9204 - auc_roc: 0.7542 - auc_pr: 0.3581 - val_loss: 0.3671 - val_acc: 0.9021 - val_auc_roc: 0.5234 - val_auc_pr: 0.1097
# Epoch 235/300
# 777/777 - 1s - loss: 0.2525 - acc: 0.9194 - auc_roc: 0.7535 - auc_pr: 0.3514 - val_loss: 0.3771 - val_acc: 0.9066 - val_auc_roc: 0.5213 - val_auc_pr: 0.1155
# Epoch 236/300
# 777/777 - 1s - loss: 0.2522 - acc: 0.9194 - auc_roc: 0.7528 - auc_pr: 0.3522 - val_loss: 0.3606 - val_acc: 0.9053 - val_auc_roc: 0.5257 - val_auc_pr: 0.1122
# Epoch 237/300
# 777/777 - 1s - loss: 0.2518 - acc: 0.9192 - auc_roc: 0.7514 - auc_pr: 0.3538 - val_loss: 0.3645 - val_acc: 0.9066 - val_auc_roc: 0.5252 - val_auc_pr: 0.1185
# Epoch 238/300
# 777/777 - 2s - loss: 0.2526 - acc: 0.9189 - auc_roc: 0.7482 - auc_pr: 0.3505 - val_loss: 0.3594 - val_acc: 0.9066 - val_auc_roc: 0.5227 - val_auc_pr: 0.1187
# Epoch 239/300
# 777/777 - 2s - loss: 0.2512 - acc: 0.9189 - auc_roc: 0.7548 - auc_pr: 0.3556 - val_loss: 0.3609 - val_acc: 0.9034 - val_auc_roc: 0.5251 - val_auc_pr: 0.1142
# Epoch 240/300
# 777/777 - 2s - loss: 0.2517 - acc: 0.9194 - auc_roc: 0.7493 - auc_pr: 0.3560 - val_loss: 0.3710 - val_acc: 0.9073 - val_auc_roc: 0.5138 - val_auc_pr: 0.1099
# Epoch 241/300
# 777/777 - 1s - loss: 0.2509 - acc: 0.9192 - auc_roc: 0.7569 - auc_pr: 0.3551 - val_loss: 0.3709 - val_acc: 0.9041 - val_auc_roc: 0.5163 - val_auc_pr: 0.1124
# Epoch 242/300
# 777/777 - 1s - loss: 0.2507 - acc: 0.9202 - auc_roc: 0.7554 - auc_pr: 0.3620 - val_loss: 0.3633 - val_acc: 0.9034 - val_auc_roc: 0.5218 - val_auc_pr: 0.1197
# Epoch 243/300
# 777/777 - 1s - loss: 0.2512 - acc: 0.9197 - auc_roc: 0.7501 - auc_pr: 0.3566 - val_loss: 0.3771 - val_acc: 0.9073 - val_auc_roc: 0.5203 - val_auc_pr: 0.1127
# Epoch 244/300
# 777/777 - 1s - loss: 0.2514 - acc: 0.9191 - auc_roc: 0.7509 - auc_pr: 0.3548 - val_loss: 0.3719 - val_acc: 0.9047 - val_auc_roc: 0.5141 - val_auc_pr: 0.1133
# Epoch 245/300
# 777/777 - 1s - loss: 0.2511 - acc: 0.9194 - auc_roc: 0.7506 - auc_pr: 0.3597 - val_loss: 0.3737 - val_acc: 0.9047 - val_auc_roc: 0.5120 - val_auc_pr: 0.1139
# Epoch 246/300
# 777/777 - 1s - loss: 0.2505 - acc: 0.9205 - auc_roc: 0.7536 - auc_pr: 0.3595 - val_loss: 0.3705 - val_acc: 0.9060 - val_auc_roc: 0.5214 - val_auc_pr: 0.1176
# Epoch 247/300
# 777/777 - 2s - loss: 0.2505 - acc: 0.9194 - auc_roc: 0.7562 - auc_pr: 0.3610 - val_loss: 0.3733 - val_acc: 0.9066 - val_auc_roc: 0.5107 - val_auc_pr: 0.1109
# Epoch 248/300
# 777/777 - 2s - loss: 0.2504 - acc: 0.9192 - auc_roc: 0.7581 - auc_pr: 0.3579 - val_loss: 0.3737 - val_acc: 0.9053 - val_auc_roc: 0.5233 - val_auc_pr: 0.1141
# Epoch 249/300
# 777/777 - 1s - loss: 0.2514 - acc: 0.9189 - auc_roc: 0.7468 - auc_pr: 0.3540 - val_loss: 0.3857 - val_acc: 0.9086 - val_auc_roc: 0.5032 - val_auc_pr: 0.1060
# Epoch 250/300
# 777/777 - 2s - loss: 0.2517 - acc: 0.9204 - auc_roc: 0.7525 - auc_pr: 0.3570 - val_loss: 0.3748 - val_acc: 0.9053 - val_auc_roc: 0.5272 - val_auc_pr: 0.1174
# Epoch 251/300
# 777/777 - 1s - loss: 0.2510 - acc: 0.9199 - auc_roc: 0.7508 - auc_pr: 0.3585 - val_loss: 0.3657 - val_acc: 0.9028 - val_auc_roc: 0.5248 - val_auc_pr: 0.1154
# Epoch 252/300
# 777/777 - 2s - loss: 0.2498 - acc: 0.9196 - auc_roc: 0.7597 - auc_pr: 0.3622 - val_loss: 0.3689 - val_acc: 0.9034 - val_auc_roc: 0.5194 - val_auc_pr: 0.1086
# Epoch 253/300
# 777/777 - 1s - loss: 0.2501 - acc: 0.9186 - auc_roc: 0.7556 - auc_pr: 0.3581 - val_loss: 0.3739 - val_acc: 0.9066 - val_auc_roc: 0.5079 - val_auc_pr: 0.1090
# Epoch 254/300
# 777/777 - 2s - loss: 0.2512 - acc: 0.9184 - auc_roc: 0.7554 - auc_pr: 0.3532 - val_loss: 0.3656 - val_acc: 0.9047 - val_auc_roc: 0.5181 - val_auc_pr: 0.1125
# Epoch 255/300
# 777/777 - 2s - loss: 0.2511 - acc: 0.9189 - auc_roc: 0.7587 - auc_pr: 0.3546 - val_loss: 0.3766 - val_acc: 0.9073 - val_auc_roc: 0.5077 - val_auc_pr: 0.1049
# Epoch 256/300
# 777/777 - 1s - loss: 0.2518 - acc: 0.9208 - auc_roc: 0.7478 - auc_pr: 0.3529 - val_loss: 0.3814 - val_acc: 0.9028 - val_auc_roc: 0.4928 - val_auc_pr: 0.1005
# Epoch 257/300
# 777/777 - 1s - loss: 0.2499 - acc: 0.9199 - auc_roc: 0.7523 - auc_pr: 0.3646 - val_loss: 0.3805 - val_acc: 0.9060 - val_auc_roc: 0.5150 - val_auc_pr: 0.1103
# Epoch 258/300
# 777/777 - 1s - loss: 0.2505 - acc: 0.9192 - auc_roc: 0.7565 - auc_pr: 0.3567 - val_loss: 0.3786 - val_acc: 0.9028 - val_auc_roc: 0.5212 - val_auc_pr: 0.1137
# Epoch 259/300
# 777/777 - 1s - loss: 0.2521 - acc: 0.9189 - auc_roc: 0.7491 - auc_pr: 0.3487 - val_loss: 0.3815 - val_acc: 0.9060 - val_auc_roc: 0.5159 - val_auc_pr: 0.1124
# Epoch 260/300
# 777/777 - 1s - loss: 0.2510 - acc: 0.9200 - auc_roc: 0.7524 - auc_pr: 0.3559 - val_loss: 0.3612 - val_acc: 0.9060 - val_auc_roc: 0.5213 - val_auc_pr: 0.1184
# Epoch 261/300
# 777/777 - 2s - loss: 0.2510 - acc: 0.9192 - auc_roc: 0.7541 - auc_pr: 0.3574 - val_loss: 0.3770 - val_acc: 0.9079 - val_auc_roc: 0.5167 - val_auc_pr: 0.1103
# Epoch 262/300
# 777/777 - 1s - loss: 0.2511 - acc: 0.9202 - auc_roc: 0.7513 - auc_pr: 0.3596 - val_loss: 0.3835 - val_acc: 0.9066 - val_auc_roc: 0.5166 - val_auc_pr: 0.1140
# Epoch 263/300
# 777/777 - 2s - loss: 0.2508 - acc: 0.9192 - auc_roc: 0.7549 - auc_pr: 0.3554 - val_loss: 0.3744 - val_acc: 0.9066 - val_auc_roc: 0.5210 - val_auc_pr: 0.1171
# Epoch 264/300
# 777/777 - 2s - loss: 0.2508 - acc: 0.9197 - auc_roc: 0.7510 - auc_pr: 0.3577 - val_loss: 0.3754 - val_acc: 0.9028 - val_auc_roc: 0.5212 - val_auc_pr: 0.1127
# Epoch 265/300
# 777/777 - 2s - loss: 0.2506 - acc: 0.9194 - auc_roc: 0.7570 - auc_pr: 0.3558 - val_loss: 0.3862 - val_acc: 0.9073 - val_auc_roc: 0.5094 - val_auc_pr: 0.1099
# Epoch 266/300
# 777/777 - 2s - loss: 0.2513 - acc: 0.9197 - auc_roc: 0.7509 - auc_pr: 0.3570 - val_loss: 0.3833 - val_acc: 0.9066 - val_auc_roc: 0.5212 - val_auc_pr: 0.1147
# Epoch 267/300
# 777/777 - 2s - loss: 0.2512 - acc: 0.9197 - auc_roc: 0.7502 - auc_pr: 0.3542 - val_loss: 0.3723 - val_acc: 0.9099 - val_auc_roc: 0.5200 - val_auc_pr: 0.1161
# Epoch 268/300
# 777/777 - 2s - loss: 0.2516 - acc: 0.9197 - auc_roc: 0.7527 - auc_pr: 0.3591 - val_loss: 0.3722 - val_acc: 0.9079 - val_auc_roc: 0.5180 - val_auc_pr: 0.1105
# Epoch 269/300
# 777/777 - 2s - loss: 0.2498 - acc: 0.9205 - auc_roc: 0.7546 - auc_pr: 0.3630 - val_loss: 0.3720 - val_acc: 0.9015 - val_auc_roc: 0.5106 - val_auc_pr: 0.1109
# Epoch 270/300
# 777/777 - 2s - loss: 0.2503 - acc: 0.9188 - auc_roc: 0.7595 - auc_pr: 0.3594 - val_loss: 0.3725 - val_acc: 0.9034 - val_auc_roc: 0.5194 - val_auc_pr: 0.1126
# Epoch 271/300
# 777/777 - 1s - loss: 0.2509 - acc: 0.9186 - auc_roc: 0.7522 - auc_pr: 0.3537 - val_loss: 0.3913 - val_acc: 0.9073 - val_auc_roc: 0.5223 - val_auc_pr: 0.1157
# Epoch 272/300
# 777/777 - 2s - loss: 0.2495 - acc: 0.9210 - auc_roc: 0.7554 - auc_pr: 0.3684 - val_loss: 0.3787 - val_acc: 0.9066 - val_auc_roc: 0.5106 - val_auc_pr: 0.1060
# Epoch 273/300
# 777/777 - 3s - loss: 0.2510 - acc: 0.9188 - auc_roc: 0.7561 - auc_pr: 0.3544 - val_loss: 0.3903 - val_acc: 0.9073 - val_auc_roc: 0.5094 - val_auc_pr: 0.1129
# Epoch 274/300
# 777/777 - 2s - loss: 0.2508 - acc: 0.9189 - auc_roc: 0.7513 - auc_pr: 0.3568 - val_loss: 0.3711 - val_acc: 0.9060 - val_auc_roc: 0.5211 - val_auc_pr: 0.1138
# Epoch 275/300
# 777/777 - 1s - loss: 0.2504 - acc: 0.9194 - auc_roc: 0.7571 - auc_pr: 0.3588 - val_loss: 0.3873 - val_acc: 0.9060 - val_auc_roc: 0.5124 - val_auc_pr: 0.1117
# Epoch 276/300
# 777/777 - 1s - loss: 0.2495 - acc: 0.9199 - auc_roc: 0.7542 - auc_pr: 0.3625 - val_loss: 0.3725 - val_acc: 0.9073 - val_auc_roc: 0.5260 - val_auc_pr: 0.1177
# Epoch 277/300
# 777/777 - 1s - loss: 0.2496 - acc: 0.9196 - auc_roc: 0.7570 - auc_pr: 0.3640 - val_loss: 0.3898 - val_acc: 0.9073 - val_auc_roc: 0.5118 - val_auc_pr: 0.1156
# Epoch 278/300
# 777/777 - 1s - loss: 0.2497 - acc: 0.9188 - auc_roc: 0.7537 - auc_pr: 0.3630 - val_loss: 0.3821 - val_acc: 0.9060 - val_auc_roc: 0.5136 - val_auc_pr: 0.1199
# Epoch 279/300
# 777/777 - 1s - loss: 0.2500 - acc: 0.9199 - auc_roc: 0.7533 - auc_pr: 0.3608 - val_loss: 0.3694 - val_acc: 0.9060 - val_auc_roc: 0.5205 - val_auc_pr: 0.1207
# Epoch 280/300
# 777/777 - 2s - loss: 0.2490 - acc: 0.9196 - auc_roc: 0.7581 - auc_pr: 0.3667 - val_loss: 0.3875 - val_acc: 0.9047 - val_auc_roc: 0.5153 - val_auc_pr: 0.1117
# Epoch 281/300
# 777/777 - 2s - loss: 0.2495 - acc: 0.9184 - auc_roc: 0.7605 - auc_pr: 0.3642 - val_loss: 0.3703 - val_acc: 0.9053 - val_auc_roc: 0.5176 - val_auc_pr: 0.1179
# Epoch 282/300
# 777/777 - 2s - loss: 0.2495 - acc: 0.9197 - auc_roc: 0.7576 - auc_pr: 0.3640 - val_loss: 0.3856 - val_acc: 0.9002 - val_auc_roc: 0.5117 - val_auc_pr: 0.1097
# Epoch 283/300
# 777/777 - 2s - loss: 0.2497 - acc: 0.9202 - auc_roc: 0.7584 - auc_pr: 0.3603 - val_loss: 0.3743 - val_acc: 0.9047 - val_auc_roc: 0.5197 - val_auc_pr: 0.1176
# Epoch 284/300
# 777/777 - 2s - loss: 0.2494 - acc: 0.9197 - auc_roc: 0.7582 - auc_pr: 0.3618 - val_loss: 0.4049 - val_acc: 0.9079 - val_auc_roc: 0.5150 - val_auc_pr: 0.1148
# Epoch 285/300
# 777/777 - 2s - loss: 0.2506 - acc: 0.9184 - auc_roc: 0.7592 - auc_pr: 0.3583 - val_loss: 0.3765 - val_acc: 0.9053 - val_auc_roc: 0.5144 - val_auc_pr: 0.1196
# Epoch 286/300
# 777/777 - 1s - loss: 0.2503 - acc: 0.9191 - auc_roc: 0.7571 - auc_pr: 0.3587 - val_loss: 0.3789 - val_acc: 0.9053 - val_auc_roc: 0.5175 - val_auc_pr: 0.1141
# Epoch 287/300
# 777/777 - 1s - loss: 0.2497 - acc: 0.9189 - auc_roc: 0.7543 - auc_pr: 0.3647 - val_loss: 0.3758 - val_acc: 0.9060 - val_auc_roc: 0.5227 - val_auc_pr: 0.1159
# Epoch 288/300
# 777/777 - 1s - loss: 0.2498 - acc: 0.9189 - auc_roc: 0.7593 - auc_pr: 0.3610 - val_loss: 0.3905 - val_acc: 0.9066 - val_auc_roc: 0.5134 - val_auc_pr: 0.1114
# Epoch 289/300
# 777/777 - 1s - loss: 0.2487 - acc: 0.9197 - auc_roc: 0.7638 - auc_pr: 0.3662 - val_loss: 0.3691 - val_acc: 0.9066 - val_auc_roc: 0.5206 - val_auc_pr: 0.1158
# Epoch 290/300
# 777/777 - 1s - loss: 0.2487 - acc: 0.9196 - auc_roc: 0.7647 - auc_pr: 0.3640 - val_loss: 0.3859 - val_acc: 0.9060 - val_auc_roc: 0.5077 - val_auc_pr: 0.1118
# Epoch 291/300
# 777/777 - 2s - loss: 0.2500 - acc: 0.9197 - auc_roc: 0.7573 - auc_pr: 0.3584 - val_loss: 0.3802 - val_acc: 0.9053 - val_auc_roc: 0.5180 - val_auc_pr: 0.1140
# Epoch 292/300
# 777/777 - 2s - loss: 0.2493 - acc: 0.9197 - auc_roc: 0.7612 - auc_pr: 0.3639 - val_loss: 0.3820 - val_acc: 0.9073 - val_auc_roc: 0.5028 - val_auc_pr: 0.1092
# Epoch 293/300
# 777/777 - 2s - loss: 0.2485 - acc: 0.9205 - auc_roc: 0.7630 - auc_pr: 0.3677 - val_loss: 0.3928 - val_acc: 0.9079 - val_auc_roc: 0.5085 - val_auc_pr: 0.1132
# Epoch 294/300
# 777/777 - 1s - loss: 0.2493 - acc: 0.9196 - auc_roc: 0.7553 - auc_pr: 0.3626 - val_loss: 0.3787 - val_acc: 0.9041 - val_auc_roc: 0.5190 - val_auc_pr: 0.1152
# Epoch 295/300
# 777/777 - 1s - loss: 0.2488 - acc: 0.9199 - auc_roc: 0.7596 - auc_pr: 0.3673 - val_loss: 0.3912 - val_acc: 0.9079 - val_auc_roc: 0.5243 - val_auc_pr: 0.1150
# Epoch 296/300
# 777/777 - 2s - loss: 0.2486 - acc: 0.9200 - auc_roc: 0.7545 - auc_pr: 0.3661 - val_loss: 0.3961 - val_acc: 0.9034 - val_auc_roc: 0.5165 - val_auc_pr: 0.1079
# Epoch 297/300
# 777/777 - 2s - loss: 0.2486 - acc: 0.9200 - auc_roc: 0.7589 - auc_pr: 0.3666 - val_loss: 0.3787 - val_acc: 0.9079 - val_auc_roc: 0.5120 - val_auc_pr: 0.1161
# Epoch 298/300
# 777/777 - 2s - loss: 0.2485 - acc: 0.9200 - auc_roc: 0.7584 - auc_pr: 0.3688 - val_loss: 0.3816 - val_acc: 0.9047 - val_auc_roc: 0.5138 - val_auc_pr: 0.1187
# Epoch 299/300
# 777/777 - 2s - loss: 0.2489 - acc: 0.9199 - auc_roc: 0.7577 - auc_pr: 0.3632 - val_loss: 0.3861 - val_acc: 0.9028 - val_auc_roc: 0.5143 - val_auc_pr: 0.1105
# Epoch 300/300
# 777/777 - 2s - loss: 0.2492 - acc: 0.9196 - auc_roc: 0.7550 - auc_pr: 0.3631 - val_loss: 0.3846 - val_acc: 0.9079 - val_auc_roc: 0.5141 - val_auc_pr: 0.1126
#
#
# Score for fold 5: loss of 0.384646475315094; auc_pr of 11.257261782884598%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.3558735251426697 - AUC PR: 10.833856463432312%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.37147021293640137 - AUC PR: 10.53875982761383%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.45690229535102844 - AUC PR: 13.771195709705353%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.371720552444458 - AUC PR: 12.956267595291138%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.384646475315094 - AUC PR: 11.257261782884598%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > AUC PR: 11.871468275785446 (+- 1.2661558816885254)
# > Loss: 0.3881226122379303
# ------------------------------------------------------------------------

# %%
# Execução para os dados de teste

X_test = features.loc[labeled_test.index].values
y_test = test_targets

test_metrics = model.evaluate(X_test, y_test)
print("\nTest Set Metrics:")
for name, val in zip(model.metrics_names, test_metrics):
    print("\t{}: {:0.4f}".format(name, val))
# Out:
# 61/61 [==============================] - 0s 3ms/step - loss: 0.4025 - acc: 0.9068 - auc_roc: 0.5522 - auc_pr: 0.1165
#
# Test Set Metrics:
# 	loss: 0.4025
# 	acc: 0.9068
# 	auc_roc: 0.5522
# 	auc_pr: 0.1165
